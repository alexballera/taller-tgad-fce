# %% [markdown]
# <figure>
# <center>
# <img src='https://www.economicas.uba.ar/wp-content/uploads/2020/08/cropped-logo_FCE.png' />
# </figure>

# %% [markdown]
# # **Universidad de Buenos Aires**
# ## **Facultad de Ciencias Económicas**
#
# ### **Taller de Programación para el Análisis de Datos**
#
# #### **Clase 0: ejecución de Colab en VSCode**

# %%
print('Bienvenidos al Taller de Programación para el Análisis de Datos de la Tecnicatura en Gestión y Análisis de Datos en Organizaciones')
# Out:
# Bienvenidos al Taller de Programación para el Análisis de Datos de la Tecnicatura en Gestión y Análisis de Datos en Organizaciones
