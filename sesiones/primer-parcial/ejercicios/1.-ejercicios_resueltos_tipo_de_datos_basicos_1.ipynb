# %% [markdown]
# #<center>Taller de Programación</center>
# #<center>Guía de Ejercicios — Elementos Básicos 1</center>

# %% [markdown]
# **Temas:** Variables, tipos de datos, operaciones aritméticas, división entera y resto, strings, indexing y slicing, f-strings, conversión de tipos, `input()`, type hints.
#
# > Cada ejercicio tiene su celda de resolución y una celda de solución debajo. Intentá resolver el ejercicio antes de mirar la solución.

# %% [markdown]
# ---
# ### **Ejercicio 1** — Variables y tipos de datos

# %% [markdown]
# Creá las siguientes variables con type hints y mostrá su valor y tipo con `print()`:
#
# - Tu nombre completo
# - Tu edad
# - Tu altura en metros
# - Si sos estudiante de grado (`True` o `False`)
#
# La salida esperada debe tener el formato:
# ```
# Nombre: Ana García | Tipo: <class 'str'>
# Edad: 22 | Tipo: <class 'int'>
# Altura: 1.68 | Tipo: <class 'float'>
# Estudiante de grado: True | Tipo: <class 'bool'>
# ```

# %%
# Tu resolución acá
nombre_completo: str = "Alexander Ballera"
edad: int = 24
altura_metros: float = 1.75
es_estudiante_grado: bool = True

print(f"Nombre: {nombre_completo} | Tipo: {type(nombre_completo)}")
print(f"Edad: {edad} | Tipo: {type(edad)}")
print(f"Altura: {altura_metros} | Tipo: {type(altura_metros)}")
print(f"Estudiante de grado: {es_estudiante_grado} | Tipo: {type(es_estudiante_grado)}")
# Out:
# Nombre: Alexander Ballera | Tipo: <class 'str'>
# Edad: 24 | Tipo: <class 'int'>
# Altura: 1.75 | Tipo: <class 'float'>
# Estudiante de grado: True | Tipo: <class 'bool'>

# %% [markdown]
# #### Solución — Ejercicio 1

# %%
nombre: str    = "Ana García"
edad: int      = 22
altura: float  = 1.68
es_grado: bool = True

print("Nombre:",            nombre,   "| Tipo:", type(nombre))
print("Edad:",              edad,     "| Tipo:", type(edad))
print("Altura:",            altura,   "| Tipo:", type(altura))
print("Estudiante de grado:", es_grado, "| Tipo:", type(es_grado))
# Out:
# Nombre: Ana García | Tipo: <class 'str'>
# Edad: 22 | Tipo: <class 'int'>
# Altura: 1.68 | Tipo: <class 'float'>
# Estudiante de grado: True | Tipo: <class 'bool'>

# %% [markdown]
# ---
# ### **Ejercicio 2** — Operaciones aritméticas básicas

# %% [markdown]
# Una empresa vendió **347 unidades** de un producto a **$2.850,00** cada una. Sobre el precio unitario se aplica un **IVA del 21%**.
#
# Calculá y mostrá:
# 1. El ingreso bruto (sin IVA)
# 2. El IVA total recaudado
# 3. El ingreso total (con IVA)
# 4. El precio unitario con IVA
#
# Usá type hints en todas las variables.

# %%
# Tu resolución acá
unidades: int = 347
precio_unitario: float = 2850.0
tasa_iva: float = 0.21

ingreso_bruto: float = unidades * precio_unitario
iva_total: float = ingreso_bruto * tasa_iva
ingreso_total: float = ingreso_bruto + iva_total
precio_unitario_con_iva: float = precio_unitario * (1 + tasa_iva)

print(f"Ingreso bruto (sin IVA): ${ingreso_bruto:.2f}")
print(f"IVA total recaudado:     ${iva_total:.2f}")
print(f"Ingreso total (con IVA): ${ingreso_total:.2f}")
print(f"Precio unitario con IVA: ${precio_unitario_con_iva:.2f}")
# Out:
# Ingreso bruto (sin IVA): $988950.00
# IVA total recaudado:     $207679.50
# Ingreso total (con IVA): $1196629.50
# Precio unitario con IVA: $3448.50

# %% [markdown]
# #### Solución — Ejercicio 2

# %%
unidades: int          = 347
precio_unitario: float = 2850.0
tasa_iva: float        = 0.21

ingreso_bruto: float   = unidades * precio_unitario
iva_total: float       = ingreso_bruto * tasa_iva
ingreso_total: float   = ingreso_bruto + iva_total
precio_con_iva: float  = precio_unitario * (1 + tasa_iva)

print("Ingreso bruto:         $", ingreso_bruto)
print("IVA total:             $", iva_total)
print("Ingreso total:         $", ingreso_total)
print("Precio unitario + IVA: $", precio_con_iva)
# Out:
# Ingreso bruto:         $ 988950.0
# IVA total:             $ 207679.5
# Ingreso total:         $ 1196629.5
# Precio unitario + IVA: $ 3448.5

# %% [markdown]
# ---
# ### **Ejercicio 3** — División entera y resto (`//` y `%`)

# %% [markdown]
# Un depósito recibió **1.250 unidades** de un producto. Cada caja contiene **48 unidades**.
#
# Calculá y mostrá:
# 1. Cuántas cajas completas se pueden armar
# 2. Cuántas unidades sobran (no caben en ninguna caja)
# 3. Si sobran unidades, cuántas unidades faltan para completar una caja más
#
# La salida esperada:
# ```
# Unidades totales: 1250
# Cajas completas: 26
# Unidades sobrantes: 2
# Faltan 46 unidades para completar otra caja
# ```

# %%
# Tu resolución acá
unidades_totales: int = 1250
unidades_por_caja: int = 48

cajas_completas: int = unidades_totales // unidades_por_caja
unidades_sobrantes: int = unidades_totales % unidades_por_caja

print(f"Unidades totales: {unidades_totales}")
print(f"Cajas completas: {cajas_completas}")
print(f"Unidades sobrantes: {unidades_sobrantes}")

if unidades_sobrantes > 0:
    faltan: int = unidades_por_caja - unidades_sobrantes
    print(f"Faltan {faltan} unidades para completar otra caja")
else:
    print("No sobran unidades")
# Out:
# Unidades totales: 1250
# Cajas completas: 26
# Unidades sobrantes: 2
# Faltan 46 unidades para completar otra caja

# %% [markdown]
# #### Solución — Ejercicio 3

# %%
unidades: int        = 1250
por_caja: int        = 48

cajas_completas: int = unidades // por_caja
sobrantes: int       = unidades % por_caja
faltan: int          = por_caja - sobrantes

print("Unidades totales:", unidades)
print("Cajas completas:",  cajas_completas)
print("Unidades sobrantes:", sobrantes)
print("Faltan", faltan, "unidades para completar otra caja")
# Out:
# Unidades totales: 1250
# Cajas completas: 26
# Unidades sobrantes: 2
# Faltan 46 unidades para completar otra caja

# %% [markdown]
# ---
# ### **Ejercicio 4** — Indexing y slicing de strings

# %% [markdown]
# Dada la siguiente variable:
#
# ```python
# codigo: str = "UCA-AN-2024-G01"
# ```
#
# Este código tiene el formato `INSTITUCION-CARRERA-AÑO-GRUPO`. Sin usar métodos como `.split()`, usá **indexing y slicing** para extraer:
#
# 1. La institución (`"UCA"`) → primeros 3 caracteres
# 2. La carrera (`"AN"`) → caracteres 4 y 5
# 3. El año (`"2024"`) → caracteres 7 al 10
# 4. El grupo (`"G01"`) → últimos 3 caracteres
# 5. El código completo al revés
# 6. Solo los caracteres en posiciones pares (0, 2, 4, ...)
#
# Mostrá cada resultado con una etiqueta descriptiva.

# %%
# Tu resolución acá
codigo: str = "UCA-AN-2024-G01"

institucion: str = codigo[:3]
carrera: str = codigo[4:6]
anio: str = codigo[7:11]
grupo: str = codigo[-3:]
codigo_al_reves: str = codigo[::-1]
posiciones_pares: str = codigo[::2]

print(f"Institución: {institucion}")
print(f"Carrera: {carrera}")
print(f"Año: {anio}")
print(f"Grupo: {grupo}")
print(f"Código al revés: {codigo_al_reves}")
print(f"Posiciones pares: {posiciones_pares}")
# Out:
# Institución: UCA
# Carrera: AN
# Año: 2024
# Grupo: G01
# Código al revés: 10G-4202-NA-ACU
# Posiciones pares: UAA-04G1

# %% [markdown]
# #### Solución — Ejercicio 4

# %%
codigo: str = "UCA-AN-2024-G01"

institucion: str = codigo[:3]
carrera: str     = codigo[4:6]
anio: str        = codigo[7:11]
grupo: str       = codigo[-3:]
al_reves: str    = codigo[::-1]
pares: str       = codigo[::2]

print("Institución:", institucion)
print("Carrera:    ", carrera)
print("Año:        ", anio)
print("Grupo:      ", grupo)
print("Al revés:   ", al_reves)
print("Pos. pares: ", pares)
# Out:
# Institución: UCA
# Carrera:     AN
# Año:         2024
# Grupo:       G01
# Al revés:    10G-4202-NA-ACU
# Pos. pares:  UAA-04G1

# %% [markdown]
# ---
# ### **Ejercicio 5** — Métodos de strings

# %% [markdown]
# Dado el siguiente texto:
#
# ```python
# texto: str = "  Licenciatura en Analítica de Negocios  "
# ```
#
# Sin modificar la variable original, realizá las siguientes operaciones y mostrá el resultado:
#
# 1. Eliminá los espacios del inicio y del final
# 2. Convertí el texto limpio a mayúsculas
# 3. Convertí el texto limpio a minúsculas
# 4. Reemplazá `"Analítica"` por `"Ciencia"`
# 5. Contá cuántas veces aparece la letra `"a"` (minúscula) en el texto limpio
# 6. Verificá si el texto limpio empieza con `"Licenciatura"` (`True`/`False`)
# 7. Mostrá la cantidad de caracteres del texto limpio

# %%
# Tu resolución acá
texto: str = "  Licenciatura en Analítica de Negocios  "

texto_limpio: str = texto.strip()
texto_mayusculas: str = texto_limpio.upper()
texto_minusculas: str = texto_limpio.lower()
texto_reemplazado: str = texto_limpio.replace("Analítica", "Ciencia")
cantidad_a: int = texto_limpio.count("a")
empieza_con_licenciatura: bool = texto_limpio.startswith("Licenciatura")
longitud_texto: int = len(texto_limpio)

print(f"Sin espacios: {texto_limpio}")
print(f"Mayúsculas: {texto_mayusculas}")
print(f"Minúsculas: {texto_minusculas}")
print(f"Reemplazo: {texto_reemplazado}")
print(f"Cantidad de 'a': {cantidad_a}")
print(f"Empieza con 'Licenciatura': {empieza_con_licenciatura}")
print(f"Longitud: {longitud_texto}")
# Out:
# Sin espacios: Licenciatura en Analítica de Negocios
# Mayúsculas: LICENCIATURA EN ANALÍTICA DE NEGOCIOS
# Minúsculas: licenciatura en analítica de negocios
# Reemplazo: Licenciatura en Ciencia de Negocios
# Cantidad de 'a': 4
# Empieza con 'Licenciatura': True
# Longitud: 37

# %% [markdown]
# #### Solución — Ejercicio 5

# %%
texto: str = "  Licenciatura en Analítica de Negocios  "

texto_limpio: str = texto.strip()

print("Sin espacios:      ", texto_limpio)
print("Mayúsculas:        ", texto_limpio.upper())
print("Minúsculas:        ", texto_limpio.lower())
print("Reemplazo:         ", texto_limpio.replace("Analítica", "Ciencia"))
print("Cantidad 'a':      ", texto_limpio.count("a"))
print("Empieza con 'Lic':", texto_limpio.startswith("Licenciatura"))
print("Longitud:          ", len(texto_limpio))
# Out:
# Sin espacios:       Licenciatura en Analítica de Negocios
# Mayúsculas:         LICENCIATURA EN ANALÍTICA DE NEGOCIOS
# Minúsculas:         licenciatura en analítica de negocios
# Reemplazo:          Licenciatura en Ciencia de Negocios
# Cantidad 'a':       4
# Empieza con 'Lic': True
# Longitud:           37

# %% [markdown]
# ---
# ### **Ejercicio 6** — f-strings y formato de salida

# %% [markdown]
# Tenés los siguientes datos de un producto:
#
# ```python
# nombre: str    = "Monitor 27 pulgadas"
# precio: float  = 87650.0
# stock: int     = 14
# descuento: float = 0.12
# ```
#
# Usando **exclusivamente f-strings**, generá la siguiente salida. Prestá atención al formato de los números:
#
# ```
# Producto:        Monitor 27 pulgadas
# Precio original: $87650.00
# Descuento:       12.00%
# Ahorro:          $10518.00
# Precio final:    $77132.00
# Stock:           14 unidades
# ```

# %%
# Tu resolución acá
nombre: str = "Monitor 27 pulgadas"
precio: float = 87650.0
stock: int = 14
descuento: float = 0.12

ahorro: float = precio * descuento
precio_final: float = precio - ahorro

print(f"Producto:        {nombre}")
print(f"Precio original: ${precio:.2f}")
print(f"Descuento:       {descuento * 100:.2f}%")
print(f"Ahorro:          ${ahorro:.2f}")
print(f"Precio final:    ${precio_final:.2f}")
print(f"Stock:           {stock} unidades")
# Out:
# Producto:        Monitor 27 pulgadas
# Precio original: $87650.00
# Descuento:       12.00%
# Ahorro:          $10518.00
# Precio final:    $77132.00
# Stock:           14 unidades

# %% [markdown]
# #### Solución — Ejercicio 6

# %%
nombre: str      = "Monitor 27 pulgadas"
precio: float    = 87650.0
stock: int       = 14
descuento: float = 0.12

ahorro: float       = precio * descuento
precio_final: float = precio - ahorro

print(f"Producto:        {nombre}")
print(f"Precio original: ${precio:.2f}")
print(f"Descuento:       {descuento * 100:.2f}%")
print(f"Ahorro:          ${ahorro:.2f}")
print(f"Precio final:    ${precio_final:.2f}")
print(f"Stock:           {stock} unidades")
# Out:
# Producto:        Monitor 27 pulgadas
# Precio original: $87650.00
# Descuento:       12.00%
# Ahorro:          $10518.00
# Precio final:    $77132.00
# Stock:           14 unidades

# %% [markdown]
# ---
# ### **Ejercicio 7** — Conversión de tipos

# %% [markdown]
# El siguiente programa simula la lectura de datos ingresados por un usuario. Los datos llegan siempre como **strings**:
#
# ```python
# entrada_precio    = "1250.50"
# entrada_cantidad  = "8"
# entrada_descuento = "15"
# ```
#
# Convertí cada variable al tipo adecuado y calculá:
#
# 1. El subtotal (precio × cantidad)
# 2. El monto del descuento
# 3. El total final
# 4. Un mensaje de resumen con f-string:
# ```
# Resumen: 8 unidades a $1250.50 c/u | Descuento: 15% | Total: $8503.40
# ```

# %%
# Tu resolución acá
entrada_precio: str = "1250.50"
entrada_cantidad: str = "8"
entrada_descuento: str = "15"

precio: float = float(entrada_precio)
cantidad: int = int(entrada_cantidad)
descuento: float = float(entrada_descuento)

subtotal: float = precio * cantidad
monto_descuento: float = subtotal * (descuento / 100)
total_final: float = subtotal - monto_descuento

print(f"Subtotal: ${subtotal:.2f}")
print(f"Monto del descuento: ${monto_descuento:.2f}")
print(f"Total final: ${total_final:.2f}")
print(f"Resumen: {cantidad} unidades a ${precio:.2f} c/u | Descuento: {int(descuento)}% | Total: ${total_final:.2f}")
# Out:
# Subtotal: $10004.00
# Monto del descuento: $1500.60
# Total final: $8503.40
# Resumen: 8 unidades a $1250.50 c/u | Descuento: 15% | Total: $8503.40

# %% [markdown]
# #### Solución — Ejercicio 7

# %%
entrada_precio:    str = "1250.50"
entrada_cantidad:  str = "8"
entrada_descuento: str = "15"

precio: float    = float(entrada_precio)
cantidad: int    = int(entrada_cantidad)
descuento: float = float(entrada_descuento)

subtotal: float        = precio * cantidad
monto_descuento: float = subtotal * (descuento / 100)
total: float           = subtotal - monto_descuento

print(f"Resumen: {cantidad} unidades a ${precio} c/u | "
      f"Descuento: {int(descuento)}% | Total: ${total:.2f}")
# Out:
# Resumen: 8 unidades a $1250.5 c/u | Descuento: 15% | Total: $8503.40

# %% [markdown]
# ---
# ### **Ejercicio 8** — `input()` y conversión de tipos

# %% [markdown]
# Escribí un programa que le pida al usuario:
#
# 1. Su nombre
# 2. Su salario mensual bruto (como número)
# 3. Su porcentaje de ahorro mensual (como número entre 0 y 100)
#
# Y luego muestre:
#
# ```
# Hola, Martín!
# Tu salario bruto es: $45000.00
# Ahorrás el 20% → $9000.00 por mes
# En un año acumulás: $108000.00
# ```
#
# > Recordá que `input()` siempre devuelve un string: convertí los números antes de operar.

# %%
# Tu resolución acá
nombre: str = input("Tu nombre: ")
salario_bruto_str: str = input("Tu salario mensual bruto: ")
porcentaje_ahorro_str: str = input("Tu porcentaje de ahorro (0-100): ")

salario_bruto: float = float(salario_bruto_str)
porcentaje_ahorro: float = float(porcentaje_ahorro_str)

ahorro_mensual: float = salario_bruto * (porcentaje_ahorro / 100)
ahorro_anual: float = ahorro_mensual * 12

print(f"Hola, {nombre}!")
print(f"Tu salario bruto es: ${salario_bruto:.2f}")
print(f"Ahorrás el {int(porcentaje_ahorro)}% -> ${ahorro_mensual:.2f} por mes")
print(f"En un año acumulás: ${ahorro_anual:.2f}")
# Out:
# Hola, Alexander!
# Tu salario bruto es: $2000000.00
# Ahorrás el 10% -> $200000.00 por mes
# En un año acumulás: $2400000.00

# %% [markdown]
# #### Solución — Ejercicio 8

# %%
nombre: str             = input("Tu nombre: ")
salario_str: str        = input("Tu salario mensual bruto: ")
porcentaje_str: str     = input("Tu porcentaje de ahorro (0-100): ")

salario: float          = float(salario_str)
porcentaje: float       = float(porcentaje_str)

ahorro_mensual: float   = salario * (porcentaje / 100)
ahorro_anual: float     = ahorro_mensual * 12

print(f"Hola, {nombre}!")
print(f"Tu salario bruto es: ${salario:.2f}")
print(f"Ahorrás el {int(porcentaje)}% → ${ahorro_mensual:.2f} por mes")
print(f"En un año acumulás: ${ahorro_anual:.2f}")
# Out:
# Hola, Alexander!
# Tu salario bruto es: $2000000.00
# Ahorrás el 10% → $200000.00 por mes
# En un año acumulás: $2400000.00

# %% [markdown]
# ---
# ### **Ejercicio 9** — Manipulación avanzada de strings

# %% [markdown]
# Escribí un programa que procese el nombre completo de una persona. El usuario ingresa su nombre y apellido **en cualquier combinación de mayúsculas y minúsculas** (por ejemplo: `"ana GARCÍA"`, `"BRUNO lopez"`, `"carla Pérez"`).
#
# El programa debe:
#
# 1. Leer el nombre completo con `input()`
# 2. Normalizar el formato a **título** (primera letra de cada palabra en mayúscula)
# 3. Separar nombre y apellido (asumí que son exactamente dos palabras)
# 4. Generar un nombre de usuario con el formato: primera letra del nombre + apellido en minúsculas
# 5. Mostrar el resultado:
#
# ```
# Nombre completo:  Ana García
# Nombre:           Ana
# Apellido:         García
# Usuario:          agarcia
# Largo del nombre: 9 caracteres (sin espacios)
# ```
#
# **Pistas:** `.title()`, `.split()`, indexing de listas, `.replace()`

# %%
# Tu resolución acá
entrada: str = input("Ingresá tu nombre completo: ")

nombre_completo: str = entrada.strip().title()
partes: list[str] = nombre_completo.split()

if len(partes) < 2:
    print("Error: ingresá nombre y apellido (dos palabras).")
else:
    nombre: str = partes[0]
    apellido: str = partes[1]
    usuario: str = nombre[0].lower() + apellido.lower()
    largo_sin_espacios: int = len(nombre_completo.replace(" ", ""))

    print(f"Nombre completo:  {nombre_completo}")
    print(f"Nombre:           {nombre}")
    print(f"Apellido:         {apellido}")
    print(f"Usuario:          {usuario}")
    print(f"Largo del nombre: {largo_sin_espacios} caracteres (sin espacios)")
# Out:
# Nombre completo:  Alexander Ballera
# Nombre:           Alexander
# Apellido:         Ballera
# Usuario:          aballera
# Largo del nombre: 16 caracteres (sin espacios)

# %% [markdown]
# #### Solución — Ejercicio 9

# %%
entrada: str          = input("Ingresá tu nombre completo: ")

nombre_completo: str  = entrada.strip().title()
partes: list          = nombre_completo.split()
nombre: str           = partes[0]
apellido: str         = partes[1]
usuario: str          = nombre[0].lower() + apellido.lower()
largo: int            = len(nombre_completo.replace(" ", ""))

print(f"Nombre completo:  {nombre_completo}")
print(f"Nombre:           {nombre}")
print(f"Apellido:         {apellido}")
print(f"Usuario:          {usuario}")
print(f"Largo del nombre: {largo} caracteres (sin espacios)")
# Out:
# Nombre completo:  Alexander Ballera
# Nombre:           Alexander
# Apellido:         Ballera
# Usuario:          aballera
# Largo del nombre: 16 caracteres (sin espacios)

# %% [markdown]
# ---
# ### **Ejercicio 10** — Integrador

# %% [markdown]
# Un empleado tiene los siguientes datos:
#
# ```
# Nombre:                     "María José Rodríguez"
# Salario bruto:              95000.0
# Años de antigüedad:         7
# Adicional por antigüedad:   2% por año
# Impuesto a las ganancias:   17%
# ```
#
# Calculá y mostrá un **recibo de sueldo** con el siguiente formato:
#
# ```
# ========================================
#            RECIBO DE SUELDO
# ========================================
# Empleado:            MARÍA JOSÉ RODRÍGUEZ
# Iniciales:           MJR
# ----------------------------------------
# Salario base:        $95000.00
# Adicional (7 años):  $13300.00
#                      ----------
# Salario bruto:       $108300.00
# Descuento (17%):    -$18411.00
#                      ----------
# SALARIO NETO:        $89889.00
# ========================================
# ```
#
# **Además:**
# - Las iniciales se obtienen tomando la primera letra de cada palabra del nombre
# - El nombre debe mostrarse en mayúsculas
# - Usá f-strings con `:.2f` para todos los montos

# %%
# Tu resolución acá
nombre_completo: str = "María José Rodríguez"
salario_base: float = 95000.0
anios_antiguedad: int = 7
tasa_antiguedad_por_anio: float = 0.02
tasa_impuesto: float = 0.17

adicional_antiguedad: float = salario_base * anios_antiguedad * tasa_antiguedad_por_anio
salario_bruto: float = salario_base + adicional_antiguedad
descuento_impuesto: float = salario_bruto * tasa_impuesto
salario_neto: float = salario_bruto - descuento_impuesto

iniciales: str = ""
for palabra in nombre_completo.split():
    iniciales += palabra[0].upper()

separador_igual: str = "=" * 40
separador_guion: str = "-" * 40

print(separador_igual)
print("           RECIBO DE SUELDO")
print(separador_igual)
print(f"Empleado:            {nombre_completo.upper()}")
print(f"Iniciales:           {iniciales}")
print(separador_guion)
print(f"Salario base:        ${salario_base:.2f}")
print(f"Adicional ({anios_antiguedad} años):  ${adicional_antiguedad:.2f}")
print("                     ----------")
print(f"Salario bruto:       ${salario_bruto:.2f}")
print(f"Descuento ({int(tasa_impuesto * 100)}%):    -${descuento_impuesto:.2f}")
print("                     ----------")
print(f"SALARIO NETO:        ${salario_neto:.2f}")
print(separador_igual)
# Out:
# ...
#            RECIBO DE SUELDO
# ...
# Empleado:            MARÍA JOSÉ RODRÍGUEZ
# Iniciales:           MJR
# ----------------------------------------
# Salario base:        $95000.00
# Adicional (7 años):  $13300.00
#                      ----------
# Salario bruto:       $108300.00
# Descuento (17%):    -$18411.00
#                      ----------
# SALARIO NETO:        $89889.00
# ...

# %% [markdown]
# #### Solución — Ejercicio 10

# %%
nombre: str            = "María José Rodríguez"
salario_base: float    = 95000.0
anios: int             = 7
tasa_antiguedad: float = 0.02
tasa_impuesto: float   = 0.17

# Cálculos
adicional: float       = salario_base * anios * tasa_antiguedad
salario_bruto: float   = salario_base + adicional
descuento: float       = salario_bruto * tasa_impuesto
salario_neto: float    = salario_bruto - descuento

# Iniciales: primera letra de cada palabra
iniciales: str = ""
for palabra in nombre.split():
    iniciales = iniciales + palabra[0].upper()

# Formato de salida
sep1: str = "=" * 40
sep2: str = "-" * 40

print(sep1)
print("           RECIBO DE SUELDO")
print(sep1)
print(f"Empleado:            {nombre.upper()}")
print(f"Iniciales:           {iniciales}")
print(sep2)
print(f"Salario base:        ${salario_base:.2f}")
print(f"Adicional ({anios} años):  ${adicional:.2f}")
print(f"                     ----------")
print(f"Salario bruto:       ${salario_bruto:.2f}")
print(f"Descuento ({int(tasa_impuesto*100)}%):    -${descuento:.2f}")
print(f"                     ----------")
print(f"SALARIO NETO:        ${salario_neto:.2f}")
print(sep1)
# Out:
# ...
#            RECIBO DE SUELDO
# ...
# Empleado:            MARÍA JOSÉ RODRÍGUEZ
# Iniciales:           MJR
# ----------------------------------------
# Salario base:        $95000.00
# Adicional (7 años):  $13300.00
#                      ----------
# Salario bruto:       $108300.00
# Descuento (17%):    -$18411.00
#                      ----------
# SALARIO NETO:        $89889.00
# ...
