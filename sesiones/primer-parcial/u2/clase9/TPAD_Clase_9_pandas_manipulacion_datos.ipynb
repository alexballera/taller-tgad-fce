# %% [markdown]
# <figure>
# <center>
# <img src='https://www.economicas.uba.ar/wp-content/uploads/2020/08/cropped-logo_FCE.png' />
# </figure>

# %% [markdown]
# # **Universidad de Buenos Aires**
# ## **Facultad de Ciencias Económicas**
#
# ### **Taller de Programación para el Análisis de Datos**
#
# #### **Clase 9: Manipulación de datos**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **pandas** es una herramienta de manipulación y análisis de datos de código abierto construida sobre el lenguaje de programación **Python** .
#
# Algunas de las principales características de esta librería son:
#
# * Define nuevas estructuras de datos basadas en los arrays de la librería NumPy pero con nuevas funcionalidades.
# * Permite leer y escribir fácilmente archivos en formato CSV, Excel y bases de datos SQL.
# * Permite acceder a los datos mediante índices o nombres para filas y columnas.
# * Ofrece métodos para reordenar, dividir y combinar conjuntos de datos.

# %% [markdown]
# Links de interés
#
# https://pandas.pydata.org

# %% [markdown]
# Importamos las librerías que vamos a utilizar

# %%
import pandas as pd

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Ejemplo 1

# %% [markdown]
# Cargamos el archivo de datos en un dataframe de Pandas

# %%
df=pd.read_csv('Software_Professional_Salaries.csv')

# %%
type(df) # devuelve un DataFrame
# Out:
# pandas.DataFrame

# %% [markdown]
# Listar la cantidad de filas y columnas que tiene el dataset

# %%
df.shape # devuelve una tupla con el número de filas y columnas
# Out:
# (22770, 8)

# %%
print("cant filas",df.shape[0])
print("cant columnas",df.shape[1])
# Out:
# cant filas 22770
# cant columnas 8

# %%
dimensiones=df.shape
print("cant filas",dimensiones[0])
print("cant columnas",dimensiones[1])
# Out:
# cant filas 22770
# cant columnas 8

# %%
cant_filas, cant_cols = df.shape

print("cant filas",cant_filas)
print("cant columnas",cant_cols)
# Out:
# cant filas 22770
# cant columnas 8

# %%
df.head() # devuelve las primeras 5 filas del DataFrame, si se le pasa un número devuelve esa cantidad de filas
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %% [markdown]
# Mostramos las primeras
# del dataset

# %%
df.head(9) # devuelve las primeras 9 filas del DataFrame
# Out:
#    Rating                             Company Name          Job Title  \
# 0     3.8                                   Sasken  Android Developer
# 1     4.5         Advanced Millennium Technologies  Android Developer
# 2     4.0                                Unacademy  Android Developer
# 3     3.8                       SnapBizz Cloudtech  Android Developer
# 4     4.4                   Appoids Tech Solutions  Android Developer
# 5     4.2                               Freelancer  Android Developer
# 6     3.7                            SQUARE N CUBE  Android Developer
# 7     3.1  Samsung R&D Institute India - Bangalore  Android Developer
# 8     3.7                     DXMinds Technologies  Android Developer
#
#     Salary  Salaries Reported   Location Employment Status Job Roles
# 0   400000                  3  Bangalore         Full Time   Android
# 1   400000                  3  Bangalore         Full Time   Android
# ...

# %% [markdown]
# Mostramos las últimas filas del dataset

# %%
df.tail() # devuelve las últimas 5 filas del DataFrame, si se le pasa un número devuelve esa cantidad de filas
# Out:
#        Rating             Company Name                 Job Title  Salary  \
# 22765     4.7         Expert Solutions             Web Developer  200000
# 22766     4.0  Nextgen Innovation Labs             Web Developer  300000
# 22767     4.1                  Fresher  Full Stack Web Developer  192000
# 22768     4.1                Accenture  Full Stack Web Developer  300000
# 22769     3.8          Thomson Reuters   Associate Web Developer  300000
#
#        Salaries Reported   Location Employment Status Job Roles
# 22765                  1  Bangalore         Full Time       Web
# 22766                  1  Bangalore         Full Time       Web
# 22767                 13  Bangalore         Full Time       Web
# 22768                  7  Bangalore         Full Time       Web
# 22769                  7  Bangalore         Full Time       Web

# %%
df.tail(10) # devuelve las últimas 10 filas del DataFrame
# Out:
#        Rating             Company Name                 Job Title  Salary  \
# 22760     4.0              DiscoverWeb             Web Developer  100000
# 22761     4.6             Masai School             Web Developer  101376
# 22762     3.9            Fresher Zones             Web Developer  100000
# 22763     4.4           Unicon Systems             Web Developer  500000
# 22764     5.0                   BJSHub             Web Developer  400000
# 22765     4.7         Expert Solutions             Web Developer  200000
# 22766     4.0  Nextgen Innovation Labs             Web Developer  300000
# 22767     4.1                  Fresher  Full Stack Web Developer  192000
# 22768     4.1                Accenture  Full Stack Web Developer  300000
# 22769     3.8          Thomson Reuters   Associate Web Developer  300000
#
#        Salaries Reported   Location Employment Status Job Roles
# 22760                  1  Bangalore         Full Time       Web
# ...

# %% [markdown]
# Mostramos algunas filas del azar

# %%
df.sample() # devuelve una fila aleatoria del DataFrame, si se le pasa un número devuelve esa cantidad de filas aleatorias
# Out:
#        Rating Company Name                      Job Title  Salary  \
# 16008     3.9      VComply  Software Development Engineer  650000
#
#        Salaries Reported Location Employment Status Job Roles
# 16008                  1  Kolkata         Full Time       SDE

# %%
df.sample(10) # devuelve 10 filas aleatorias del DataFrame
# Out:
#        Rating                   Company Name  \
# 2219      4.0                        Agnitio
# 3843      4.5                        Grappus
# 10173     4.5                         Google
# 12463     4.5                     HackerRank
# 4338      3.4  Rohini Industrial Electricals
# 4804      4.2                            CSG
# 20080     2.6                   SOA Software
# 18808     3.9                            XYZ
# 10628     4.4                      Microsoft
# 11195     5.0                        Teqpool
#
#                                  Job Title   Salary  Salaries Reported  \
# 2219                     Android Developer   216000                  1
# 3843            Backend Developer - Intern   144000                  1
# 10173                Senior Java Developer  4900000                  1
# 12463  Software Development Engineer (SDE)  1600000                  2
# 4338                Database Administrator   700000                  1
# ...

# %%
df.columns # devuelve un Index con los nombres de las columnas del DataFrame
# Out:
# Index(['Rating', 'Company Name', 'Job Title', 'Salary', 'Salaries Reported',
#        'Location', 'Employment Status', 'Job Roles'],
#       dtype='str')

# %%
type(df.columns) # devuelve el tipo de dato de df.columns, que es un Index, un objeto similar a una lista pero con algunas funcionalidades adicionales
# Out:
# pandas.Index

# %%
df.columns.values # devuelve un array de numpy con los nombres de las columnas del DataFrame
# Out:
# <StringArray>
# [           'Rating',      'Company Name',         'Job Title',
#             'Salary', 'Salaries Reported',          'Location',
#  'Employment Status',         'Job Roles']
# Length: 8, dtype: str

# %%
type(df.columns.values) # devuelve el tipo de dato de df.columns.values, que es un array de numpy, un objeto similar a una lista pero con algunas funcionalidades adicionales y optimizado para cálculos numéricos
# Out:
# pandas.arrays.StringArray

# %% [markdown]
# Listar los nombres de las columnas del dataset

# %%
df.columns.tolist() # devuelve una lista con los nombres de las columnas del DataFrame, es una forma de convertir el Index a una lista común y corriente
# Out:
# ['Rating',
#  'Company Name',
#  'Job Title',
#  'Salary',
#  'Salaries Reported',
#  'Location',
#  'Employment Status',
#  'Job Roles']

# %%
nombre_cols=df.columns.tolist() # guardo la lista de nombres de columnas en una variable para usarla después

type(nombre_cols) # devuelve el tipo de dato de nombre_cols, que es una lista, un objeto que puede contener cualquier tipo de dato y tiene muchas funcionalidades para manipular sus elementos
# Out:
# list

# %%
lista_columnas=df.columns.tolist() # guardo la lista de nombres de columnas en una variable para usarla después

for columna in lista_columnas:
  print(columna)
# Out:
# Rating
# Company Name
# Job Title
# Salary
# Salaries Reported
# Location
# Employment Status
# Job Roles

# %%
lista_columnas.pop(0) # elimina el primer elemento de la lista, que es el nombre de la primera columna, y lo devuelve, en este caso 'Timestamp'
# Out:
# 'Rating'

# %%
lista_columnas # muestra la lista de columnas sin el primer elemento, que era 'Timestamp'
# Out:
# ['Company Name',
#  'Job Title',
#  'Salary',
#  'Salaries Reported',
#  'Location',
#  'Employment Status',
#  'Job Roles']

# %% [markdown]
# Mostrar el tipo de cada columna del dataframe

# %%
df.info() # muestra un resumen de la información del DataFrame, incluyendo el número de filas, el número de columnas, el tipo de dato de cada columna, la cantidad de valores no nulos y la cantidad de memoria utilizada
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22770 entries, 0 to 22769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22770 non-null  float64
#  1   Company Name       22769 non-null  str
#  2   Job Title          22770 non-null  str
#  3   Salary             22770 non-null  int64
#  4   Salaries Reported  22770 non-null  int64
#  5   Location           22770 non-null  str
#  6   Employment Status  22770 non-null  str
#  7   Job Roles          22770 non-null  str
# dtypes: float64(1), int64(2), str(5)
# memory usage: 1.4 MB

# %%
df.dtypes # muestra el tipo de dato de cada columna del DataFrame, es una forma más específica de ver los tipos de datos que tiene cada columna, como int64, float64, object, etc.
# Out:
# Rating               float64
# Company Name             str
# Job Title                str
# Salary                 int64
# Salaries Reported      int64
# Location                 str
# Employment Status        str
# Job Roles                str
# dtype: object

# %%
type(df.dtypes) # devuelve el tipo de dato de df.dtypes, que es una Serie, un objeto similar a un DataFrame pero con una sola columna y un índice, que en este caso es el nombre de las columnas del DataFrame original y los valores son los tipos de datos de cada columna.
# Out:
# pandas.Series

# %% [markdown]
# ### Formas de acceder al contenido del Dataframe

# %%
fila_cero=df.iloc[10] # devuelve la fila con índice 10 del DataFrame, es decir, la undécima fila, ya que el índice empieza en 0, y la guarda en la variable fila_cero
print(fila_cero)
# Out:
# Rating                             3.6
# Company Name             Craft Silicon
# Job Title            Android Developer
# Salary                          300000
# Salaries Reported                    3
# Location                     Bangalore
# Employment Status            Full Time
# Job Roles                      Android
# Name: 10, dtype: object

# %%
df.iloc[10:15] # devuelve las filas con índices del 10 al 14 del DataFrame, es decir, las filas 11 a 15, ya que el índice empieza en 0 y el rango no incluye el último número
# Out:
#     Rating            Company Name                   Job Title  Salary  \
# 10     3.6           Craft Silicon           Android Developer  300000
# 11     3.9  Baronford & Associates           Android Developer  240000
# 12     3.7                   Wibmo           Android Developer  900000
# 13     4.8            Retail Pulse  Android Developer - Intern   24000
# 14     3.9              Bookmyshow           Android Developer  600000
#
#     Salaries Reported   Location Employment Status Job Roles
# 10                  3  Bangalore         Full Time   Android
# 11                  2  Bangalore         Full Time   Android
# 12                  2  Bangalore         Full Time   Android
# 13                  2  Bangalore            Intern   Android
# 14                  2  Bangalore         Full Time   Android

# %%
df_filas_10a15=df.iloc[10:15] # guarda las filas con índices del 10 al 14 del DataFrame en la variable df_filas_10a15, que es un nuevo DataFrame con esas filas

df_filas_10a15.head() # muestra las primeras 5 filas del nuevo DataFrame df_filas_10a15, que en este caso son todas las filas que tiene, ya que tiene menos de 5 filas
# Out:
#     Rating            Company Name                   Job Title  Salary  \
# 10     3.6           Craft Silicon           Android Developer  300000
# 11     3.9  Baronford & Associates           Android Developer  240000
# 12     3.7                   Wibmo           Android Developer  900000
# 13     4.8            Retail Pulse  Android Developer - Intern   24000
# 14     3.9              Bookmyshow           Android Developer  600000
#
#     Salaries Reported   Location Employment Status Job Roles
# 10                  3  Bangalore         Full Time   Android
# 11                  2  Bangalore         Full Time   Android
# 12                  2  Bangalore         Full Time   Android
# 13                  2  Bangalore            Intern   Android
# 14                  2  Bangalore         Full Time   Android

# %%
df.iloc[10:15,[0,3]] # devuelve las filas con índices del 10 al 14 del DataFrame, es decir, las filas 11 a 15, y solo las columnas con índices 0 y 3, es decir, la primera y la cuarta columna, ya que el índice empieza en 0 y el rango no incluye el último número
# Out:
#     Rating  Salary
# 10     3.6  300000
# 11     3.9  240000
# 12     3.7  900000
# 13     4.8   24000
# 14     3.9  600000

# %%
df.iloc[10:15,[0,3]] # devuelve las filas con índices del 10 al 14 del DataFrame, es decir, las filas 11 a 15, y solo las columnas con índices 0 y 3, es decir, la primera y la cuarta columna, ya que el índice empieza en 0 y el rango no incluye el último número
# Out:
#     Rating  Salary
# 10     3.6  300000
# 11     3.9  240000
# 12     3.7  900000
# 13     4.8   24000
# 14     3.9  600000

# %%
df.iloc[10:15, 0:3] # devuelve las columnas 0,1,2
# Out:
#     Rating            Company Name                   Job Title
# 10     3.6           Craft Silicon           Android Developer
# 11     3.9  Baronford & Associates           Android Developer
# 12     3.7                   Wibmo           Android Developer
# 13     4.8            Retail Pulse  Android Developer - Intern
# 14     3.9              Bookmyshow           Android Developer

# %%
df["Rating"] # devuelve una Serie
# Out:
# 0        3.8
# 1        4.5
# 2        4.0
# 3        3.8
# 4        4.4
#         ...
# 22765    4.7
# 22766    4.0
# 22767    4.1
# 22768    4.1
# 22769    3.8
# Name: Rating, Length: 22770, dtype: float64

# %%
df[["Rating"]] # devuelve un DataFrame, con doble corchete se obtiene un DataFrame, con simple corchete se obtiene una Serie
# Out:
#        Rating
# 0         3.8
# 1         4.5
# 2         4.0
# 3         3.8
# 4         4.4
# ...       ...
# 22765     4.7
# 22766     4.0
# 22767     4.1
# 22768     4.1
# 22769     3.8
#
# [22770 rows x 1 columns]

# %%
type(df["Rating"]) # devuelve el tipo de dato de df["Rating"], que es una Serie, un objeto similar a un DataFrame pero con una sola columna y un índice, que en este caso es el mismo índice del DataFrame original y los valores son los datos de la columna "Rating"
# Out:
# pandas.Series

# %%
df_2_cols=df[["Rating","Salary"]] # devuelve un DataFrame con las columnas "Rating" y "Salary", con doble corchete se obtiene un DataFrame, con simple corchete se obtiene una Serie
df_2_cols
# Out:
# /home/alexballera/proyectos/educacion/datos/taller-tgad-fce/.venv/lib/python3.12/site-packages/IPython/core/displayhook.py:292: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
#        Rating   Salary
# 0         3.8   400000
# 1         4.5   400000
# 2         4.0  1000000
# 3         3.8   300000
# 4         4.4   600000
# ...       ...      ...
# 22765     4.7   200000
# 22766     4.0   300000
# 22767     4.1   192000
# 22768     4.1   300000
# 22769     3.8   300000
#
# [22770 rows x 2 columns]

# %%
type(df_2_cols) # devuelve el tipo de dato de df_2_cols, que es un DataFrame, un objeto bidimensional con filas y columnas, que en este caso tiene las columnas "Rating" y "Salary" y el mismo índice que el DataFrame original
# Out:
# pandas.DataFrame

# %%
type(df[["Rating"]]) # devuelve el tipo de dato de df[["Rating"]], que es un DataFrame, un objeto bidimensional con filas y columnas, que en este caso tiene la columna "Rating" y el mismo índice que el DataFrame original
# Out:
# pandas.DataFrame

# %%
df.Rating # devuelve una Serie con los datos de la columna "Rating", es otra forma de acceder a una columna del DataFrame, pero solo funciona si el nombre de la columna no tiene espacios ni caracteres especiales y no coincide con ningún método o atributo del DataFrame, por eso es recomendable usar siempre la sintaxis df["columna"] para evitar confusiones y errores.
# Out:
# 0        3.8
# 1        4.5
# 2        4.0
# 3        3.8
# 4        4.4
#         ...
# 22765    4.7
# 22766    4.0
# 22767    4.1
# 22768    4.1
# 22769    3.8
# Name: Rating, Length: 22770, dtype: float64

# %%
df.loc[:,"Rating"] # devuelve una Serie con los datos de la columna "Rating", es otra forma de acceder a una columna del DataFrame usando el método loc, que permite seleccionar filas y columnas por etiquetas, en este caso se seleccionan todas las filas (:) y solo la columna "Rating" (:"Rating")
# Out:
# 0        3.8
# 1        4.5
# 2        4.0
# 3        3.8
# 4        4.4
#         ...
# 22765    4.7
# 22766    4.0
# 22767    4.1
# 22768    4.1
# 22769    3.8
# Name: Rating, Length: 22770, dtype: float64

# %%
df.loc[:,["Rating","Company Name"]] # devuelve un DataFrame con las columnas "Rating" y "Company Name", es otra forma de acceder a varias columnas del DataFrame usando el método loc, que permite seleccionar filas y columnas por etiquetas, en este caso se seleccionan todas las filas (:) y solo las columnas "Rating" y "Company Name" (:"Rating","Company Name")
# Out:
#        Rating                      Company Name
# 0         3.8                            Sasken
# 1         4.5  Advanced Millennium Technologies
# 2         4.0                         Unacademy
# 3         3.8                SnapBizz Cloudtech
# 4         4.4            Appoids Tech Solutions
# ...       ...                               ...
# 22765     4.7                  Expert Solutions
# 22766     4.0           Nextgen Innovation Labs
# 22767     4.1                           Fresher
# 22768     4.1                         Accenture
# 22769     3.8                   Thomson Reuters
#
# [22770 rows x 2 columns]

# %%
df_2=df.loc[:,["Rating","Company Name"]] # guarda un nuevo DataFrame con las columnas "Rating" y "Company Name" usando el método loc, que permite seleccionar filas y columnas por etiquetas, en este caso se seleccionan todas las filas (:) y solo las columnas "Rating" y "Company Name" (:"Rating","Company Name")

df_2.head()
# Out:
#    Rating                      Company Name
# 0     3.8                            Sasken
# 1     4.5  Advanced Millennium Technologies
# 2     4.0                         Unacademy
# 3     3.8                SnapBizz Cloudtech
# 4     4.4            Appoids Tech Solutions

# %%
df[["Rating","Company Name"]] # devuelve un DataFrame con las columnas "Rating" y "Company Name", es otra forma de acceder a varias columnas del DataFrame usando la sintaxis de doble corchete, que permite seleccionar varias columnas por su nombre, en este caso se seleccionan las columnas "Rating" y "Company Name"
# Out:
#        Rating                      Company Name
# 0         3.8                            Sasken
# 1         4.5  Advanced Millennium Technologies
# 2         4.0                         Unacademy
# 3         3.8                SnapBizz Cloudtech
# 4         4.4            Appoids Tech Solutions
# ...       ...                               ...
# 22765     4.7                  Expert Solutions
# 22766     4.0           Nextgen Innovation Labs
# 22767     4.1                           Fresher
# 22768     4.1                         Accenture
# 22769     3.8                   Thomson Reuters
#
# [22770 rows x 2 columns]

# %%
df["Job Title"] == "Android Developer" # devuelve una Serie de valores booleanos (True o False) indicando si cada fila del DataFrame cumple la condición de que la columna "Job Title" sea igual a "Android Developer"
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 22765    False
# 22766    False
# 22767    False
# 22768    False
# 22769    False
# Name: Job Title, Length: 22770, dtype: bool

# %%
type(df["Job Title"]=="Android Developer") # devuelve el tipo de dato de df["Job Title"]=="Android Developer", que es una Serie, un objeto similar a un DataFrame pero con una sola columna y un índice, que en este caso es el mismo índice del DataFrame original y los valores son True o False dependiendo de si cada fila cumple la condición de que la columna "Job Title" sea igual a "Android Developer"
# Out:
# pandas.Series

# %%
df[ df["Job Title"]=="Android Developer" ] # devuelve un DataFrame con las filas del DataFrame original que cumplen la condición de que la columna "Job Title" sea igual a "Android Developer", es decir, solo las filas donde el título del trabajo es "Android Developer". Esto se hace usando la sintaxis de filtrado, donde se coloca la condición entre corchetes después del nombre del DataFrame, y solo se seleccionan las filas que cumplen esa condición.
# Out:
#       Rating                            Company Name          Job Title  \
# 0        3.8                                  Sasken  Android Developer
# 1        4.5        Advanced Millennium Technologies  Android Developer
# 2        4.0                               Unacademy  Android Developer
# 3        3.8                      SnapBizz Cloudtech  Android Developer
# 4        4.4                  Appoids Tech Solutions  Android Developer
# ...      ...                                     ...                ...
# 2916     4.5                              Grupo FREL  Android Developer
# 2917     3.5                       Pioneer Infoworld  Android Developer
# 2918     3.8  Accurate Innovative Business Solutions  Android Developer
# 2919     3.8                      Massmatic Solution  Android Developer
# 2920     3.8                       Yobiting Infotech  Android Developer
#
#        Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
mascara1=df["Job Title"]=="Android Developer" # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Job Title" sea igual a "Android Developer" en la variable mascara1, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.

df_filtro1=df[mascara1]

df_filtro1
# Out:
#       Rating                            Company Name          Job Title  \
# 0        3.8                                  Sasken  Android Developer
# 1        4.5        Advanced Millennium Technologies  Android Developer
# 2        4.0                               Unacademy  Android Developer
# 3        3.8                      SnapBizz Cloudtech  Android Developer
# 4        4.4                  Appoids Tech Solutions  Android Developer
# ...      ...                                     ...                ...
# 2916     4.5                              Grupo FREL  Android Developer
# 2917     3.5                       Pioneer Infoworld  Android Developer
# 2918     3.8  Accurate Innovative Business Solutions  Android Developer
# 2919     3.8                      Massmatic Solution  Android Developer
# 2920     3.8                       Yobiting Infotech  Android Developer
#
#        Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df_filtro1.shape # devuelve una tupla con el número de filas y columnas del DataFrame df_filtro1, que es el resultado de filtrar el DataFrame original por la condición de que la columna "Job Title" sea igual a "Android Developer". En este caso, devuelve (10, 11), lo que significa que hay 10 filas y 11 columnas en el DataFrame filtrado.
# Out:
# (2029, 8)

# %%
df.loc[ df["Job Title"]=="Android Developer" ,["Rating","Company Name"] ] # devuelve un DataFrame con las filas del DataFrame original que cumplen la condición de que la columna "Job Title" sea igual a "Android Developer", es decir, solo las filas donde el título del trabajo es "Android Developer", y solo las columnas "Rating" y "Company Name". Esto se hace usando el método loc, que permite seleccionar filas y columnas por etiquetas, donde se coloca la condición de filtrado en la parte de las filas (antes de la coma) y las columnas que se quieren seleccionar en la parte de las columnas (después de la coma).
# Out:
#       Rating                            Company Name
# 0        3.8                                  Sasken
# 1        4.5        Advanced Millennium Technologies
# 2        4.0                               Unacademy
# 3        3.8                      SnapBizz Cloudtech
# 4        4.4                  Appoids Tech Solutions
# ...      ...                                     ...
# 2916     4.5                              Grupo FREL
# 2917     3.5                       Pioneer Infoworld
# 2918     3.8  Accurate Innovative Business Solutions
# 2919     3.8                      Massmatic Solution
# 2920     3.8                       Yobiting Infotech
#
# [2029 rows x 2 columns]

# %%
df["Job Title"]=="Android Developer" # devuelve una Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Job Title" sea igual a "Android Developer".
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 22765    False
# 22766    False
# 22767    False
# 22768    False
# 22769    False
# Name: Job Title, Length: 22770, dtype: bool

# %%
cond1=df["Job Title"]=="Android Developer" # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Job Title" sea igual a "Android Developer" en la variable cond1, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.
cond2=df["Salary"]>1000000 # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Salary" sea mayor a 1000000 en la variable cond2, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.

cond_simultaneas=cond1 & cond2

cond_simultaneas
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 22765    False
# 22766    False
# 22767    False
# 22768    False
# 22769    False
# Length: 22770, dtype: bool

# %%
cond1=df["Job Title"]=="Android Developer" # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Job Title" sea igual a "Android Developer" en la variable cond1, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.
cond2=df["Salary"]>1000000 # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Salary" sea mayor a 1000000 en la variable cond2, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.

df[ cond1 & cond2 ]
# Out:
#       Rating                 Company Name          Job Title   Salary  \
# 82       4.3             Ashwin Infotrron  Android Developer  1188000
# 96       4.1                        Dunzo  Android Developer  2800000
# 99       4.0                 Grab (India)  Android Developer  1200000
# 106      4.0          Walmart Global Tech  Android Developer  2300000
# 136      4.0                     Deloitte  Android Developer  1200000
# ...      ...                          ...                ...      ...
# 2715     3.6  Athena Consultancy Services  Android Developer  1400000
# 2731     2.4                       MobiTV  Android Developer  1188000
# 2803     2.5                        Swipe  Android Developer  2500000
# 2852     3.8                     UxExpert  Android Developer  1044000
# 2856     4.0                   Hungryybee  Android Developer  1188000
#
#       Salaries Reported   Location Employment Status Job Roles
# 82                    1  Bangalore         Full Time   Android
# ...

# %%
df[cond_simultaneas] # devuelve un DataFrame con las filas del DataFrame original que cumplen simultáneamente las condiciones de que la columna "Job Title" sea igual a "Android Developer" y la columna "Salary" sea mayor a 1000000.
# Out:
#       Rating                 Company Name          Job Title   Salary  \
# 82       4.3             Ashwin Infotrron  Android Developer  1188000
# 96       4.1                        Dunzo  Android Developer  2800000
# 99       4.0                 Grab (India)  Android Developer  1200000
# 106      4.0          Walmart Global Tech  Android Developer  2300000
# 136      4.0                     Deloitte  Android Developer  1200000
# ...      ...                          ...                ...      ...
# 2715     3.6  Athena Consultancy Services  Android Developer  1400000
# 2731     2.4                       MobiTV  Android Developer  1188000
# 2803     2.5                        Swipe  Android Developer  2500000
# 2852     3.8                     UxExpert  Android Developer  1044000
# 2856     4.0                   Hungryybee  Android Developer  1188000
#
#       Salaries Reported   Location Employment Status Job Roles
# 82                    1  Bangalore         Full Time   Android
# ...

# %%
cond1=df["Job Title"]=="Android Developer" # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Job Title" sea igual a "Android Developer" en la variable cond1, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.
cond2=df["Salary"]>1000000 # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Salary" sea mayor a 1000000 en la variable cond2, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.
cond3=df["Rating"]<=2.5 # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Rating" sea menor o igual a 2.5 en la variable cond3, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.

df[ cond1 & cond2 & cond3 ] # devuelve un DataFrame con las filas del DataFrame original que cumplen simultáneamente las condiciones de que la columna "Job Title" sea igual a "Android Developer", la columna "Salary" sea mayor a 1000000 y la columna "Rating" sea menor o igual a 2.5.
# Out:
#       Rating Company Name          Job Title   Salary  Salaries Reported  \
# 2731     2.4       MobiTV  Android Developer  1188000                  1
# 2803     2.5        Swipe  Android Developer  2500000                  1
#
#      Location Employment Status Job Roles
# 2731     Pune         Full Time   Android
# 2803     Pune         Full Time   Android

# %%
cond1=df["Job Title"]=="Android Developer" # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Job Title" sea igual a "Android Developer" en la variable cond1, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.
cond2=df["Salary"]>1000000 # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Salary" sea mayor a 1000000 en la variable cond2, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.

df[ cond1 | cond2 ] # devuelve un DataFrame con las filas del DataFrame original que cumplen al menos una de las condiciones de que la columna "Job Title" sea igual a "Android Developer" o la columna "Salary" sea mayor a 1000000, es decir, se seleccionan las filas donde el título del trabajo es "Android Developer", o las filas donde el salario es mayor a 1000000, o ambas condiciones se cumplen. Esto se hace usando el operador | para indicar que se deben cumplir al menos una de las condiciones.
# Out:
#        Rating                                Company Name  \
# 0         3.8                                      Sasken
# 1         4.5            Advanced Millennium Technologies
# 2         4.0                                   Unacademy
# 3         3.8                          SnapBizz Cloudtech
# 4         4.4                      Appoids Tech Solutions
# ...       ...                                         ...
# 22675     4.1         Chethan's Charters- GD FEA Employer
# 22681     4.0                                 Alex mercer
# 22699     3.8                                       Wipro
# 22707     4.6                 Regal Software Technologies
# 22748     4.2  Full Time Soluções em Serviços Financeiros
#
#                         Job Title   Salary  Salaries Reported   Location  \
# 0               Android Developer   400000                  3  Bangalore
# 1               Android Developer   400000                  3  Bangalore
# ...

# %%
cond1=df["Job Title"]=="Android Developer" # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Job Title" sea igual a "Android Developer" en la variable cond1, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.
cond2=df["Salary"]>1000000 # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Salary" sea mayor a 1000000 en la variable cond2, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.
cond3=df["Rating"]<=2.5 # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Rating" sea menor o igual a 2.5 en la variable cond3, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.

cond4= (cond1 | cond2) & cond3 # combina las condiciones usando operadores lógicos: se seleccionan las filas donde se cumple al menos una de las condiciones cond1 o cond2, y además se cumple la condición cond3.

df[ cond4 ] # devuelve un DataFrame con las filas del DataFrame original que cumplen la combinación de condiciones especificada en cond4.
# Out:
#        Rating              Company Name                            Job Title  \
# 42        1.0                   Pricyfy                    Android Developer
# 140       2.4        Chromozome Network                    Android Developer
# 147       2.2           ZINOHA PHARMACY                    Android Developer
# 199       2.4               Travelyaari       Android Developer - Contractor
# 217       1.8         Prowide Solutions                    Android Developer
# ...       ...                       ...                                  ...
# 18302     2.4    Toronto Board of Trade  Software Development Engineer (SDE)
# 18558     1.7      A.K.Jha & Associates  Software Development Engineer (SDE)
# 19217     1.0                     ZEVEX      Software Development Engineer I
# 19369     1.3  Coozo Creative Solutions  Software Development Engineer (SDE)
# 21700     2.5       Bosal International                        Test Engineer
#
# ...

# %%
df.to_csv("filtro1.csv",sep=";",index=False) # guarda el DataFrame df en un archivo CSV llamado "filtro1.csv", usando el punto y coma (;) como separador de campos, y sin incluir el índice del DataFrame en el archivo. Esto se hace usando el método to_csv, que permite exportar un DataFrame a un archivo CSV con diferentes opciones de formato.

# %%
cond1=df["Job Title"]=="Android Developer" # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Job Title" sea igual a "Android Developer" en la variable cond1, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.
cond2=df["Salary"]>1000000 # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Salary" sea mayor a 1000000 en la variable cond2, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.

df.loc[cond1 & cond2,["Rating","Company Name"] ] # devuelve un DataFrame con las filas del DataFrame original que cumplen ambas condiciones cond1 y cond2, y solo muestra las columnas "Rating" y "Company Name".
# Out:
#       Rating                 Company Name
# 82       4.3             Ashwin Infotrron
# 96       4.1                        Dunzo
# 99       4.0                 Grab (India)
# 106      4.0          Walmart Global Tech
# 136      4.0                     Deloitte
# ...      ...                          ...
# 2715     3.6  Athena Consultancy Services
# 2731     2.4                       MobiTV
# 2803     2.5                        Swipe
# 2852     3.8                     UxExpert
# 2856     4.0                   Hungryybee
#
# [153 rows x 2 columns]

# %% [markdown]
# ### Medidas de resumen

# %%
df.describe() # devuelve un resumen estadístico de las columnas numéricas del DataFrame, incluyendo la cantidad de valores no nulos, la media, la desviación estándar, el valor mínimo, los percentiles 25, 50 y 75, y el valor máximo. Esto es útil para obtener una visión general de la distribución de los datos en esas columnas.
# Out:
#              Rating        Salary  Salaries Reported
# count  22770.000000  2.277000e+04       22770.000000
# mean       3.918213  6.953872e+05           1.855775
# std        0.519675  8.843990e+05           6.823668
# min        1.000000  2.112000e+03           1.000000
# 25%        3.700000  3.000000e+05           1.000000
# 50%        3.900000  5.000000e+05           1.000000
# 75%        4.200000  9.000000e+05           1.000000
# max        5.000000  9.000000e+07         361.000000

# %%
df[ ["Rating"] ].describe() # devuelve un resumen estadístico de la columna "Rating" del DataFrame, incluyendo la cantidad de valores no nulos, la media, la desviación estándar, el valor mínimo, los percentiles 25, 50 y 75, y el valor máximo. Esto es útil para obtener una visión general de la distribución de los datos en esa columna específica. Se usa la sintaxis de doble corchete para obtener un DataFrame con una sola columna, lo que permite usar el método describe() para obtener el resumen estadístico.
# Out:
#              Rating
# count  22770.000000
# mean       3.918213
# std        0.519675
# min        1.000000
# 25%        3.700000
# 50%        3.900000
# 75%        4.200000
# max        5.000000

# %%
type( df[["Rating"]].describe() ) # devuelve el tipo de dato de df[["Rating"]].describe(), que es un DataFrame, un objeto bidimensional con filas y columnas, que en este caso tiene la columna "Rating" y el mismo índice que el DataFrame original, pero con los valores correspondientes al resumen estadístico
# Out:
# pandas.DataFrame

# %%
df[["Salary"]].describe().loc["min", "Salary"] # devuelve el valor mínimo de la columna "Salary" del resumen estadístico obtenido con describe(), accediendo a la fila "min" y a la columna "Salary" del DataFrame resultante. Esto es útil para obtener el valor mínimo de esa columna específica.
# Out:
# np.float64(2112.0)

# %%
df["Salary"].min() # devuelve el valor mínimo de la columna "Salary" del DataFrame, es una forma más directa de obtener el valor mínimo de esa columna específica sin necesidad de usar describe() y loc.
# Out:
# np.int64(2112)

# %%
salario_minimo=df["Salary"].min() # guarda el valor mínimo de la columna "Salary" del DataFrame en la variable salario_minimo, que es un número que representa el salario mínimo registrado en esa columna.

print("El salario mínimo es: $",salario_minimo)
# Out:
# El salario mínimo es: $ 2112

# %%
df["Salary"].max() # devuelve el valor máximo de la columna "Salary" del DataFrame, es una forma más directa de obtener el valor máximo de esa columna específica sin necesidad de usar describe() y loc.
# Out:
# np.int64(90000000)

# %%
df["Salary"].mean() # devuelve la media aritmética de los valores de la columna "Salary" del DataFrame, es decir, la suma de todos los valores dividida por la cantidad de valores no nulos en esa columna. Esto es útil para obtener una medida de tendencia central de los datos en esa columna específica.
# Out:
# np.float64(695387.2112428634)

# %%
df["Salary"].std() # devuelve la desviación estándar de los valores de la columna "Salary" del DataFrame, que es una medida de dispersión que indica cuánto se alejan los valores de esa columna respecto a su media. Esto es útil para entender la variabilidad de los datos en esa columna específica.
# Out:
# np.float64(884399.0136761833)

# %%
df["Salary"].median() # devuelve la mediana de los valores de la columna "Salary" del DataFrame, que es el valor que se encuentra en el medio de los datos ordenados de menor a mayor. Si hay una cantidad par de valores, devuelve el promedio de los dos valores centrales. Esto es útil para obtener una medida de tendencia central que no se vea afectada por valores extremos o atípicos en esa columna específica.
# Out:
# np.float64(500000.0)

# %%
df["Salary"].mode() # devuelve la moda de los valores de la columna "Salary" del DataFrame, que es el valor o los valores que se repiten con mayor frecuencia en esa columna. Si hay un solo valor que se repite más veces, devuelve una Serie con ese valor. Si hay varios valores que se repiten con la misma frecuencia máxima, devuelve una Serie con todos esos valores. Esto es útil para obtener una medida de tendencia central que representa el valor más común en esa columna específica.
# Out:
# 0    300000
# Name: Salary, dtype: int64

# %%
df["Salary"].quantile(0.1) # devuelve el percentil 10 de los valores de la columna "Salary" del DataFrame, que es el valor por debajo del cual se encuentra el 10% de los datos en esa columna. Esto es útil para entender la distribución de los datos y detectar posibles valores atípicos o extremos en esa columna específica.
# Out:
# np.float64(180000.0)

# %%
df[["Salary"]].agg(["min","max","mean","median"]) # devuelve un DataFrame con las estadísticas agregadas de la columna "Salary" del DataFrame, incluyendo el valor mínimo, el valor máximo, la media y la mediana. Esto se hace usando el método agg, que permite aplicar varias funciones de agregación a una columna o a varias columnas, y devuelve un DataFrame con los resultados de esas funciones. En este caso, se aplican las funciones min, max, mean y median a la columna "Salary".
# Out:
#               Salary
# min     2.112000e+03
# max     9.000000e+07
# mean    6.953872e+05
# median  5.000000e+05

# %% [markdown]
# Cambiar nombre a una columna

# %%
columnas={"Company Name":"Company_Name","Job Title":"Job_Title","Salaries Reported":"Salaries_Reported"}

df_rename_cols=df.rename(columns = columnas) # devuelve un nuevo DataFrame con las columnas renombradas según el diccionario columnas, donde las claves son los nombres originales de las columnas y los valores son los nuevos nombres que se quieren asignar. En este caso, se renombraron las columnas "Company Name" a "Company_Name", "Job Title" a "Job_Title" y "Salaries Reported" a "Salaries_Reported". El DataFrame original df no se modifica, sino que se crea un nuevo DataFrame df_rename_cols con los cambios de nombre.
df_rename_cols.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries_Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
columnas={"Company Name":"Company_Name","Job Title":"Job_Title","Salaries Reported":"Salaries_Reported"}
df.rename(columns = columnas, inplace = True) # renombra las columnas del DataFrame df según el diccionario columnas, donde las claves son los nombres originales de las columnas y los valores son los nuevos nombres que se quieren asignar. En este caso, se renombraron las columnas "Company Name" a "Company_Name", "Job Title" a "Job_Title" y "Salaries Reported" a "Salaries_Reported". El parámetro inplace=True indica que el cambio de nombre se realiza en el mismo DataFrame df, sin necesidad de crear un nuevo DataFrame.
df.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries_Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %% [markdown]
# Eliminar columnas o filas

# %%
df.drop("Salaries_Reported", axis="columns", inplace=True) # elimina la columna "Salaries_Reported" del DataFrame df, usando el método drop, donde se especifica el nombre de la columna a eliminar, el eje (axis) que indica que se trata de una columna y no de una fila, y el parámetro inplace=True que indica que el cambio se realiza en el mismo DataFrame df, sin necesidad de crear un nuevo DataFrame.

# %%
df2 = df.drop(columns=["Salaries_Reported"], errors="ignore") # devuelve un nuevo DataFrame df2 que es el resultado de eliminar la columna "Salaries_Reported" del DataFrame df, usando el método drop con la opción columns para indicar que se trata de una columna, y la opción errors="ignore" para evitar que se genere un error si la columna a eliminar no existe en el DataFrame. En este caso, como ya se eliminó la columna "Salaries_Reported" en el paso anterior, esta línea no genera ningún cambio en el DataFrame df2, que es igual al DataFrame df sin esa columna.
df2.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#     Location Employment Status Job Roles
# 0  Bangalore         Full Time   Android
# 1  Bangalore         Full Time   Android
# 2  Bangalore         Full Time   Android
# 3  Bangalore         Full Time   Android
# 4  Bangalore         Full Time   Android

# %%
df.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#     Location Employment Status Job Roles
# 0  Bangalore         Full Time   Android
# 1  Bangalore         Full Time   Android
# 2  Bangalore         Full Time   Android
# 3  Bangalore         Full Time   Android
# 4  Bangalore         Full Time   Android

# %%
df = df.drop(columns=["Salaries_Reported", "Rating"], errors="ignore") # elimina las columnas "Salaries_Reported" y "Rating" del DataFrame df, usando el método drop con la opción columns para indicar que se trata de columnas, y la opción errors="ignore" para evitar que se genere un error si alguna de las columnas a eliminar no existe en el DataFrame. En este caso, como ya se eliminó la columna "Salaries_Reported" en el paso anterior, esta línea solo elimina la columna "Rating" del DataFrame df, y el resultado se guarda en el mismo DataFrame df.
df.head()
# Out:
#                        Company_Name          Job_Title   Salary   Location  \
# 0                            Sasken  Android Developer   400000  Bangalore
# 1  Advanced Millennium Technologies  Android Developer   400000  Bangalore
# 2                         Unacademy  Android Developer  1000000  Bangalore
# 3                SnapBizz Cloudtech  Android Developer   300000  Bangalore
# 4            Appoids Tech Solutions  Android Developer   600000  Bangalore
#
#   Employment Status Job Roles
# 0         Full Time   Android
# 1         Full Time   Android
# 2         Full Time   Android
# 3         Full Time   Android
# 4         Full Time   Android

# %%
df.head()
# Out:
#                        Company_Name          Job_Title   Salary   Location  \
# 0                            Sasken  Android Developer   400000  Bangalore
# 1  Advanced Millennium Technologies  Android Developer   400000  Bangalore
# 2                         Unacademy  Android Developer  1000000  Bangalore
# 3                SnapBizz Cloudtech  Android Developer   300000  Bangalore
# 4            Appoids Tech Solutions  Android Developer   600000  Bangalore
#
#   Employment Status Job Roles
# 0         Full Time   Android
# 1         Full Time   Android
# 2         Full Time   Android
# 3         Full Time   Android
# 4         Full Time   Android

# %%
df_sin_fila0=df.drop(0) # devuelve un nuevo DataFrame df_sin_fila0 que es el resultado de eliminar la fila con índice 0 del DataFrame df, usando el método drop sin especificar el eje (axis), lo que por defecto se interpreta como filas. Esto significa que se elimina la primera fila del DataFrame, que tiene el índice 0, y el resultado se guarda en un nuevo DataFrame df_sin_fila0. El DataFrame original df no se modifica, sino que se crea un nuevo DataFrame df_sin_fila0 con esa fila eliminada.
df_sin_fila0.head()
# Out:
#                        Company_Name          Job_Title   Salary   Location  \
# 1  Advanced Millennium Technologies  Android Developer   400000  Bangalore
# 2                         Unacademy  Android Developer  1000000  Bangalore
# 3                SnapBizz Cloudtech  Android Developer   300000  Bangalore
# 4            Appoids Tech Solutions  Android Developer   600000  Bangalore
# 5                        Freelancer  Android Developer   100000  Bangalore
#
#   Employment Status Job Roles
# 1         Full Time   Android
# 2         Full Time   Android
# 3         Full Time   Android
# 4         Full Time   Android
# 5         Full Time   Android

# %%
df.head(10)
# Out:
#                               Company_Name          Job_Title   Salary  \
# 0                                   Sasken  Android Developer   400000
# 1         Advanced Millennium Technologies  Android Developer   400000
# 2                                Unacademy  Android Developer  1000000
# 3                       SnapBizz Cloudtech  Android Developer   300000
# 4                   Appoids Tech Solutions  Android Developer   600000
# 5                               Freelancer  Android Developer   100000
# 6                            SQUARE N CUBE  Android Developer   192000
# 7  Samsung R&D Institute India - Bangalore  Android Developer   400000
# 8                     DXMinds Technologies  Android Developer   300000
# 9          Endeavour Software Technologies  Android Developer   600000
#
#     Location Employment Status Job Roles
# 0  Bangalore         Full Time   Android
# 1  Bangalore         Full Time   Android
# 2  Bangalore         Full Time   Android
# ...

# %%
df.drop(8,inplace=True) # elimina la fila con índice 8 del DataFrame df, usando el método drop sin especificar el eje (axis), lo que por defecto se interpreta como filas. Esto significa que se elimina la fila con índice 8 del DataFrame, y el cambio se realiza en el mismo DataFrame df, sin necesidad de crear un nuevo DataFrame.
df.head(10)
# Out:
#                                Company_Name          Job_Title   Salary  \
# 0                                    Sasken  Android Developer   400000
# 1          Advanced Millennium Technologies  Android Developer   400000
# 2                                 Unacademy  Android Developer  1000000
# 3                        SnapBizz Cloudtech  Android Developer   300000
# 4                    Appoids Tech Solutions  Android Developer   600000
# 5                                Freelancer  Android Developer   100000
# 6                             SQUARE N CUBE  Android Developer   192000
# 7   Samsung R&D Institute India - Bangalore  Android Developer   400000
# 9           Endeavour Software Technologies  Android Developer   600000
# 10                            Craft Silicon  Android Developer   300000
#
#      Location Employment Status Job Roles
# 0   Bangalore         Full Time   Android
# 1   Bangalore         Full Time   Android
# 2   Bangalore         Full Time   Android
# ...

# %%
df.drop([0,1,2,3]) # devuelve un nuevo DataFrame que es el resultado de eliminar las filas con índices 0, 1, 2 y 3 del DataFrame df, usando el método drop sin especificar el eje (axis), lo que por defecto se interpreta como filas. Esto significa que se eliminan las filas con esos índices del DataFrame, y el resultado se guarda en un nuevo DataFrame. El DataFrame original df no se modifica, sino que se crea un nuevo DataFrame con esas filas eliminadas.
# Out:
#                                   Company_Name                 Job_Title  \
# 4                       Appoids Tech Solutions         Android Developer
# 5                                   Freelancer         Android Developer
# 6                                SQUARE N CUBE         Android Developer
# 7      Samsung R&D Institute India - Bangalore         Android Developer
# 9              Endeavour Software Technologies         Android Developer
# ...                                        ...                       ...
# 22765                         Expert Solutions             Web Developer
# 22766                  Nextgen Innovation Labs             Web Developer
# 22767                                  Fresher  Full Stack Web Developer
# 22768                                Accenture  Full Stack Web Developer
# 22769                          Thomson Reuters   Associate Web Developer
#
#        Salary   Location Employment Status Job Roles
# ...

# %%
df[0:3].index # devuelve el índice de las filas con índices del 0 al 2 del DataFrame df, es decir, las filas 1 a 3, ya que el índice empieza en 0 y el rango no incluye el último número. Esto muestra los índices de esas filas específicas del DataFrame.
# Out:
# Index([0, 1, 2], dtype='int64')

# %%
df.drop( df[0:3].index ) # devuelve un nuevo DataFrame que es el resultado de eliminar las filas con índices del 0 al 2 del DataFrame df, usando el método drop y pasando como argumento el índice de esas filas obtenido con df[0:3].index. Esto significa que se eliminan las filas con esos índices del DataFrame, y el resultado se guarda en un nuevo DataFrame. El DataFrame original df no se modifica, sino que se crea un nuevo DataFrame con esas filas eliminadas.
# Out:
#                                   Company_Name                 Job_Title  \
# 3                           SnapBizz Cloudtech         Android Developer
# 4                       Appoids Tech Solutions         Android Developer
# 5                                   Freelancer         Android Developer
# 6                                SQUARE N CUBE         Android Developer
# 7      Samsung R&D Institute India - Bangalore         Android Developer
# ...                                        ...                       ...
# 22765                         Expert Solutions             Web Developer
# 22766                  Nextgen Innovation Labs             Web Developer
# 22767                                  Fresher  Full Stack Web Developer
# 22768                                Accenture  Full Stack Web Developer
# 22769                          Thomson Reuters   Associate Web Developer
#
#        Salary   Location Employment Status Job Roles
# ...

# %%
df.drop( [0,1,2,3] ) # devuelve un nuevo DataFrame que es el resultado de eliminar las filas con índices 0, 1, 2 y 3 del DataFrame df, usando el método drop sin especificar el eje (axis), lo que por defecto se interpreta como filas. Esto significa que se eliminan las filas con esos índices del DataFrame, y el resultado se guarda en un nuevo DataFrame. El DataFrame original df no se modifica, sino que se crea un nuevo DataFrame con esas filas eliminadas.
# Out:
#                                   Company_Name                 Job_Title  \
# 4                       Appoids Tech Solutions         Android Developer
# 5                                   Freelancer         Android Developer
# 6                                SQUARE N CUBE         Android Developer
# 7      Samsung R&D Institute India - Bangalore         Android Developer
# 9              Endeavour Software Technologies         Android Developer
# ...                                        ...                       ...
# 22765                         Expert Solutions             Web Developer
# 22766                  Nextgen Innovation Labs             Web Developer
# 22767                                  Fresher  Full Stack Web Developer
# 22768                                Accenture  Full Stack Web Developer
# 22769                          Thomson Reuters   Associate Web Developer
#
#        Salary   Location Employment Status Job Roles
# ...

# %%
df[df["Job_Title"]=="Android Developer"] # devuelve un DataFrame con las filas del DataFrame original que cumplen la condición de que la columna "Job_Title" sea igual a "Android Developer", es decir, solo las filas donde el título del trabajo es "Android Developer". Esto se hace usando la sintaxis de filtrado, donde se coloca la condición entre corchetes después del nombre del DataFrame, y solo se seleccionan las filas que cumplen esa condición.
# Out:
#                                 Company_Name          Job_Title   Salary  \
# 0                                     Sasken  Android Developer   400000
# 1           Advanced Millennium Technologies  Android Developer   400000
# 2                                  Unacademy  Android Developer  1000000
# 3                         SnapBizz Cloudtech  Android Developer   300000
# 4                     Appoids Tech Solutions  Android Developer   600000
# ...                                      ...                ...      ...
# 2916                              Grupo FREL  Android Developer   400000
# 2917                       Pioneer Infoworld  Android Developer   156000
# 2918  Accurate Innovative Business Solutions  Android Developer   500000
# 2919                      Massmatic Solution  Android Developer   264000
# 2920                       Yobiting Infotech  Android Developer   180000
#
#        Location Employment Status Job Roles
# 0     Bangalore         Full Time   Android
# ...

# %%
df[df["Job_Title"]=="Android Developer"].index # devuelve el índice de las filas del DataFrame original que cumplen la condición de que la columna "Job_Title" sea igual a "Android Developer", es decir, solo las filas donde el título del trabajo es "Android Developer". Esto muestra los índices de esas filas específicas del DataFrame.
# Out:
# Index([   0,    1,    2,    3,    4,    5,    6,    7,    9,   10,
#        ...
#        2911, 2912, 2913, 2914, 2915, 2916, 2917, 2918, 2919, 2920],
#       dtype='int64', length=2028)

# %%
df.drop( df[df["Job_Title"]=="Android Developer"].index ) # devuelve un nuevo DataFrame que es el resultado de eliminar las filas del DataFrame original que cumplen la condición de que la columna "Job_Title" sea igual a "Android Developer", es decir, solo las filas donde el título del trabajo es "Android Developer". Esto se hace usando el método drop y pasando como argumento el índice de esas filas obtenido con df[df["Job_Title"]=="Android Developer"].index. Esto significa que se eliminan las filas con esos índices del DataFrame, y el resultado se guarda en un nuevo DataFrame. El DataFrame original df no se modifica, sino que se crea un nuevo DataFrame con esas filas eliminadas.
# Out:
#                   Company_Name                   Job_Title  Salary   Location  \
# 13                Retail Pulse  Android Developer - Intern   24000  Bangalore
# 30               powerplay app  Android Developer - Intern  396000  Bangalore
# 54                  GreedyGame  Android Developer - Intern  348000  Bangalore
# 62                      Dcoder  Android Developer - Intern   96000  Bangalore
# 66            Across The Globe  Android Developer - Intern   72000  Bangalore
# ...                        ...                         ...     ...        ...
# 22765         Expert Solutions               Web Developer  200000  Bangalore
# 22766  Nextgen Innovation Labs               Web Developer  300000  Bangalore
# 22767                  Fresher    Full Stack Web Developer  192000  Bangalore
# 22768                Accenture    Full Stack Web Developer  300000  Bangalore
# 22769          Thomson Reuters     Associate Web Developer  300000  Bangalore
#
# ...

# %%
cond1=df["Job_Title"]=="Android Developer" # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Job_Title" sea igual a "Android Developer" en la variable cond1, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.
cond2=df["Salary"]<30000 # guarda la Serie de valores booleanos que indica si cada fila del DataFrame cumple la condición de que la columna "Salary" sea menor a 30000 en la variable cond2, que es una Serie con el mismo índice que el DataFrame original y valores True o False dependiendo de si cada fila cumple esa condición.

indices_drop=df[cond1 & cond2].index # obtiene los índices de las filas que cumplen ambas condiciones, es decir, donde el título del trabajo es "Android Developer" y el salario es menor a 30000.

df.drop( indices_drop ) # devuelve un nuevo DataFrame que es el resultado de eliminar las filas del DataFrame original que cumplen ambas condiciones. El DataFrame original df no se modifica, sino que se crea un nuevo DataFrame con esas filas eliminadas.
# Out:
#                            Company_Name                 Job_Title   Salary  \
# 0                                Sasken         Android Developer   400000
# 1      Advanced Millennium Technologies         Android Developer   400000
# 2                             Unacademy         Android Developer  1000000
# 3                    SnapBizz Cloudtech         Android Developer   300000
# 4                Appoids Tech Solutions         Android Developer   600000
# ...                                 ...                       ...      ...
# 22765                  Expert Solutions             Web Developer   200000
# 22766           Nextgen Innovation Labs             Web Developer   300000
# 22767                           Fresher  Full Stack Web Developer   192000
# 22768                         Accenture  Full Stack Web Developer   300000
# 22769                   Thomson Reuters   Associate Web Developer   300000
#
#         Location Employment Status Job Roles
# ...

# %%
df.drop( df[cond1 ].index ) # devuelve un nuevo DataFrame que es el resultado de eliminar las filas del DataFrame original que cumplen la condición de que la columna "Job_Title" sea igual a "Android Developer", es decir, solo las filas donde el título del trabajo es "Android Developer". Esto se hace usando el método drop y pasando como argumento el índice de esas filas obtenido con df[cond1].index. Esto significa que se eliminan las filas con esos índices del DataFrame, y el resultado se guarda en un nuevo DataFrame. El DataFrame original df no se modifica, sino que se crea un nuevo DataFrame con esas filas eliminadas.
# Out:
#                   Company_Name                   Job_Title  Salary   Location  \
# 13                Retail Pulse  Android Developer - Intern   24000  Bangalore
# 30               powerplay app  Android Developer - Intern  396000  Bangalore
# 54                  GreedyGame  Android Developer - Intern  348000  Bangalore
# 62                      Dcoder  Android Developer - Intern   96000  Bangalore
# 66            Across The Globe  Android Developer - Intern   72000  Bangalore
# ...                        ...                         ...     ...        ...
# 22765         Expert Solutions               Web Developer  200000  Bangalore
# 22766  Nextgen Innovation Labs               Web Developer  300000  Bangalore
# 22767                  Fresher    Full Stack Web Developer  192000  Bangalore
# 22768                Accenture    Full Stack Web Developer  300000  Bangalore
# 22769          Thomson Reuters     Associate Web Developer  300000  Bangalore
#
# ...

# %%
df.drop( df[cond1 ].index ).reset_index(drop=True) # devuelve un nuevo DataFrame que es el resultado de eliminar las filas del DataFrame original que cumplen la condición de que la columna "Job_Title" sea igual a "Android Developer", y luego se reinicia el índice del DataFrame resultante. Esto se hace usando el método drop para eliminar las filas con índices obtenidos con df[cond1].index, y luego se usa el método reset_index con el parámetro drop=True para reiniciar el índice del nuevo DataFrame sin agregar la columna de índice antiguo, lo que significa que se asignan nuevos índices secuenciales empezando desde 0. El DataFrame original df no se modifica, sino que se crea un nuevo DataFrame con esas filas eliminadas y el índice reiniciado.
# Out:
#                   Company_Name                   Job_Title  Salary   Location  \
# 0                 Retail Pulse  Android Developer - Intern   24000  Bangalore
# 1                powerplay app  Android Developer - Intern  396000  Bangalore
# 2                   GreedyGame  Android Developer - Intern  348000  Bangalore
# 3                       Dcoder  Android Developer - Intern   96000  Bangalore
# 4             Across The Globe  Android Developer - Intern   72000  Bangalore
# ...                        ...                         ...     ...        ...
# 20736         Expert Solutions               Web Developer  200000  Bangalore
# 20737  Nextgen Innovation Labs               Web Developer  300000  Bangalore
# 20738                  Fresher    Full Stack Web Developer  192000  Bangalore
# 20739                Accenture    Full Stack Web Developer  300000  Bangalore
# 20740          Thomson Reuters     Associate Web Developer  300000  Bangalore
#
# ...

# %% [markdown]
# ### Modificación de valores

# %%
cond1=df["Job_Title"]=="Android Developer"
cond2=df["Salary"]<30000

df.loc[cond1 & cond2,["Rating"]]=10

df.loc[cond1 & cond2]
# Out:
#                Company_Name          Job_Title  Salary   Location  \
# 1980             Freelancer  Android Developer   21120  New Delhi
# 2291      VVDN Technologies  Android Developer   14784  New Delhi
# 2472  Acmatics Technologies  Android Developer   12000  New Delhi
#
#      Employment Status Job Roles  Rating
# 1980         Full Time   Android    10.0
# 2291         Full Time   Android    10.0
# 2472         Full Time   Android    10.0

# %%
df.head()
# Out:
#                        Company_Name          Job_Title   Salary   Location  \
# 0                            Sasken  Android Developer   400000  Bangalore
# 1  Advanced Millennium Technologies  Android Developer   400000  Bangalore
# 2                         Unacademy  Android Developer  1000000  Bangalore
# 3                SnapBizz Cloudtech  Android Developer   300000  Bangalore
# 4            Appoids Tech Solutions  Android Developer   600000  Bangalore
#
#   Employment Status Job Roles  Rating
# 0         Full Time   Android     NaN
# 1         Full Time   Android     NaN
# 2         Full Time   Android     NaN
# 3         Full Time   Android     NaN
# 4         Full Time   Android     NaN

# %%
df.iloc[0,0]=str(1000) # asigna el valor "1000" (como cadena de texto) a la celda que se encuentra en la fila con índice 0 y la columna con índice 0 del DataFrame df, usando el método iloc para acceder a esa posición específica del DataFrame. Esto modifica el valor original de esa celda, que era un número, y lo reemplaza por una cadena de texto.

df.head()
# Out:
#                        Company_Name          Job_Title   Salary   Location  \
# 0                              1000  Android Developer   400000  Bangalore
# 1  Advanced Millennium Technologies  Android Developer   400000  Bangalore
# 2                         Unacademy  Android Developer  1000000  Bangalore
# 3                SnapBizz Cloudtech  Android Developer   300000  Bangalore
# 4            Appoids Tech Solutions  Android Developer   600000  Bangalore
#
#   Employment Status Job Roles  Rating
# 0         Full Time   Android     NaN
# 1         Full Time   Android     NaN
# 2         Full Time   Android     NaN
# 3         Full Time   Android     NaN
# 4         Full Time   Android     NaN

# %% [markdown]
# ### Creación de nuevas columnas

# %%
df["Relative_Salary"] = df["Salary"] / df["Salary"].max() # crea una nueva columna "Relative_Salary" en el DataFrame df, que contiene el resultado de dividir cada valor de la columna "Salary" por el valor máximo de esa columna. Esto se hace para obtener una medida relativa del salario de cada fila en comparación con el salario máximo registrado en esa columna. El resultado es un número entre 0 y 1 que indica qué tan alto es el salario de cada fila en relación al salario máximo.
df.head()
# Out:
#                        Company_Name          Job_Title   Salary   Location  \
# 0                              1000  Android Developer   400000  Bangalore
# 1  Advanced Millennium Technologies  Android Developer   400000  Bangalore
# 2                         Unacademy  Android Developer  1000000  Bangalore
# 3                SnapBizz Cloudtech  Android Developer   300000  Bangalore
# 4            Appoids Tech Solutions  Android Developer   600000  Bangalore
#
#   Employment Status Job Roles  Rating  Relative_Salary
# 0         Full Time   Android     NaN         0.004444
# 1         Full Time   Android     NaN         0.004444
# 2         Full Time   Android     NaN         0.011111
# 3         Full Time   Android     NaN         0.003333
# 4         Full Time   Android     NaN         0.006667

# %%
df.head()
# Out:
#                        Company_Name          Job_Title   Salary   Location  \
# 0                              1000  Android Developer   400000  Bangalore
# 1  Advanced Millennium Technologies  Android Developer   400000  Bangalore
# 2                         Unacademy  Android Developer  1000000  Bangalore
# 3                SnapBizz Cloudtech  Android Developer   300000  Bangalore
# 4            Appoids Tech Solutions  Android Developer   600000  Bangalore
#
#   Employment Status Job Roles  Rating  Relative_Salary
# 0         Full Time   Android     NaN         0.004444
# 1         Full Time   Android     NaN         0.004444
# 2         Full Time   Android     NaN         0.011111
# 3         Full Time   Android     NaN         0.003333
# 4         Full Time   Android     NaN         0.006667

# %%
salario_maximo=df["Salary"].max()
df["Relative_Salary"]=df["Salary"]/salario_maximo # crea una nueva columna "Relative_Salary" en el DataFrame df, que contiene el resultado de dividir cada valor de la columna "Salary" por el valor máximo de esa columna, que se guarda previamente en la variable salario_maximo. Esto se hace para obtener una medida relativa del salario de cada fila en comparación con el salario máximo registrado en esa columna. El resultado es un número entre 0 y 1 que indica qué tan alto es el salario de cada fila en relación al salario máximo.
df.head()
# Out:
#                        Company_Name          Job_Title   Salary   Location  \
# 0                              1000  Android Developer   400000  Bangalore
# 1  Advanced Millennium Technologies  Android Developer   400000  Bangalore
# 2                         Unacademy  Android Developer  1000000  Bangalore
# 3                SnapBizz Cloudtech  Android Developer   300000  Bangalore
# 4            Appoids Tech Solutions  Android Developer   600000  Bangalore
#
#   Employment Status Job Roles  Rating  Relative_Salary
# 0         Full Time   Android     NaN         0.004444
# 1         Full Time   Android     NaN         0.004444
# 2         Full Time   Android     NaN         0.011111
# 3         Full Time   Android     NaN         0.003333
# 4         Full Time   Android     NaN         0.006667

# %% [markdown]
# #### Apply

# %%
df["Rating"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 22765   NaN
# 22766   NaN
# 22767   NaN
# 22768   NaN
# 22769   NaN
# Name: Rating, Length: 22769, dtype: float64

# %%
def rating_cat(rating):
  level="Bajo"
  if rating>=2 and rating<4:
    level="Medio"
  elif rating>=4:
    level="Alto"

  return level

# crea una nueva columna "Rating_category" en el DataFrame df,
# que contiene el resultado de aplicar la función rating_cat a
# cada valor de la columna "Rating". La función rating_cat toma
# un valor de rating y devuelve una categoría de nivel
# ("Bajo", "Medio" o "Alto") según el rango en el que se encuentre
# ese valor. La función apply se usa para aplicar esta función a
# cada elemento de la columna "Rating" y crear la nueva columna
# con los resultados.

df["Rating_category"]=df["Rating"].apply(rating_cat)
df.head(10)
# Out:
#                                Company_Name          Job_Title   Salary  \
# 0                                      1000  Android Developer   400000
# 1          Advanced Millennium Technologies  Android Developer   400000
# 2                                 Unacademy  Android Developer  1000000
# 3                        SnapBizz Cloudtech  Android Developer   300000
# 4                    Appoids Tech Solutions  Android Developer   600000
# 5                                Freelancer  Android Developer   100000
# 6                             SQUARE N CUBE  Android Developer   192000
# 7   Samsung R&D Institute India - Bangalore  Android Developer   400000
# 9           Endeavour Software Technologies  Android Developer   600000
# 10                            Craft Silicon  Android Developer   300000
#
#      Location Employment Status Job Roles  Rating  Relative_Salary  \
# 0   Bangalore         Full Time   Android     NaN         0.004444
# ...

# %%
def rating_cat_fila(fila):
  level="Bajo"
  if fila["Rating"]>=2 and fila["Rating"]<4:
    level="Medio"
  elif fila["Rating"]>=4:
    level="Alto"

  return level

# crea una nueva columna "Rating_category" en el DataFrame df,
# que contiene el resultado de aplicar la función rating_cat_fila
# a cada fila del DataFrame. La función rating_cat_fila toma una
# fila del DataFrame como argumento y devuelve una categoría de
# nivel ("Bajo", "Medio" o "Alto") según el valor de la columna
# "Rating" en esa fila. La función apply se usa para aplicar esta
# función a cada fila del DataFrame, especificando axis="columns"
# para indicar que la función debe recibir cada fila como un objeto
# Series.
# El resultado es una nueva columna con las categorías de nivel
# correspondientes a cada valor de rating.

df["Rating_category"]=df.apply(rating_cat_fila,axis="columns")
df.head(10)
# Out:
#                                Company_Name          Job_Title   Salary  \
# 0                                      1000  Android Developer   400000
# 1          Advanced Millennium Technologies  Android Developer   400000
# 2                                 Unacademy  Android Developer  1000000
# 3                        SnapBizz Cloudtech  Android Developer   300000
# 4                    Appoids Tech Solutions  Android Developer   600000
# 5                                Freelancer  Android Developer   100000
# 6                             SQUARE N CUBE  Android Developer   192000
# 7   Samsung R&D Institute India - Bangalore  Android Developer   400000
# 9           Endeavour Software Technologies  Android Developer   600000
# 10                            Craft Silicon  Android Developer   300000
#
#      Location Employment Status Job Roles  Rating  Relative_Salary  \
# 0   Bangalore         Full Time   Android     NaN         0.004444
# ...

# %%
def salary_porc(fila):
  if fila["Company_Name"]=="Sasken":
    porc_salary=fila["Salary"]*0.01
  else:
    porc_salary=fila["Salary"]*0.21

  return porc_salary

# crea una nueva columna "Salary_porc" en el DataFrame df,
# que contiene el resultado de aplicar la función salary_porc
# a cada fila del DataFrame. La función salary_porc toma una
# fila del DataFrame como argumento y devuelve un valor que
# es el resultado de multiplicar el valor de la columna "Salary"
# por un porcentaje específico según el valor de la columna
# "Company_Name" en esa fila. Si el nombre de la empresa es "Sasken",
# se multiplica por 0.01 (1%), y para cualquier otra empresa se
# multiplica por 0.21 (21%). La función apply se usa para aplicar
# esta función a cada fila del DataFrame, especificando axis="columns"
# para indicar que la función debe recibir cada fila como un objeto Series.
# El resultado es una nueva columna con los valores calculados según esa lógica.

df["Salary_porc"]=df.apply(salary_porc,axis="columns")
df.head(10)
# Out:
#                                Company_Name          Job_Title   Salary  \
# 0                                      1000  Android Developer   400000
# 1          Advanced Millennium Technologies  Android Developer   400000
# 2                                 Unacademy  Android Developer  1000000
# 3                        SnapBizz Cloudtech  Android Developer   300000
# 4                    Appoids Tech Solutions  Android Developer   600000
# 5                                Freelancer  Android Developer   100000
# 6                             SQUARE N CUBE  Android Developer   192000
# 7   Samsung R&D Institute India - Bangalore  Android Developer   400000
# 9           Endeavour Software Technologies  Android Developer   600000
# 10                            Craft Silicon  Android Developer   300000
#
#      Location Employment Status Job Roles  Rating  Relative_Salary  \
# 0   Bangalore         Full Time   Android     NaN         0.004444
# ...

# %%
df["Rating_category_lambda"]=df["Rating"].apply(lambda rating: "Bajo" if rating<2 else ("Medio" if (rating>=2 and rating<4) else "Alto") )
df.head(10)
# Out:
#                                Company_Name          Job_Title   Salary  \
# 0                                      1000  Android Developer   400000
# 1          Advanced Millennium Technologies  Android Developer   400000
# 2                                 Unacademy  Android Developer  1000000
# 3                        SnapBizz Cloudtech  Android Developer   300000
# 4                    Appoids Tech Solutions  Android Developer   600000
# 5                                Freelancer  Android Developer   100000
# 6                             SQUARE N CUBE  Android Developer   192000
# 7   Samsung R&D Institute India - Bangalore  Android Developer   400000
# 9           Endeavour Software Technologies  Android Developer   600000
# 10                            Craft Silicon  Android Developer   300000
#
#      Location Employment Status Job Roles  Rating  Relative_Salary  \
# 0   Bangalore         Full Time   Android     NaN         0.004444
# ...

# %% [markdown]
# ### Ordenamiento

# %%
df.sort_values(by="Salary")
# Out:
#                      Company_Name  \
# 22563         Keeves Technologies
# 9937                      Virtusa
# 16838  Excel Engineering Services
# 5463                     Scholify
# 22028                    Yes Bank
# ...                           ...
# 5819               Nityo Infotech
# 9260            OASYS Cybernetics
# 7121               Koru UX Design
# 4471                   Concentrix
# 18635           Thapar University
#
#                                            Job_Title    Salary   Location  \
# 22563                         Web Developer - Intern      2112  Bangalore
# 9937                           Junior Java Developer      8448  Hyderabad
# 16838           Senior Software Development Engineer     12000     Mumbai
# 5463                    Front End Developer - Intern     12000  Bangalore
# 22028                                  Web Developer     12000  Bangalore
# ...                                              ...       ...        ...
# ...

# %%
df.sort_values(by="Salary",ascending=[False])
# Out:
#                      Company_Name  \
# 18635           Thapar University
# 4471                   Concentrix
# 7121               Koru UX Design
# 9260            OASYS Cybernetics
# 5819               Nityo Infotech
# ...                           ...
# 16838  Excel Engineering Services
# 18429                        ....
# 13985                  Webboombaa
# 9937                      Virtusa
# 22563         Keeves Technologies
#
#                                            Job_Title    Salary   Location  \
# 18635            Software Development Engineer (SDE)  90000000  New Delhi
# 4471                   Oracle Database Administrator  10000000  Bangalore
# 7121                      Senior Front End Developer  10000000       Pune
# 9260                           Senior Java Developer  10000000    Chennai
# 5819   Lead UI Designer, Magento Front-end Developer   9900000  Bangalore
# ...                                              ...       ...        ...
# ...

# %%
df_sorted=df.sort_values(by=["Salary","Job_Title"],ascending=[False,True])
df_sorted.head(5)
# Out:
#             Company_Name                                      Job_Title  \
# 18635  Thapar University            Software Development Engineer (SDE)
# 4471          Concentrix                  Oracle Database Administrator
# 7121      Koru UX Design                     Senior Front End Developer
# 9260   OASYS Cybernetics                          Senior Java Developer
# 5819      Nityo Infotech  Lead UI Designer, Magento Front-end Developer
#
#          Salary   Location Employment Status Job Roles  Rating  \
# 18635  90000000  New Delhi         Full Time       SDE     NaN
# 4471   10000000  Bangalore         Full Time  Database     NaN
# 7121   10000000       Pune         Full Time  Frontend     NaN
# 9260   10000000    Chennai         Full Time      Java     NaN
# 5819    9900000  Bangalore         Full Time  Frontend     NaN
#
#        Relative_Salary Rating_category  Salary_porc Rating_category_lambda
# 18635         1.000000            Bajo   18900000.0                   Alto
# ...

# %% [markdown]
# # Ejemplo 2

# %%
ds_trabajo2=pd.read_csv('titanic.csv')

# %%
ds_trabajo2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab( ds_trabajo2['Survived'] , ds_trabajo2['Sex'] )
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
ds_trabajo2.groupby(['Pclass','Sex'])['Survived'].sum() # devuelve un DataFrame con la suma de los valores de la columna "Survived" agrupados por las combinaciones de las columnas "Pclass
# Out:
# Pclass  Sex
# 1       female    91
#         male      45
# 2       female    70
#         male      17
# 3       female    72
#         male      47
# Name: Survived, dtype: int64

# %% [markdown]
# Mostrar información de resumen del dataset

# %%
ds_trabajo2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Seleccionar fila por posición

# %%
ds_trabajo2.iloc[0] # devuelve la primera fila del DataFrame ds_trabajo2, que corresponde al pasajero con índice 0, mostrando los valores de todas las columnas para ese pasajero.
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %% [markdown]
# Seleccionar columna por posición

# %%
ds_trabajo2.iloc[:,0] # devuelve la primera columna del DataFrame ds_trabajo2, que corresponde a la columna "PassengerId", mostrando los valores de esa columna para todos los pasajeros.
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %% [markdown]
# ##### Seleccionar columna por nombre

# %%
ds_trabajo2.PassengerId
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
ds_trabajo2["PassengerId"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
ds_trabajo2.loc[:,"PassengerId"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
ds_trabajo2.loc[:,["PassengerId","Age"]]
# Out:
#      PassengerId   Age
# 0              1  22.0
# 1              2  38.0
# 2              3  26.0
# 3              4  35.0
# 4              5  35.0
# ..           ...   ...
# 886          887  27.0
# 887          888  19.0
# 888          889   NaN
# 889          890  26.0
# 890          891  32.0
#
# [891 rows x 2 columns]

# %% [markdown]
# ##### Selección de filas en función de características de columnas

# %%
ds_trabajo2.loc[:,"Survived"]==1 # devuelve una Serie de valores booleanos que indica si cada pasajero del DataFrame ds_trabajo2 sobrevivió o no, es decir, si el valor de la columna "Survived" es igual a 1 (sobrevivió) o no (no sobrevivió).
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
ds_trabajo2["Survived"]==1 # devuelve una Serie de valores booleanos que indica si cada pasajero del DataFrame ds_trabajo2 sobrevivió o no, es decir, si el valor de la columna "Survived" es igual a 1 (sobrevivió) o no (no sobrevivió).
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
ds_trabajo2.loc[ds_trabajo2.loc[:,"Survived"]==1] # devuelve un DataFrame con las filas del DataFrame ds_trabajo2 que corresponden a los pasajeros que sobrevivieron, es decir, aquellos donde el valor de la columna "Survived" es igual a 1. Esto se hace usando el método loc para filtrar las filas según esa condición.
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Seleccionar filas utilizando múltiples condiciones

# %%
ds_trabajo2.loc[ (ds_trabajo2["Survived"]==1) & (ds_trabajo2["Age"]>30) ] # devuelve un DataFrame con las filas del DataFrame ds_trabajo2 que corresponden a los pasajeros que sobrevivieron y tienen más de 30 años, es decir, aquellos donde el valor de la columna "Survived" es igual a 1 y el valor de la columna "Age" es mayor a 30. Esto se hace usando el método loc para filtrar las filas según ambas condiciones combinadas con el operador &.
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 21            22         1       2
# ..           ...       ...     ...
# 857          858         1       1
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
cond1=ds_trabajo2["Survived"]==1
cond2=ds_trabajo2["Age"]>30

ds_trabajo2.loc[ cond1 & cond2 ] # devuelve un DataFrame con las filas del DataFrame ds_trabajo2 que corresponden a los pasajeros que sobrevivieron y tienen más de 30 años, es decir, aquellos donde el valor de la columna "Survived" es igual a 1 y el valor de la columna "Age" es mayor a 30. Esto se hace usando el método loc para filtrar las filas según ambas condiciones combinadas con el operador &, donde las condiciones se guardaron previamente en las variables cond1 y cond2 para mayor claridad.
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 21            22         1       2
# ..           ...       ...     ...
# 857          858         1       1
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ##### Eliminar columma

# %%
ds_trabajo2.drop('PassengerId', axis='columns', inplace=True)  # inplace=True -> Elimina columna sobre el mismo dataframe
ds_trabajo2.columns.tolist()
# Out:
# ['Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# ##### Eliminar fila por condición

# %%
ds_trabajo_sobrevivientes=ds_trabajo2.copy()
# elimina las filas del DataFrame ds_trabajo_sobrevivientes que corresponden
# a los pasajeros que no sobrevivieron, es decir, aquellos donde el valor de
# la columna "Survived" es igual a 0. Esto se hace usando el método drop y
# pasando como argumento el índice de esas filas obtenido con
# ds_trabajo2[ds_trabajo2["Survived"]==0].index, indicando que se trata de
# filas (axis='index') y que el cambio se realiza en el mismo DataFrame
# ds_trabajo_sobrevivientes (inplace=True).

ds_trabajo_sobrevivientes.drop(ds_trabajo2[ds_trabajo2["Survived"]==0].index, axis='index',inplace=True)
ds_trabajo_sobrevivientes.shape
# Out:
# (342, 11)

# %%
ds_trabajo_sobrevivientes=ds_trabajo2.copy()

# elimina las filas del DataFrame ds_trabajo_sobrevivientes que corresponden
# a los pasajeros que no sobrevivieron, es decir, aquellos donde el valor de
# la columna "Survived" es igual a 0. Esto se hace usando el método drop y
# pasando como argumento el índice de esas filas obtenido con
# ds_trabajo2.loc[ds_trabajo2.loc[:,"Survived"]==0,:].index, indicando que
# se trata de filas (axis='index') y que el cambio se realiza en el mismo
# DataFrame ds_trabajo_sobrevivientes (inplace=True). La diferencia con la
# línea anterior es que aquí se usa loc para obtener el índice de las filas
# a eliminar, pero el resultado es el mismo.

ds_trabajo_sobrevivientes.drop(ds_trabajo2.loc[ds_trabajo2.loc[:,"Survived"]==0,:].index, axis='index', inplace=True)
ds_trabajo_sobrevivientes.shape
# Out:
# (342, 11)

# %%
ds_trabajo_sobrevivientes.head()
# Out:
#    Survived  Pclass                                               Name  \
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 8  female  27.0      0      2            347742  11.1333   NaN        S
# 9  female  14.0      1      0            237736  30.0708   NaN        C

# %% [markdown]
# ##### Cambiar valores de features

# %%
ds_trabajo_reemplazo_valores=ds_trabajo2.copy()

ds_trabajo_reemplazo_valores.loc[ds_trabajo_reemplazo_valores.loc[:,"Survived"]==1,"Survived"]=3
ds_trabajo_reemplazo_valores.loc[ds_trabajo_reemplazo_valores.loc[:,"Survived"]==0,"Survived"]=4

ds_trabajo_reemplazo_valores.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         4       3                            Braund, Mr. Owen Harris
# 1         3       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         3       3                             Heikkinen, Miss. Laina
# 3         3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         4       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
ds_trabajo2.loc[:,"Survived"].replace(to_replace=[0,1],value=["No","Yes"],inplace=True) # reemplaza los valores de la columna "Survived" del DataFrame ds_trabajo2, donde se reemplazan los valores 0 por "No" y los valores 1 por "Yes". Esto se hace usando el método replace, donde se especifica la columna a modificar con loc, se indican los valores a reemplazar con to_replace, los nuevos valores con value, y se establece inplace=True para realizar el cambio en el mismo DataFrame ds_trabajo2.

ds_trabajo2.head()
# Out:
# /tmp/ipykernel_957277/1395579668.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
# ...

# %% [markdown]
# Apply

# %%
def mayor_edad(edad):
    if edad >= 21:
        return "mayor"
    else:
        return "menor"

# %%
ds_trabajo2['mayor_edad'] = ds_trabajo2['Age'].apply(mayor_edad) # crea una nueva columna "mayor_edad" en el DataFrame ds_trabajo2, que contiene el resultado de aplicar la función mayor_edad a cada valor de la columna "Age". La función mayor_edad toma un valor de edad y devuelve "mayor" si la edad es mayor

# %%
ds_trabajo2.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# ...

# %%
#El mismo ejemplo anterior pero usando lambda

ds_trabajo2['mayor_edad'] = ds_trabajo2['Age'].apply(lambda x: "Mayor" if x>=21 else "Menor") # crea una nueva columna "mayor_edad" en el DataFrame ds_trabajo2, que contiene el resultado de aplicar una función lambda a cada valor de la columna "Age". La función lambda toma un valor x (que representa la edad) y devuelve "Mayor" si x es mayor o igual a 21, y "Menor" si x es menor a 21. Esto se hace usando el método apply para aplicar esta función a cada elemento de la columna "Age" y crear la nueva columna con los resultados.
ds_trabajo2.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   mayor_edad
# 0      Mayor
# 1      Mayor
# 2      Mayor
# 3      Mayor
# 4      Mayor

# %% [markdown]
# # Unión de DataFrames
#
# https://pandas.pydata.org/docs/user_guide/merging.html

# %% [markdown]
# Concat

# %%
d1 = {"Nombre": ["Pedro", "Juan"],
      "id": [1, 2]}
d2 = {"Nombre": "Mariano",
      "id": 3}

df1 = pd.DataFrame(d1, index= [1, 2])
df2 = pd.DataFrame(d2, index=[3])

df3 = pd.concat([df1, df2]) # concatena los DataFrames df1 y df2 en un nuevo DataFrame df3, usando la función pd.concat. Esto se hace pasando una lista de los DataFrames a concatenar como argumento, y el resultado es un nuevo DataFrame que contiene todas las filas de ambos DataFrames, con el mismo índice que tenían originalmente. En este caso, df3 tendrá las filas de df1 con índices 1 y 2, y la fila de df2 con índice 3.

df3
# Out:
#     Nombre  id
# 1    Pedro   1
# 2     Juan   2
# 3  Mariano   3

# %%
df1.head()
# Out:
#   Nombre  id
# 1  Pedro   1
# 2   Juan   2

# %%
df1.head()
# Out:
#   Nombre  id
# 1  Pedro   1
# 2   Juan   2

# %%
df2.head()
# Out:
#     Nombre  id
# 3  Mariano   3

# %%
d1 = {"Nombre": ["Pedro", "Juan"],
      "id": [1, 2]}
d2 = {"Profesión": ["Médico", "Ingeniero"]}

df1 = pd.DataFrame(d1, index=[1, 2])
df2 = pd.DataFrame(d2, index=[1, 2])

df3 = pd.concat([df1, df2], axis=1)
df3
# Out:
#   Nombre  id  Profesión
# 1  Pedro   1     Médico
# 2   Juan   2  Ingeniero

# %% [markdown]
# Merge

# %%
d1 = {"Nombre": ["Pedro", "Juan","Pablo"],
      "id": [1, 2, 3],
      "id_profesion": [1,2,1]}

d2 = {"Profesión": ["Médico", "Ingeniero"],
       "id_profesion": [1,2]
      }

df1 = pd.DataFrame(d1, index=[1, 2,3])
df2 = pd.DataFrame(d2, index=[1, 2])

result = pd.merge(df1,df2) # devuelve un nuevo DataFrame result que es el resultado de realizar una combinación (merge) entre los DataFrames df1 y df2, usando la función pd.merge. Esto se hace buscando las filas de ambos DataFrames que tienen el mismo valor en la columna "id_profesion", y combinando esas filas en una sola fila en el DataFrame result. El resultado es un nuevo DataFrame que contiene las columnas de ambos DataFrames, pero solo las filas donde el valor de "id_profesion" coincide en ambos DataFrames. En este caso, result tendrá las filas correspondientes a "Pedro" y "Juan", ya que ambos tienen un valor de "id_profesion" que coincide con los valores en df2, mientras que "Pablo" no aparecerá en el resultado porque su valor de "id_profesion" no tiene coincidencia en df2.
result
# Out:
#   Nombre  id  id_profesion  Profesión
# 0  Pedro   1             1     Médico
# 1   Juan   2             2  Ingeniero
# 2  Pablo   3             1     Médico

# %%
d1 = {"Nombre": ["Pedro", "Juan","Pablo","Manuel"],
      "id": [1, 2, 3, 4],
      "id_profesion": [1,2,1,3]}

d2 = {"Profesión": ["Médico", "Ingeniero"],
       "id_profesion": [1,2]
      }

df1 = pd.DataFrame(d1, index={1, 2,3,4})
df2 = pd.DataFrame(d2, index={1, 2})

result = pd.merge(df1,df2,how='inner')
result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_957277/4286468845.py in ?()
#       5 d2 = {"Profesión": ["Médico", "Ingeniero"],
#       6        "id_profesion": [1,2]
#       7       }
#       8
# ----> 9 df1 = pd.DataFrame(d1, index={1, 2,3,4})
#      10 df2 = pd.DataFrame(d2, index={1, 2})
#      11
#      12 result = pd.merge(df1,df2,how='inner')
#
# ~/proyectos/educacion/datos/taller-tgad-fce/.venv/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, data, index, columns, dtype, copy)
#     739                 return
#     740
#     741         # GH47215
#     742         if isinstance(index, set):
# --> 743             raise ValueError("index cannot be a set")
#     744         if isinstance(columns, set):
#     745             raise ValueError("columns cannot be a set")
#     746
#
# ValueError: index cannot be a set

# %%
d1 = {"Nombre": ["Pedro", "Juan","Pablo","Manuel"],
      "id": [1, 2, 3, 4],
      "id_profesion": [1,2,1,3]}

d2 = {"Profesión": ["Médico", "Ingeniero"],
       "id_profesion": [1,2]
      }

df1 = pd.DataFrame(d1, index={1, 2,3,4})
df2 = pd.DataFrame(d2, index={1, 2})

result = pd.merge(df1,df2,how='outer')
result
# Out:
#    Nombre  id  id_profesion  Profesión
# 0   Pedro   1             1     Médico
# 1   Pablo   3             1     Médico
# 2    Juan   2             2  Ingeniero
# 3  Manuel   4             3        NaN

# %%
d1 = {"Nombre": ["Pedro", "Juan","Pablo","Manuel"],
      "id": [1, 2, 3, 4],
      "id_profesion": [1,2,1,3]}

d2 = {"Profesión": ["Médico", "Ingeniero"],
       "id_profesion": [1,2]
      }

df1 = pd.DataFrame(d1, index={1, 2,3,4})
df2 = pd.DataFrame(d2, index={1, 2})

result = pd.merge(df1,df2,how='left')
result
# Out:
#    Nombre  id  id_profesion  Profesión
# 0   Pedro   1             1     Médico
# 1    Juan   2             2  Ingeniero
# 2   Pablo   3             1     Médico
# 3  Manuel   4             3        NaN

# %%
d1 = {"Nombre": ["Pedro", "Juan","Pablo","Manuel"],
      "id": [1, 2, 3, 4],
      "id_profesion": [1,2,1,3]}

d2 = {"Profesión": ["Médico", "Ingeniero"],
       "id_profesion": [1,2]
      }

df1 = pd.DataFrame(d1, index={1, 2,3,4})
df2 = pd.DataFrame(d2, index={1, 2})

result = pd.merge(df1,df2,how='right')
result

# %%
d1 = {"Nombre": ["Pedro", "Juan","Pablo","Manuel"],
      "id": [1, 2, 3, 4],
      "id_profesion": [1,2,1,3]}

d2 = {"Profesión": ["Médico", "Ingeniero"],
       "id_profesion": [1,2]
      }

df1 = pd.DataFrame(d1, index={1, 2,3,4})
df2 = pd.DataFrame(d2, index={1, 2})

result = pd.merge(df1,df2,how='right',left_on="id_profesion",right_on="id_profesion")
result
