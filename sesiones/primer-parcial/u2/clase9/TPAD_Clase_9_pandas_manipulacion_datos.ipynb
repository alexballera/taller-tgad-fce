# %% [markdown]
# <figure>
# <center>
# <img src='https://www.economicas.uba.ar/wp-content/uploads/2020/08/cropped-logo_FCE.png' />
# </figure>

# %% [markdown]
# # **Universidad de Buenos Aires**
# ## **Facultad de Ciencias Económicas**
#
# ### **Taller de Programación para el Análisis de Datos**
#
# #### **Clase 9: Manipulación de datos**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **pandas** es una herramienta de manipulación y análisis de datos de código abierto construida sobre el lenguaje de programación **Python** .
#
# Algunas de las principales características de esta librería son:
#
# * Define nuevas estructuras de datos basadas en los arrays de la librería NumPy pero con nuevas funcionalidades.
# * Permite leer y escribir fácilmente archivos en formato CSV, Excel y bases de datos SQL.
# * Permite acceder a los datos mediante índices o nombres para filas y columnas.
# * Ofrece métodos para reordenar, dividir y combinar conjuntos de datos.

# %% [markdown]
# Links de interés
#
# https://pandas.pydata.org

# %% [markdown]
# Importamos las librerías que vamos a utilizar

# %%
import pandas as pd

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Ejemplo 1

# %% [markdown]
# Cargamos el archivo de datos en un dataframe de Pandas

# %%
df=pd.read_csv('Software_Professional_Salaries.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Listar la cantidad de filas y columnas que tiene el dataset

# %%
df.shape
# Out:
# (22774, 6)

# %%
print("cant filas",df.shape[0])
print("cant columnas",df.shape[1])
# Out:
# cant filas 22774
# cant columnas 6

# %%
dimensiones=df.shape
print("cant filas",dimensiones[0])
print("cant columnas",dimensiones[1])
# Out:
# cant filas 22774
# cant columnas 6

# %%
cant_filas, cant_cols = df.shape

print("cant filas",cant_filas)
print("cant columnas",cant_cols)
# Out:
# cant filas 22774
# cant columnas 6

# %%
df.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location
# 0                  3  Bangalore
# 1                  3  Bangalore
# 2                  3  Bangalore
# 3                  3  Bangalore
# 4                  3  Bangalore

# %% [markdown]
# Mostramos las primeras
# del dataset

# %%
df.head(9)
# Out:
#    Rating                             Company Name          Job Title  \
# 0     3.8                                   Sasken  Android Developer
# 1     4.5         Advanced Millennium Technologies  Android Developer
# 2     4.0                                Unacademy  Android Developer
# 3     3.8                       SnapBizz Cloudtech  Android Developer
# 4     4.4                   Appoids Tech Solutions  Android Developer
# 5     4.2                               Freelancer  Android Developer
# 6     3.7                            SQUARE N CUBE  Android Developer
# 7     3.1  Samsung R&D Institute India - Bangalore  Android Developer
# 8     3.7                     DXMinds Technologies  Android Developer
#
#     Salary  Salaries Reported   Location
# 0   400000                  3  Bangalore
# 1   400000                  3  Bangalore
# 2  1000000                  3  Bangalore
# 3   300000                  3  Bangalore
# 4   600000                  3  Bangalore
# 5   100000                  3  Bangalore
# 6   192000                  3  Bangalore
# 7   400000                  3  Bangalore
# 8   300000                  3  Bangalore

# %% [markdown]
# Mostramos las últimas filas del dataset

# %%
df.tail()
# Out:
#        Rating             Company Name                 Job Title  Salary  \
# 22769     4.7         Expert Solutions             Web Developer  200000
# 22770     4.0  Nextgen Innovation Labs             Web Developer  300000
# 22771     4.1                  Fresher  Full Stack Web Developer  192000
# 22772     4.1                Accenture  Full Stack Web Developer  300000
# 22773     3.8          Thomson Reuters   Associate Web Developer  300000
#
#        Salaries Reported   Location
# 22769                  1  Bangalore
# 22770                  1  Bangalore
# 22771                 13  Bangalore
# 22772                  7  Bangalore
# 22773                  7  Bangalore

# %%
df.tail(10)
# Out:
#        Rating             Company Name                 Job Title  Salary  \
# 22764     4.0              DiscoverWeb             Web Developer  100000
# 22765     4.6             Masai School             Web Developer  101376
# 22766     3.9            Fresher Zones             Web Developer  100000
# 22767     4.4           Unicon Systems             Web Developer  500000
# 22768     5.0                   BJSHub             Web Developer  400000
# 22769     4.7         Expert Solutions             Web Developer  200000
# 22770     4.0  Nextgen Innovation Labs             Web Developer  300000
# 22771     4.1                  Fresher  Full Stack Web Developer  192000
# 22772     4.1                Accenture  Full Stack Web Developer  300000
# 22773     3.8          Thomson Reuters   Associate Web Developer  300000
#
#        Salaries Reported   Location
# 22764                  1  Bangalore
# 22765                  1  Bangalore
# 22766                  1  Bangalore
# 22767                  1  Bangalore
# 22768                  1  Bangalore
# 22769                  1  Bangalore
# 22770                  1  Bangalore
# 22771                 13  Bangalore
# 22772                  7  Bangalore
# 22773                  7  Bangalore

# %% [markdown]
# Mostramos algunas filas del azar

# %%
df.sample()
# Out:
#      Rating Company Name          Job Title   Salary  Salaries Reported  \
# 909     3.8        Wipro  Android Tech Lead  1500000                  1
#
#       Location
# 909  Bangalore

# %%
df.sample(10)
# Out:
#        Rating           Company Name                               Job Title  \
# 989       3.9   BridgeLabz Solutions                       Android Developer
# 16032     5.0            Tech Mentro  Software Development Engineer - Intern
# 11784     3.0        Gridlex Service                 Python/Django Developer
# 1498      4.5  Avantari Technologies                Senior Android Developer
# 13588     4.3        Tally Solutions     Software Development Engineer (SDE)
# 14691     4.0       Fresherworld.com           Software Development Engineer
# 14671     2.6          Pyro Networks           Software Development Engineer
# 6494      3.5         Magic Software                     Front End Developer
# 5731      4.4                  QTalk                      Front End Engineer
# 417       4.1             Tealthcare              Android Developer - Intern
#
#         Salary  Salaries Reported   Location
# 989     400000                  1    Chennai
# 16032   120000                  1    Kolkata
# 11784  1000000                  1  Hyderabad
# 1498    324000                  1  Hyderabad
# 13588   600000                  5  Bangalore
# 14691   156000                  1  Hyderabad
# 14671   372000                  1  Hyderabad
# 6494    500000                  2  New Delhi
# 5731   1000000                  1  Bangalore
# 417     144000                  1  Bangalore

# %%
df.columns
# Out:
# Index(['Rating', 'Company Name', 'Job Title', 'Salary', 'Salaries Reported',
#        'Location'],
#       dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.columns.values
# Out:
# array(['Rating', 'Company Name', 'Job Title', 'Salary',
#        'Salaries Reported', 'Location'], dtype=object)

# %%
type(df.columns.values)
# Out:
# numpy.ndarray

# %% [markdown]
# Listar los nombres de las columnas del dataset

# %%
df.columns.tolist()
# Out:
# ['Rating',
#  'Company Name',
#  'Job Title',
#  'Salary',
#  'Salaries Reported',
#  'Location']

# %%
nombre_cols=df.columns.tolist()

type(nombre_cols)
# Out:
# list

# %%
lista_columnas=df.columns.tolist()

for columna in lista_columnas:
  print(columna)
# Out:
# Rating
# Company Name
# Job Title
# Salary
# Salaries Reported
# Location

# %%
lista_columnas.pop(0)
# Out:
# 'Rating'

# %%
lista_columnas
# Out:
# ['Company Name', 'Job Title', 'Salary', 'Salaries Reported', 'Location']

# %% [markdown]
# Mostrar el tipo de cada columna del dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22774 entries, 0 to 22773
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22774 non-null  float64
#  1   Company Name       22773 non-null  object
#  2   Job Title          22774 non-null  object
#  3   Salary             22774 non-null  int64
#  4   Salaries Reported  22774 non-null  int64
#  5   Location           22774 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.0+ MB

# %%
df.dtypes
# Out:
# Rating               float64
# Company Name          object
# Job Title             object
# Salary                 int64
# Salaries Reported      int64
# Location              object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Formas de acceder al contenido del Dataframe

# %%
fila_cero=df.iloc[10]
print(fila_cero)
# Out:
# Rating                             3.6
# Company Name             Craft Silicon
# Job Title            Android Developer
# Salary                          300000
# Salaries Reported                    3
# Location                     Bangalore
# Name: 10, dtype: object

# %%
df.iloc[10:15]
# Out:
#     Rating            Company Name                   Job Title  Salary  \
# 10     3.6           Craft Silicon           Android Developer  300000
# 11     3.9  Baronford & Associates           Android Developer  240000
# 12     3.7                   Wibmo           Android Developer  900000
# 13     4.8            Retail Pulse  Android Developer - Intern   24000
# 14     3.9              Bookmyshow           Android Developer  600000
#
#     Salaries Reported   Location
# 10                  3  Bangalore
# 11                  2  Bangalore
# 12                  2  Bangalore
# 13                  2  Bangalore
# 14                  2  Bangalore

# %%
df_filas_10a15=df.iloc[10:15]

df_filas_10a15.head()
# Out:
#     Rating            Company Name                   Job Title  Salary  \
# 10     3.6           Craft Silicon           Android Developer  300000
# 11     3.9  Baronford & Associates           Android Developer  240000
# 12     3.7                   Wibmo           Android Developer  900000
# 13     4.8            Retail Pulse  Android Developer - Intern   24000
# 14     3.9              Bookmyshow           Android Developer  600000
#
#     Salaries Reported   Location
# 10                  3  Bangalore
# 11                  2  Bangalore
# 12                  2  Bangalore
# 13                  2  Bangalore
# 14                  2  Bangalore

# %%
df.iloc[10:15,[0,3]]
# Out:
#     Rating  Salary
# 10     3.6  300000
# 11     3.9  240000
# 12     3.7  900000
# 13     4.8   24000
# 14     3.9  600000

# %%
df.iloc[10:15,[0,1,3]]
# Out:
#     Rating            Company Name  Salary
# 10     3.6           Craft Silicon  300000
# 11     3.9  Baronford & Associates  240000
# 12     3.7                   Wibmo  900000
# 13     4.8            Retail Pulse   24000
# 14     3.9              Bookmyshow  600000

# %%
df["Rating"]
# Out:
# 0        3.8
# 1        4.5
# 2        4.0
# 3        3.8
# 4        4.4
#         ...
# 22769    4.7
# 22770    4.0
# 22771    4.1
# 22772    4.1
# 22773    3.8
# Name: Rating, Length: 22774, dtype: float64

# %%
type(df["Rating"])
# Out:
# pandas.core.series.Series

# %%
df_2_cols=df[["Rating","Salary"]]
df_2_cols
# Out:
#        Rating   Salary
# 0         3.8   400000
# 1         4.5   400000
# 2         4.0  1000000
# 3         3.8   300000
# 4         4.4   600000
# ...       ...      ...
# 22769     4.7   200000
# 22770     4.0   300000
# 22771     4.1   192000
# 22772     4.1   300000
# 22773     3.8   300000
#
# [22774 rows x 2 columns]

# %%
type(df_2_cols)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[["Rating"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.Rating
# Out:
# 0        3.8
# 1        4.5
# 2        4.0
# 3        3.8
# 4        4.4
#         ...
# 22769    4.7
# 22770    4.0
# 22771    4.1
# 22772    4.1
# 22773    3.8
# Name: Rating, Length: 22774, dtype: float64

# %%
df.loc[:,"Rating"]
# Out:
# 0        3.8
# 1        4.5
# 2        4.0
# 3        3.8
# 4        4.4
#         ...
# 22769    4.7
# 22770    4.0
# 22771    4.1
# 22772    4.1
# 22773    3.8
# Name: Rating, Length: 22774, dtype: float64

# %%
df.loc[:,["Rating","Company Name"]]
# Out:
#        Rating                      Company Name
# 0         3.8                            Sasken
# 1         4.5  Advanced Millennium Technologies
# 2         4.0                         Unacademy
# 3         3.8                SnapBizz Cloudtech
# 4         4.4            Appoids Tech Solutions
# ...       ...                               ...
# 22769     4.7                  Expert Solutions
# 22770     4.0           Nextgen Innovation Labs
# 22771     4.1                           Fresher
# 22772     4.1                         Accenture
# 22773     3.8                   Thomson Reuters
#
# [22774 rows x 2 columns]

# %%
df_2=df.loc[:,["Rating","Company Name"]]

df_2.head()
# Out:
#    Rating                      Company Name
# 0     3.8                            Sasken
# 1     4.5  Advanced Millennium Technologies
# 2     4.0                         Unacademy
# 3     3.8                SnapBizz Cloudtech
# 4     4.4            Appoids Tech Solutions

# %%
df[["Rating","Company Name"]]
# Out:
#        Rating                      Company Name
# 0         3.8                            Sasken
# 1         4.5  Advanced Millennium Technologies
# 2         4.0                         Unacademy
# 3         3.8                SnapBizz Cloudtech
# 4         4.4            Appoids Tech Solutions
# ...       ...                               ...
# 22769     4.7                  Expert Solutions
# 22770     4.0           Nextgen Innovation Labs
# 22771     4.1                           Fresher
# 22772     4.1                         Accenture
# 22773     3.8                   Thomson Reuters
#
# [22774 rows x 2 columns]

# %%
df["Job Title"] == "Android Developer"
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 22769    False
# 22770    False
# 22771    False
# 22772    False
# 22773    False
# Name: Job Title, Length: 22774, dtype: bool

# %%
type(df["Job Title"]=="Android Developer")
# Out:
# pandas.core.series.Series

# %%
df[ df["Job Title"]=="Android Developer" ]
# Out:
#       Rating                            Company Name          Job Title  \
# 0        3.8                                  Sasken  Android Developer
# 1        4.5        Advanced Millennium Technologies  Android Developer
# 2        4.0                               Unacademy  Android Developer
# 3        3.8                      SnapBizz Cloudtech  Android Developer
# 4        4.4                  Appoids Tech Solutions  Android Developer
# ...      ...                                     ...                ...
# 2916     4.5                              Grupo FREL  Android Developer
# 2917     3.5                       Pioneer Infoworld  Android Developer
# 2918     3.8  Accurate Innovative Business Solutions  Android Developer
# 2919     3.8                      Massmatic Solution  Android Developer
# 2920     3.8                       Yobiting Infotech  Android Developer
#
#        Salary  Salaries Reported   Location
# 0      400000                  3  Bangalore
# 1      400000                  3  Bangalore
# 2     1000000                  3  Bangalore
# 3      300000                  3  Bangalore
# 4      600000                  3  Bangalore
# ...       ...                ...        ...
# 2916   400000                  1       Pune
# 2917   156000                  1       Pune
# 2918   500000                  1       Pune
# 2919   264000                  1       Pune
# 2920   180000                  1       Pune
#
# [2029 rows x 6 columns]

# %%
mascara1=df["Job Title"]=="Android Developer"

df_filtro1=df[mascara1]

df_filtro1
# Out:
#       Rating                            Company Name          Job Title  \
# 0        3.8                                  Sasken  Android Developer
# 1        4.5        Advanced Millennium Technologies  Android Developer
# 2        4.0                               Unacademy  Android Developer
# 3        3.8                      SnapBizz Cloudtech  Android Developer
# 4        4.4                  Appoids Tech Solutions  Android Developer
# ...      ...                                     ...                ...
# 2916     4.5                              Grupo FREL  Android Developer
# 2917     3.5                       Pioneer Infoworld  Android Developer
# 2918     3.8  Accurate Innovative Business Solutions  Android Developer
# 2919     3.8                      Massmatic Solution  Android Developer
# 2920     3.8                       Yobiting Infotech  Android Developer
#
#        Salary  Salaries Reported   Location
# 0      400000                  3  Bangalore
# 1      400000                  3  Bangalore
# 2     1000000                  3  Bangalore
# 3      300000                  3  Bangalore
# 4      600000                  3  Bangalore
# ...       ...                ...        ...
# 2916   400000                  1       Pune
# 2917   156000                  1       Pune
# 2918   500000                  1       Pune
# 2919   264000                  1       Pune
# 2920   180000                  1       Pune
#
# [2029 rows x 6 columns]

# %%
df_filtro1.shape
# Out:
# (2029, 6)

# %%
df.loc[ df["Job Title"]=="Android Developer" ,["Rating","Company Name"] ]
# Out:
#       Rating                            Company Name
# 0        3.8                                  Sasken
# 1        4.5        Advanced Millennium Technologies
# 2        4.0                               Unacademy
# 3        3.8                      SnapBizz Cloudtech
# 4        4.4                  Appoids Tech Solutions
# ...      ...                                     ...
# 2916     4.5                              Grupo FREL
# 2917     3.5                       Pioneer Infoworld
# 2918     3.8  Accurate Innovative Business Solutions
# 2919     3.8                      Massmatic Solution
# 2920     3.8                       Yobiting Infotech
#
# [2029 rows x 2 columns]

# %%
df["Job Title"]=="Android Developer"
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 22769    False
# 22770    False
# 22771    False
# 22772    False
# 22773    False
# Name: Job Title, Length: 22774, dtype: bool

# %%
cond1=df["Job Title"]=="Android Developer"
cond2=df["Salary"]>1000000

cond_simultaneas=cond1 & cond2

cond_simultaneas
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 22769    False
# 22770    False
# 22771    False
# 22772    False
# 22773    False
# Length: 22774, dtype: bool

# %%
cond1=df["Job Title"]=="Android Developer"
cond2=df["Salary"]>1000000

df[ cond1 & cond2 ]
# Out:
#       Rating                 Company Name          Job Title   Salary  \
# 82       4.3             Ashwin Infotrron  Android Developer  1188000
# 96       4.1                        Dunzo  Android Developer  2800000
# 99       4.0                 Grab (India)  Android Developer  1200000
# 106      4.0          Walmart Global Tech  Android Developer  2300000
# 136      4.0                     Deloitte  Android Developer  1200000
# ...      ...                          ...                ...      ...
# 2715     3.6  Athena Consultancy Services  Android Developer  1400000
# 2731     2.4                       MobiTV  Android Developer  1188000
# 2803     2.5                        Swipe  Android Developer  2500000
# 2852     3.8                     UxExpert  Android Developer  1044000
# 2856     4.0                   Hungryybee  Android Developer  1188000
#
#       Salaries Reported   Location
# 82                    1  Bangalore
# 96                    1  Bangalore
# 99                    1  Bangalore
# 106                   1  Bangalore
# 136                   1  Bangalore
# ...                 ...        ...
# 2715                  1       Pune
# 2731                  1       Pune
# 2803                  1       Pune
# 2852                  1       Pune
# 2856                  1       Pune
#
# [153 rows x 6 columns]

# %%
df[cond_simultaneas]
# Out:
#       Rating                 Company Name          Job Title   Salary  \
# 82       4.3             Ashwin Infotrron  Android Developer  1188000
# 96       4.1                        Dunzo  Android Developer  2800000
# 99       4.0                 Grab (India)  Android Developer  1200000
# 106      4.0          Walmart Global Tech  Android Developer  2300000
# 136      4.0                     Deloitte  Android Developer  1200000
# ...      ...                          ...                ...      ...
# 2715     3.6  Athena Consultancy Services  Android Developer  1400000
# 2731     2.4                       MobiTV  Android Developer  1188000
# 2803     2.5                        Swipe  Android Developer  2500000
# 2852     3.8                     UxExpert  Android Developer  1044000
# 2856     4.0                   Hungryybee  Android Developer  1188000
#
#       Salaries Reported   Location
# 82                    1  Bangalore
# 96                    1  Bangalore
# 99                    1  Bangalore
# 106                   1  Bangalore
# 136                   1  Bangalore
# ...                 ...        ...
# 2715                  1       Pune
# 2731                  1       Pune
# 2803                  1       Pune
# 2852                  1       Pune
# 2856                  1       Pune
#
# [153 rows x 6 columns]

# %%
cond1=df["Job Title"]=="Android Developer"
cond2=df["Salary"]>1000000
cond3=df["Rating"]<=2.5

df[ cond1 & cond2 & cond3 ]
# Out:
#       Rating Company Name          Job Title   Salary  Salaries Reported  \
# 2731     2.4       MobiTV  Android Developer  1188000                  1
# 2803     2.5        Swipe  Android Developer  2500000                  1
#
#      Location
# 2731     Pune
# 2803     Pune

# %%
cond1=df["Job Title"]=="Android Developer"
cond2=df["Salary"]>1000000

df[ cond1 | cond2 ]
# Out:
#        Rating                                Company Name  \
# 0         3.8                                      Sasken
# 1         4.5            Advanced Millennium Technologies
# 2         4.0                                   Unacademy
# 3         3.8                          SnapBizz Cloudtech
# 4         4.4                      Appoids Tech Solutions
# ...       ...                                         ...
# 22679     4.1         Chethan's Charters- GD FEA Employer
# 22685     4.0                                 Alex mercer
# 22703     3.8                                       Wipro
# 22711     4.6                 Regal Software Technologies
# 22752     4.2  Full Time Soluções em Serviços Financeiros
#
#                         Job Title   Salary  Salaries Reported   Location
# 0               Android Developer   400000                  3  Bangalore
# 1               Android Developer   400000                  3  Bangalore
# 2               Android Developer  1000000                  3  Bangalore
# 3               Android Developer   300000                  3  Bangalore
# 4               Android Developer   600000                  3  Bangalore
# ...                           ...      ...                ...        ...
# 22679               Web Developer  2016960                  1  Bangalore
# 22685      Web Developer - Intern  1200000                  1  Bangalore
# 22703  Web Developer - Contractor  1300000                  1  Bangalore
# 22711               Web Developer  1400000                  1  Bangalore
# 22752               Web Developer  1176000                  1  Bangalore
#
# [6118 rows x 6 columns]

# %%
cond1=df["Job Title"]=="Android Developer"
cond2=df["Salary"]>1000000
cond3=df["Rating"]<=2.5

cond4= (cond1 | cond2) & cond3

df[ cond4 ]
# Out:
#        Rating              Company Name                            Job Title  \
# 42        1.0                   Pricyfy                    Android Developer
# 140       2.4        Chromozome Network                    Android Developer
# 147       2.2           ZINOHA PHARMACY                    Android Developer
# 199       2.4               Travelyaari       Android Developer - Contractor
# 217       1.8         Prowide Solutions                    Android Developer
# ...       ...                       ...                                  ...
# 18306     2.4    Toronto Board of Trade  Software Development Engineer (SDE)
# 18562     1.7      A.K.Jha & Associates  Software Development Engineer (SDE)
# 19221     1.0                     ZEVEX      Software Development Engineer I
# 19373     1.3  Coozo Creative Solutions  Software Development Engineer (SDE)
# 21704     2.5       Bosal International                        Test Engineer
#
#         Salary  Salaries Reported   Location
# 42      216000                  2  Bangalore
# 140     192000                  1  Bangalore
# 147     672000                  1  Bangalore
# 199    1200000                  1  Bangalore
# 217     900000                  1  Bangalore
# ...        ...                ...        ...
# 18306  1300000                  1  New Delhi
# 18562  1200000                  1  New Delhi
# 19221  1100000                  1       Pune
# 19373  2500000                  1       Pune
# 21704  1500000                  1  Bangalore
#
# [107 rows x 6 columns]

# %%
df.to_csv("filtro1.csv",sep=";",index=False)

# %%
cond1=df["Job Title"]=="Android Developer"
cond2=df["Salary"]>1000000

df.loc[cond1 & cond2,["Rating","Company Name"] ]
# Out:
#       Rating                 Company Name
# 82       4.3             Ashwin Infotrron
# 96       4.1                        Dunzo
# 99       4.0                 Grab (India)
# 106      4.0          Walmart Global Tech
# 136      4.0                     Deloitte
# ...      ...                          ...
# 2715     3.6  Athena Consultancy Services
# 2731     2.4                       MobiTV
# 2803     2.5                        Swipe
# 2852     3.8                     UxExpert
# 2856     4.0                   Hungryybee
#
# [153 rows x 2 columns]

# %% [markdown]
# ###Medidas de resumen

# %%
df.describe()
# Out:
#              Rating        Salary  Salaries Reported
# count  22774.000000  2.277400e+04       22774.000000
# mean       3.918249  6.953606e+05           1.855625
# std        0.519676  8.843263e+05           6.823078
# min        1.000000  2.112000e+03           1.000000
# 25%        3.700000  3.000000e+05           1.000000
# 50%        3.900000  5.000000e+05           1.000000
# 75%        4.200000  9.000000e+05           1.000000
# max        5.000000  9.000000e+07         361.000000

# %%
df[ ["Rating"] ].describe()
# Out:
#              Rating
# count  22774.000000
# mean       3.918249
# std        0.519676
# min        1.000000
# 25%        3.700000
# 50%        3.900000
# 75%        4.200000
# max        5.000000

# %%
type( df[["Rating"]].describe() )
# Out:
# pandas.core.frame.DataFrame

# %%
df[["Salary"]].describe().loc["min",["Salary"]]
# Out:
# Salary    2112.0
# Name: min, dtype: float64

# %%
df["Salary"].min()
# Out:
# 2112

# %%
salario_minimo=df["Salary"].min()

print("El salario mínimo es: $",salario_minimo)
# Out:
# El salario mínimo es: $ 2112

# %%
df["Salary"].max()
# Out:
# 90000000

# %%
df["Salary"].mean()
# Out:
# 695360.621761658

# %%
df["Salary"].std()
# Out:
# 884326.2972479343

# %%
df["Salary"].median()
# Out:
# 500000.0

# %%
df["Salary"].mode()
# Out:
# 0    300000
# dtype: int64

# %%
df["Salary"].quantile(0.1)
# Out:
# 180000.0

# %%
df[["Salary"]].agg(["min","max","mean","median"])
# Out:
#               Salary
# min     2.112000e+03
# max     9.000000e+07
# mean    6.953606e+05
# median  5.000000e+05

# %% [markdown]
# Cambiar nombre a una columna

# %%
columnas={"Company Name":"Company_Name","Job Title":"Job_Title","Salaries Reported":"Salaries_Reported"}

df_rename_cols=df.rename(columns = columnas)
df_rename_cols.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries_Reported   Location
# 0                  3  Bangalore
# 1                  3  Bangalore
# 2                  3  Bangalore
# 3                  3  Bangalore
# 4                  3  Bangalore

# %%
columnas={"Company Name":"Company_Name","Job Title":"Job_Title","Salaries Reported":"Salaries_Reported"}
df.rename(columns = columnas, inplace = True)
df.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries_Reported   Location
# 0                  3  Bangalore
# 1                  3  Bangalore
# 2                  3  Bangalore
# 3                  3  Bangalore
# 4                  3  Bangalore

# %% [markdown]
# Eliminar columnas o filas

# %%
df.drop("Salaries_Reported", axis="columns", inplace=True)

# %%
df2=df.drop("Salaries_Reported", axis="columns")
df2.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#     Location
# 0  Bangalore
# 1  Bangalore
# 2  Bangalore
# 3  Bangalore
# 4  Bangalore

# %%
df.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries_Reported   Location
# 0                  3  Bangalore
# 1                  3  Bangalore
# 2                  3  Bangalore
# 3                  3  Bangalore
# 4                  3  Bangalore

# %%
df.drop(["Salaries_Reported","Rating"], axis="columns")
# Out:
#                            Company_Name                 Job_Title   Salary  \
# 0                                Sasken         Android Developer   400000
# 1      Advanced Millennium Technologies         Android Developer   400000
# 2                             Unacademy         Android Developer  1000000
# 3                    SnapBizz Cloudtech         Android Developer   300000
# 4                Appoids Tech Solutions         Android Developer   600000
# ...                                 ...                       ...      ...
# 22769                  Expert Solutions             Web Developer   200000
# 22770           Nextgen Innovation Labs             Web Developer   300000
# 22771                           Fresher  Full Stack Web Developer   192000
# 22772                         Accenture  Full Stack Web Developer   300000
# 22773                   Thomson Reuters   Associate Web Developer   300000
#
#         Location
# 0      Bangalore
# 1      Bangalore
# 2      Bangalore
# 3      Bangalore
# 4      Bangalore
# ...          ...
# 22769  Bangalore
# 22770  Bangalore
# 22771  Bangalore
# 22772  Bangalore
# 22773  Bangalore
#
# [22774 rows x 4 columns]

# %%
df.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries_Reported   Location
# 0                  3  Bangalore
# 1                  3  Bangalore
# 2                  3  Bangalore
# 3                  3  Bangalore
# 4                  3  Bangalore

# %%
df_sin_fila0=df.drop(0)
df_sin_fila0.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
# 5     4.2                        Freelancer  Android Developer   100000
#
#    Salaries_Reported   Location
# 1                  3  Bangalore
# 2                  3  Bangalore
# 3                  3  Bangalore
# 4                  3  Bangalore
# 5                  3  Bangalore

# %%
df.head(10)
# Out:
#    Rating                             Company_Name          Job_Title  \
# 0     3.8                                   Sasken  Android Developer
# 1     4.5         Advanced Millennium Technologies  Android Developer
# 2     4.0                                Unacademy  Android Developer
# 3     3.8                       SnapBizz Cloudtech  Android Developer
# 4     4.4                   Appoids Tech Solutions  Android Developer
# 5     4.2                               Freelancer  Android Developer
# 6     3.7                            SQUARE N CUBE  Android Developer
# 7     3.1  Samsung R&D Institute India - Bangalore  Android Developer
# 8     3.7                     DXMinds Technologies  Android Developer
# 9     3.6          Endeavour Software Technologies  Android Developer
#
#     Salary  Salaries_Reported   Location
# 0   400000                  3  Bangalore
# 1   400000                  3  Bangalore
# 2  1000000                  3  Bangalore
# 3   300000                  3  Bangalore
# 4   600000                  3  Bangalore
# 5   100000                  3  Bangalore
# 6   192000                  3  Bangalore
# 7   400000                  3  Bangalore
# 8   300000                  3  Bangalore
# 9   600000                  3  Bangalore

# %%
df.drop(8,inplace=True)
df.head(10)
# Out:
#     Rating                             Company_Name          Job_Title  \
# 0      3.8                                   Sasken  Android Developer
# 1      4.5         Advanced Millennium Technologies  Android Developer
# 2      4.0                                Unacademy  Android Developer
# 3      3.8                       SnapBizz Cloudtech  Android Developer
# 4      4.4                   Appoids Tech Solutions  Android Developer
# 5      4.2                               Freelancer  Android Developer
# 6      3.7                            SQUARE N CUBE  Android Developer
# 7      3.1  Samsung R&D Institute India - Bangalore  Android Developer
# 9      3.6          Endeavour Software Technologies  Android Developer
# 10     3.6                            Craft Silicon  Android Developer
#
#      Salary  Salaries_Reported   Location
# 0    400000                  3  Bangalore
# 1    400000                  3  Bangalore
# 2   1000000                  3  Bangalore
# 3    300000                  3  Bangalore
# 4    600000                  3  Bangalore
# 5    100000                  3  Bangalore
# 6    192000                  3  Bangalore
# 7    400000                  3  Bangalore
# 9    600000                  3  Bangalore
# 10   300000                  3  Bangalore

# %%
df.drop([0,1,2,3])
# Out:
#        Rating                             Company_Name  \
# 4         4.4                   Appoids Tech Solutions
# 5         4.2                               Freelancer
# 6         3.7                            SQUARE N CUBE
# 7         3.1  Samsung R&D Institute India - Bangalore
# 9         3.6          Endeavour Software Technologies
# ...       ...                                      ...
# 22769     4.7                         Expert Solutions
# 22770     4.0                  Nextgen Innovation Labs
# 22771     4.1                                  Fresher
# 22772     4.1                                Accenture
# 22773     3.8                          Thomson Reuters
#
#                       Job_Title  Salary  Salaries_Reported   Location
# 4             Android Developer  600000                  3  Bangalore
# 5             Android Developer  100000                  3  Bangalore
# 6             Android Developer  192000                  3  Bangalore
# 7             Android Developer  400000                  3  Bangalore
# 9             Android Developer  600000                  3  Bangalore
# ...                         ...     ...                ...        ...
# 22769             Web Developer  200000                  1  Bangalore
# 22770             Web Developer  300000                  1  Bangalore
# 22771  Full Stack Web Developer  192000                 13  Bangalore
# 22772  Full Stack Web Developer  300000                  7  Bangalore
# 22773   Associate Web Developer  300000                  7  Bangalore
#
# [22769 rows x 6 columns]

# %%
df[0:3].index
# Out:
# Int64Index([0, 1, 2], dtype='int64')

# %%
df.drop( df[0:3].index )
# Out:
#        Rating                             Company_Name  \
# 3         3.8                       SnapBizz Cloudtech
# 4         4.4                   Appoids Tech Solutions
# 5         4.2                               Freelancer
# 6         3.7                            SQUARE N CUBE
# 7         3.1  Samsung R&D Institute India - Bangalore
# ...       ...                                      ...
# 22769     4.7                         Expert Solutions
# 22770     4.0                  Nextgen Innovation Labs
# 22771     4.1                                  Fresher
# 22772     4.1                                Accenture
# 22773     3.8                          Thomson Reuters
#
#                       Job_Title  Salary  Salaries_Reported   Location
# 3             Android Developer  300000                  3  Bangalore
# 4             Android Developer  600000                  3  Bangalore
# 5             Android Developer  100000                  3  Bangalore
# 6             Android Developer  192000                  3  Bangalore
# 7             Android Developer  400000                  3  Bangalore
# ...                         ...     ...                ...        ...
# 22769             Web Developer  200000                  1  Bangalore
# 22770             Web Developer  300000                  1  Bangalore
# 22771  Full Stack Web Developer  192000                 13  Bangalore
# 22772  Full Stack Web Developer  300000                  7  Bangalore
# 22773   Associate Web Developer  300000                  7  Bangalore
#
# [22771 rows x 6 columns]

# %%
df.drop( [0,1,2,3] )
# Out:
#        Rating                             Company_Name  \
# 4         4.4                   Appoids Tech Solutions
# 5         4.2                               Freelancer
# 6         3.7                            SQUARE N CUBE
# 7         3.1  Samsung R&D Institute India - Bangalore
# 8         3.7                     DXMinds Technologies
# ...       ...                                      ...
# 22769     4.7                         Expert Solutions
# 22770     4.0                  Nextgen Innovation Labs
# 22771     4.1                                  Fresher
# 22772     4.1                                Accenture
# 22773     3.8                          Thomson Reuters
#
#                       Job_Title  Salary  Salaries_Reported   Location
# 4             Android Developer  600000                  3  Bangalore
# 5             Android Developer  100000                  3  Bangalore
# 6             Android Developer  192000                  3  Bangalore
# 7             Android Developer  400000                  3  Bangalore
# 8             Android Developer  300000                  3  Bangalore
# ...                         ...     ...                ...        ...
# 22769             Web Developer  200000                  1  Bangalore
# 22770             Web Developer  300000                  1  Bangalore
# 22771  Full Stack Web Developer  192000                 13  Bangalore
# 22772  Full Stack Web Developer  300000                  7  Bangalore
# 22773   Associate Web Developer  300000                  7  Bangalore
#
# [22770 rows x 6 columns]

# %%
df[df["Job_Title"]=="Android Developer"]
# Out:
#       Rating                            Company_Name          Job_Title  \
# 0        3.8                                  Sasken  Android Developer
# 1        4.5        Advanced Millennium Technologies  Android Developer
# 2        4.0                               Unacademy  Android Developer
# 3        3.8                      SnapBizz Cloudtech  Android Developer
# 4        4.4                  Appoids Tech Solutions  Android Developer
# ...      ...                                     ...                ...
# 2916     4.5                              Grupo FREL  Android Developer
# 2917     3.5                       Pioneer Infoworld  Android Developer
# 2918     3.8  Accurate Innovative Business Solutions  Android Developer
# 2919     3.8                      Massmatic Solution  Android Developer
# 2920     3.8                       Yobiting Infotech  Android Developer
#
#        Salary  Salaries_Reported   Location
# 0      400000                  3  Bangalore
# 1      400000                  3  Bangalore
# 2     1000000                  3  Bangalore
# 3      300000                  3  Bangalore
# 4      600000                  3  Bangalore
# ...       ...                ...        ...
# 2916   400000                  1       Pune
# 2917   156000                  1       Pune
# 2918   500000                  1       Pune
# 2919   264000                  1       Pune
# 2920   180000                  1       Pune
#
# [2028 rows x 6 columns]

# %%
df[df["Job_Title"]=="Android Developer"].index
# Out:
# Int64Index([   0,    1,    2,    3,    4,    5,    6,    7,    9,   10,
#             ...
#             2911, 2912, 2913, 2914, 2915, 2916, 2917, 2918, 2919, 2920],
#            dtype='int64', length=2028)

# %%
df.drop( df[df["Job_Title"]=="Android Developer"].index )
# Out:
#        Rating             Company_Name                   Job_Title  Salary  \
# 13        4.8             Retail Pulse  Android Developer - Intern   24000
# 30        5.0            powerplay app  Android Developer - Intern  396000
# 54        4.7               GreedyGame  Android Developer - Intern  348000
# 62        4.2                   Dcoder  Android Developer - Intern   96000
# 66        4.2         Across The Globe  Android Developer - Intern   72000
# ...       ...                      ...                         ...     ...
# 22769     4.7         Expert Solutions               Web Developer  200000
# 22770     4.0  Nextgen Innovation Labs               Web Developer  300000
# 22771     4.1                  Fresher    Full Stack Web Developer  192000
# 22772     4.1                Accenture    Full Stack Web Developer  300000
# 22773     3.8          Thomson Reuters     Associate Web Developer  300000
#
#        Salaries_Reported   Location
# 13                     2  Bangalore
# 30                     2  Bangalore
# 54                     2  Bangalore
# 62                     2  Bangalore
# 66                     2  Bangalore
# ...                  ...        ...
# 22769                  1  Bangalore
# 22770                  1  Bangalore
# 22771                 13  Bangalore
# 22772                  7  Bangalore
# 22773                  7  Bangalore
#
# [20745 rows x 6 columns]

# %%
cond1=df["Job_Title"]=="Android Developer"
cond2=df["Salary"]<30000

indices_drop=df[cond1 & cond2].index

df.drop( indices_drop )
# Out:
#        Rating                      Company_Name                 Job_Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22769     4.7                  Expert Solutions             Web Developer
# 22770     4.0           Nextgen Innovation Labs             Web Developer
# 22771     4.1                           Fresher  Full Stack Web Developer
# 22772     4.1                         Accenture  Full Stack Web Developer
# 22773     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries_Reported   Location
# 0       400000                  3  Bangalore
# 1       400000                  3  Bangalore
# 2      1000000                  3  Bangalore
# 3       300000                  3  Bangalore
# 4       600000                  3  Bangalore
# ...        ...                ...        ...
# 22769   200000                  1  Bangalore
# 22770   300000                  1  Bangalore
# 22771   192000                 13  Bangalore
# 22772   300000                  7  Bangalore
# 22773   300000                  7  Bangalore
#
# [22771 rows x 6 columns]

# %%
df.drop( df[cond1 ].index )
# Out:
#        Rating             Company_Name                   Job_Title  Salary  \
# 13        4.8             Retail Pulse  Android Developer - Intern   24000
# 30        5.0            powerplay app  Android Developer - Intern  396000
# 54        4.7               GreedyGame  Android Developer - Intern  348000
# 62        4.2                   Dcoder  Android Developer - Intern   96000
# 66        4.2         Across The Globe  Android Developer - Intern   72000
# ...       ...                      ...                         ...     ...
# 22769     4.7         Expert Solutions               Web Developer  200000
# 22770     4.0  Nextgen Innovation Labs               Web Developer  300000
# 22771     4.1                  Fresher    Full Stack Web Developer  192000
# 22772     4.1                Accenture    Full Stack Web Developer  300000
# 22773     3.8          Thomson Reuters     Associate Web Developer  300000
#
#        Salaries_Reported   Location
# 13                     2  Bangalore
# 30                     2  Bangalore
# 54                     2  Bangalore
# 62                     2  Bangalore
# 66                     2  Bangalore
# ...                  ...        ...
# 22769                  1  Bangalore
# 22770                  1  Bangalore
# 22771                 13  Bangalore
# 22772                  7  Bangalore
# 22773                  7  Bangalore
#
# [20745 rows x 6 columns]

# %%
df.drop( df[cond1 ].index ).reset_index()
# Out:
#        index  Rating             Company_Name                   Job_Title  \
# 0         13     4.8             Retail Pulse  Android Developer - Intern
# 1         30     5.0            powerplay app  Android Developer - Intern
# 2         54     4.7               GreedyGame  Android Developer - Intern
# 3         62     4.2                   Dcoder  Android Developer - Intern
# 4         66     4.2         Across The Globe  Android Developer - Intern
# ...      ...     ...                      ...                         ...
# 20740  22769     4.7         Expert Solutions               Web Developer
# 20741  22770     4.0  Nextgen Innovation Labs               Web Developer
# 20742  22771     4.1                  Fresher    Full Stack Web Developer
# 20743  22772     4.1                Accenture    Full Stack Web Developer
# 20744  22773     3.8          Thomson Reuters     Associate Web Developer
#
#        Salary  Salaries_Reported   Location
# 0       24000                  2  Bangalore
# 1      396000                  2  Bangalore
# 2      348000                  2  Bangalore
# 3       96000                  2  Bangalore
# 4       72000                  2  Bangalore
# ...       ...                ...        ...
# 20740  200000                  1  Bangalore
# 20741  300000                  1  Bangalore
# 20742  192000                 13  Bangalore
# 20743  300000                  7  Bangalore
# 20744  300000                  7  Bangalore
#
# [20745 rows x 7 columns]

# %% [markdown]
# ### Modificación de valores

# %%
cond1=df["Job_Title"]=="Android Developer"
cond2=df["Salary"]<30000

df.loc[cond1 & cond2,["Rating"]]=10

df.loc[cond1 & cond2]
# Out:
#       Rating           Company_Name          Job_Title  Salary  \
# 1980    10.0             Freelancer  Android Developer   21120
# 2291    10.0      VVDN Technologies  Android Developer   14784
# 2472    10.0  Acmatics Technologies  Android Developer   12000
#
#       Salaries_Reported   Location
# 1980                  1  New Delhi
# 2291                  1  New Delhi
# 2472                  1  New Delhi

# %%
df.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 0  1000.0                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries_Reported   Location
# 0                  3  Bangalore
# 1                  3  Bangalore
# 2                  3  Bangalore
# 3                  3  Bangalore
# 4                  3  Bangalore

# %%
df.iloc[0,0]=1000

df.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 0  1000.0                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries_Reported   Location
# 0                  3  Bangalore
# 1                  3  Bangalore
# 2                  3  Bangalore
# 3                  3  Bangalore
# 4                  3  Bangalore

# %% [markdown]
# ### Creación de nuevas columnas

# %%
df["Relative_Salary"] = df["Salary"] / df["Salary"].max()
df.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 0   100.0                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries_Reported   Location  Relative_Salary
# 0                  3  Bangalore         0.004444
# 1                  3  Bangalore         0.004444
# 2                  3  Bangalore         0.011111
# 3                  3  Bangalore         0.003333
# 4                  3  Bangalore         0.006667

# %%
df.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 0   100.0                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries_Reported   Location  Relative_Salary
# 0                  3  Bangalore         0.004444
# 1                  3  Bangalore         0.004444
# 2                  3  Bangalore         0.011111
# 3                  3  Bangalore         0.003333
# 4                  3  Bangalore         0.006667

# %%
salario_maximo=df["Salary"].max()
df["Relative_Salary"]=df["Salary"]/salario_maximo
df.head()
# Out:
#    Rating                      Company_Name          Job_Title   Salary  \
# 0  1000.0                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries_Reported   Location  Relative_Salary
# 0                  3  Bangalore         0.004444
# 1                  3  Bangalore         0.004444
# 2                  3  Bangalore         0.011111
# 3                  3  Bangalore         0.003333
# 4                  3  Bangalore         0.006667

# %% [markdown]
# #### Apply

# %%
df["Rating"]
# Out:
# 0        3.8
# 1        4.5
# 2        4.0
# 3        3.8
# 4        4.4
#         ...
# 22769    4.7
# 22770    4.0
# 22771    4.1
# 22772    4.1
# 22773    3.8
# Name: Rating, Length: 22774, dtype: float64

# %%
def rating_cat(rating):
  level="Bajo"
  if rating>=2 and rating<4:
    level="Medio"
  elif rating>=4:
    level="Alto"

  return level

df["Rating_category"]=df["Rating"].apply(rating_cat)
df.head(10)
# Out:
#    Rating                             Company Name          Job Title  \
# 0     3.8                                   Sasken  Android Developer
# 1     4.5         Advanced Millennium Technologies  Android Developer
# 2     4.0                                Unacademy  Android Developer
# 3     3.8                       SnapBizz Cloudtech  Android Developer
# 4     4.4                   Appoids Tech Solutions  Android Developer
# 5     4.2                               Freelancer  Android Developer
# 6     3.7                            SQUARE N CUBE  Android Developer
# 7     3.1  Samsung R&D Institute India - Bangalore  Android Developer
# 8     3.7                     DXMinds Technologies  Android Developer
# 9     3.6          Endeavour Software Technologies  Android Developer
#
#     Salary  Salaries Reported   Location  Relative_Salary Rating_category
# 0   400000                  3  Bangalore         0.004444           Medio
# 1   400000                  3  Bangalore         0.004444            Alto
# 2  1000000                  3  Bangalore         0.011111            Alto
# 3   300000                  3  Bangalore         0.003333           Medio
# 4   600000                  3  Bangalore         0.006667            Alto
# 5   100000                  3  Bangalore         0.001111            Alto
# 6   192000                  3  Bangalore         0.002133           Medio
# 7   400000                  3  Bangalore         0.004444           Medio
# 8   300000                  3  Bangalore         0.003333           Medio
# 9   600000                  3  Bangalore         0.006667           Medio

# %%
def rating_cat_fila(fila):
  level="Bajo"
  if fila["Rating"]>=2 and fila["Rating"]<4:
    level="Medio"
  elif fila["Rating"]>=4:
    level="Alto"

  return level

df["Rating_category"]=df.apply(rating_cat_fila,axis="columns")
df.head(10)
# Out:
#    Rating                             Company_Name          Job_Title  \
# 0     3.8                                   Sasken  Android Developer
# 1     4.5         Advanced Millennium Technologies  Android Developer
# 2     4.0                                Unacademy  Android Developer
# 3     3.8                       SnapBizz Cloudtech  Android Developer
# 4     4.4                   Appoids Tech Solutions  Android Developer
# 5     4.2                               Freelancer  Android Developer
# 6     3.7                            SQUARE N CUBE  Android Developer
# 7     3.1  Samsung R&D Institute India - Bangalore  Android Developer
# 8     3.7                     DXMinds Technologies  Android Developer
# 9     3.6          Endeavour Software Technologies  Android Developer
#
#     Salary  Salaries_Reported   Location Rating_category
# 0   400000                  3  Bangalore           Medio
# 1   400000                  3  Bangalore            Alto
# 2  1000000                  3  Bangalore            Alto
# 3   300000                  3  Bangalore           Medio
# 4   600000                  3  Bangalore            Alto
# 5   100000                  3  Bangalore            Alto
# 6   192000                  3  Bangalore           Medio
# 7   400000                  3  Bangalore           Medio
# 8   300000                  3  Bangalore           Medio
# 9   600000                  3  Bangalore           Medio

# %%
def salary_porc(fila):
  if fila["Company_Name"]=="Sasken":
    porc_salary=fila["Salary"]*0.01
  else:
    porc_salary=fila["Salary"]*0.21

  return porc_salary

df["Salary_porc"]=df.apply(salary_porc,axis="columns")
df.head(10)
# Out:
#     Rating                             Company_Name          Job_Title  \
# 0   1000.0                                   Sasken  Android Developer
# 1      4.5         Advanced Millennium Technologies  Android Developer
# 2      4.0                                Unacademy  Android Developer
# 3      3.8                       SnapBizz Cloudtech  Android Developer
# 4      4.4                   Appoids Tech Solutions  Android Developer
# 5      4.2                               Freelancer  Android Developer
# 6      3.7                            SQUARE N CUBE  Android Developer
# 7      3.1  Samsung R&D Institute India - Bangalore  Android Developer
# 9      3.6          Endeavour Software Technologies  Android Developer
# 10     3.6                            Craft Silicon  Android Developer
#
#      Salary  Salaries_Reported   Location  Relative_Salary  Salary_porc
# 0    400000                  3  Bangalore         0.004444       4000.0
# 1    400000                  3  Bangalore         0.004444      84000.0
# 2   1000000                  3  Bangalore         0.011111     210000.0
# 3    300000                  3  Bangalore         0.003333      63000.0
# 4    600000                  3  Bangalore         0.006667     126000.0
# 5    100000                  3  Bangalore         0.001111      21000.0
# 6    192000                  3  Bangalore         0.002133      40320.0
# 7    400000                  3  Bangalore         0.004444      84000.0
# 9    600000                  3  Bangalore         0.006667     126000.0
# 10   300000                  3  Bangalore         0.003333      63000.0

# %%
df["Rating_category_lambda"]=df["Rating"].apply(lambda rating: "Bajo" if rating<2 else ("Medio" if (rating>=2 and rating<4) else "Alto") )
df.head(10)
# Out:
#    Rating                             Company_Name          Job_Title  \
# 0     3.8                                   Sasken  Android Developer
# 1     4.5         Advanced Millennium Technologies  Android Developer
# 2     4.0                                Unacademy  Android Developer
# 3     3.8                       SnapBizz Cloudtech  Android Developer
# 4     4.4                   Appoids Tech Solutions  Android Developer
# 5     4.2                               Freelancer  Android Developer
# 6     3.7                            SQUARE N CUBE  Android Developer
# 7     3.1  Samsung R&D Institute India - Bangalore  Android Developer
# 8     3.7                     DXMinds Technologies  Android Developer
# 9     3.6          Endeavour Software Technologies  Android Developer
#
#     Salary  Salaries_Reported   Location Rating_category  \
# 0   400000                  3  Bangalore           Medio
# 1   400000                  3  Bangalore            Alto
# 2  1000000                  3  Bangalore            Alto
# 3   300000                  3  Bangalore           Medio
# 4   600000                  3  Bangalore            Alto
# 5   100000                  3  Bangalore            Alto
# 6   192000                  3  Bangalore           Medio
# 7   400000                  3  Bangalore           Medio
# 8   300000                  3  Bangalore           Medio
# 9   600000                  3  Bangalore           Medio
#
#   Rating_category_lambda
# 0                  Medio
# 1                   Alto
# 2                   Alto
# 3                  Medio
# 4                   Alto
# 5                   Alto
# 6                  Medio
# 7                  Medio
# 8                  Medio
# 9                  Medio

# %% [markdown]
# ### Ordenamiento

# %%
df.sort_values(by="Salary")
# Out:
#        Rating         Company Name  \
# 22567     2.6  Keeves Technologies
# 9939      3.7              Virtusa
# 5465      4.1             Scholify
# 13988     4.3           Webboombaa
# 15079     3.8                  XYZ
# ...       ...                  ...
# 5821      3.7       Nityo Infotech
# 7123      3.5       Koru UX Design
# 4473      3.8           Concentrix
# 9262      3.6    OASYS Cybernetics
# 18639     3.6    Thapar University
#
#                                            Job Title    Salary  \
# 22567                         Web Developer - Intern      2112
# 9939                           Junior Java Developer      8448
# 5465                    Front End Developer - Intern     12000
# 13988         Software Development Engineer - Intern     12000
# 15079   Software Development Engineer (SDE) - Intern     12000
# ...                                              ...       ...
# 5821   Lead UI Designer, Magento Front-end Developer   9900000
# 7123                      Senior Front End Developer  10000000
# 4473                   Oracle Database Administrator  10000000
# 9262                           Senior Java Developer  10000000
# 18639            Software Development Engineer (SDE)  90000000
#
#        Salaries Reported   Location
# 22567                  1  Bangalore
# 9939                   5  Hyderabad
# 5465                   1  Bangalore
# 13988                  1    Chennai
# 15079                  1  Hyderabad
# ...                  ...        ...
# 5821                   1  Bangalore
# 7123                   1       Pune
# 4473                   1  Bangalore
# 9262                   1    Chennai
# 18639                  1  New Delhi
#
# [22774 rows x 6 columns]

# %%
df.sort_values(by="Salary",ascending=[False])
# Out:
#        Rating                 Company Name  \
# 18639     3.6            Thapar University
# 4473      3.8                   Concentrix
# 9262      3.6            OASYS Cybernetics
# 7123      3.5               Koru UX Design
# 5821      3.7               Nityo Infotech
# ...       ...                          ...
# 10318     3.9            Awign Enterprises
# 16842     4.4   Excel Engineering Services
# 5550      4.0  Nasya Software Technologies
# 9939      3.7                      Virtusa
# 22567     2.6          Keeves Technologies
#
#                                            Job Title    Salary  \
# 18639            Software Development Engineer (SDE)  90000000
# 4473                   Oracle Database Administrator  10000000
# 9262                           Senior Java Developer  10000000
# 7123                      Senior Front End Developer  10000000
# 5821   Lead UI Designer, Magento Front-end Developer   9900000
# ...                                              ...       ...
# 10318               Senior Java Developer Contractor     12000
# 16842           Senior Software Development Engineer     12000
# 5550                    Front End Developer - Intern     12000
# 9939                           Junior Java Developer      8448
# 22567                         Web Developer - Intern      2112
#
#        Salaries Reported   Location
# 18639                  1  New Delhi
# 4473                   1  Bangalore
# 9262                   1    Chennai
# 7123                   1       Pune
# 5821                   1  Bangalore
# ...                  ...        ...
# 10318                  1  Hyderabad
# 16842                  1     Mumbai
# 5550                   1  Bangalore
# 9939                   5  Hyderabad
# 22567                  1  Bangalore
#
# [22774 rows x 6 columns]

# %%
df_sorted=df.sort_values(by=["Salary","Job_Title"],ascending=[False,True])
df_sorted.head(5)
# Out:
#        Rating       Company_Name  \
# 18639     3.6  Thapar University
# 4473      3.8         Concentrix
# 7123      3.5     Koru UX Design
# 9262      3.6  OASYS Cybernetics
# 5821      3.7     Nityo Infotech
#
#                                            Job_Title    Salary  \
# 18639            Software Development Engineer (SDE)  90000000
# 4473                   Oracle Database Administrator  10000000
# 7123                      Senior Front End Developer  10000000
# 9262                           Senior Java Developer  10000000
# 5821   Lead UI Designer, Magento Front-end Developer   9900000
#
#        Salaries_Reported   Location  Relative_Salary  Salary_21_porc
# 18639                  1  New Delhi         1.000000      18900000.0
# 4473                   1  Bangalore         0.111111       2100000.0
# 7123                   1       Pune         0.111111       2100000.0
# 9262                   1    Chennai         0.111111       2100000.0
# 5821                   1  Bangalore         0.110000       2079000.0

# %% [markdown]
# # Ejemplo 2

# %%
ds_trabajo2=pd.read_csv('tiranic.csv')

# %%
pd.crosstab( ds_trabajo2['Survived'] , ds_trabajo2['Sex'] )
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
ds_trabajo2.groupby(['PassengerClass','Sex'])['Survived'].sum()
# Out:
# PassengerClass  Sex
# 1               female    91
#                 male      45
# 2               female    70
#                 male      17
# 3               female    72
#                 male      47
# Name: Survived, dtype: int64

# %% [markdown]
# Mostrar información de resumen del dataset

# %%
ds_trabajo2.describe()
# Out:
#        PassengerId    Survived  PassengerClass         Age       SibSp  \
# count   891.000000  891.000000      891.000000  714.000000  891.000000
# mean    446.000000    0.383838        2.308642   29.699118    0.523008
# std     257.353842    0.486592        0.836071   14.526497    1.102743
# min       1.000000    0.000000        1.000000    0.420000    0.000000
# 25%     223.500000    0.000000        2.000000   20.125000    0.000000
# 50%     446.000000    0.000000        3.000000   28.000000    0.000000
# 75%     668.500000    1.000000        3.000000   38.000000    1.000000
# max     891.000000    1.000000        3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Seleccionar fila por posición

# %%
ds_trabajo2.iloc[0]
# Out:
# PassengerId                             1
# Survived                                0
# PassengerClass                          3
# Name              Braund, Mr. Owen Harris
# Sex                                  male
# Age                                  22.0
# SibSp                                   1
# Parch                                   0
# Ticket                          A/5 21171
# Fare                                 7.25
# Cabin                                 NaN
# Embarked                                S
# Name: 0, dtype: object

# %% [markdown]
# Seleccionar columna por posición

# %%
ds_trabajo2.iloc[:,0]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %% [markdown]
# ##### Seleccionar columna por nombre

# %%
ds_trabajo2.PassengerId
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
ds_trabajo2["PassengerId"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
ds_trabajo2.loc[:,"PassengerId"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
ds_trabajo2.loc[:,["PassengerId","Age"]]
# Out:
#      PassengerId   Age
# 0              1  22.0
# 1              2  38.0
# 2              3  26.0
# 3              4  35.0
# 4              5  35.0
# ..           ...   ...
# 886          887  27.0
# 887          888  19.0
# 888          889   NaN
# 889          890  26.0
# 890          891  32.0
#
# [891 rows x 2 columns]

# %% [markdown]
# ##### Selección de filas en función de características de columnas

# %%
ds_trabajo2.loc[:,"Survived"]==1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
ds_trabajo2["Survived"]==1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
ds_trabajo2.loc[ds_trabajo.loc[:,"Survived"]==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 875      0              2667   7.2250   NaN        C
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
#
# [342 rows x 12 columns]

# %% [markdown]
# Seleccionar filas utilizando múltiples condiciones

# %%
ds_trabajo2.loc[ (ds_trabajo2["Survived"]==1) & (ds_trabajo2["Age"]>30) ]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 21            22         1       2
# ..           ...       ...     ...
# 857          858         1       1
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# ..                                                 ...     ...   ...    ...
# 857                             Daly, Mr. Peter Denis     male  51.0      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 1        0  PC 17599  71.2833   C85        C
# 3        0    113803  53.1000  C123        S
# 11       0    113783  26.5500  C103        S
# 15       0    248706  16.0000   NaN        S
# 21       0    248698  13.0000   D56        S
# ..     ...       ...      ...   ...      ...
# 857      0    113055  26.5500   E17        S
# 862      0     17466  25.9292   D17        S
# 865      0    236852  13.0000   NaN        S
# 871      1     11751  52.5542   D35        S
# 879      1     11767  83.1583   C50        C
#
# [124 rows x 12 columns]

# %%
cond1=ds_trabajo2["Survived"]==1
cond2=ds_trabajo2["Age"]>30

ds_trabajo.loc[ cond1 & cond2 ]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 21            22         1       2
# ..           ...       ...     ...
# 857          858         1       1
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# ..                                                 ...     ...   ...    ...
# 857                             Daly, Mr. Peter Denis     male  51.0      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 1        0  PC 17599  71.2833   C85        C
# 3        0    113803  53.1000  C123        S
# 11       0    113783  26.5500  C103        S
# 15       0    248706  16.0000   NaN        S
# 21       0    248698  13.0000   D56        S
# ..     ...       ...      ...   ...      ...
# 857      0    113055  26.5500   E17        S
# 862      0     17466  25.9292   D17        S
# 865      0    236852  13.0000   NaN        S
# 871      1     11751  52.5542   D35        S
# 879      1     11767  83.1583   C50        C
#
# [124 rows x 12 columns]

# %% [markdown]
# ##### Eliminar columma

# %%
ds_trabajo2.drop('PassengerId', axis='columns', inplace=True)  # inplace=True -> Elimina columna sobre el mismo dataframe
ds_trabajo2.columns.tolist()
# Out:
# ['Survived',
#  'PassengerClass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# ##### Eliminar fila por condición

# %%
ds_trabajo_sobrevivientes=ds_trabajo.copy()
ds_trabajo_sobrevivientes.drop(ds_trabajo2[ds_trabajo2["Survived"]==0].index, axis='index',inplace=True)
ds_trabajo_sobrevivientes.shape
# Out:
# (342, 11)

# %%
ds_trabajo_sobrevivientes=ds_trabajo2.copy()
ds_trabajo_sobrevivientes.drop(ds_trabajo2.loc[ds_trabajo2.loc[:,"Survived"]==0,:].index, axis='index', inplace=True)
ds_trabajo_sobrevivientes.shape
# Out:
# (342, 11)

# %%
ds_trabajo_sobrevivientes.head()
# Out:
#    Survived  PassengerClass  \
# 1         1               1
# 2         1               3
# 3         1               1
# 8         1               3
# 9         1               2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# ##### Cambiar valores de features

# %%
ds_trabajo_reemplazo_valores=ds_trabajo2.copy()

ds_trabajo_reemplazo_valores.loc[ds_trabajo_reemplazo_valores.loc[:,"Survived"]==1,"Survived"]="Yes"
ds_trabajo_reemplazo_valores.loc[ds_trabajo_reemplazo_valores.loc[:,"Survived"]==0,"Survived"]="No"

ds_trabajo_reemplazo_valores.head()
# Out:
#    PassengerId Survived  PassengerClass  \
# 0            1       No               3
# 1            2      Yes               1
# 2            3      Yes               3
# 3            4      Yes               1
# 4            5       No               3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ds_trabajo2.loc[:,"Survived"].replace(to_replace=[0,1],value=["No","Yes"],inplace=True)

ds_trabajo2.head()
# Out:
#   Survived  PassengerClass                                               Name  \
# 0       No               3                            Braund, Mr. Owen Harris
# 1      Yes               1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      Yes               3                             Heikkinen, Miss. Laina
# 3      Yes               1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       No               3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# Apply

# %%
def mayor_edad(edad):
    if edad >= 21:
        return "mayor"
    else:
        return "menor"

# %%
ds_trabajo2['mayor_edad'] = ds_trabajo2['Age'].apply(mayor_edad)

# %%
ds_trabajo2.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked mayor_edad
# 0      0         A/5 21171   7.2500   NaN        S      mayor
# 1      0          PC 17599  71.2833   C85        C      mayor
# 2      0  STON/O2. 3101282   7.9250   NaN        S      mayor
# 3      0            113803  53.1000  C123        S      mayor
# 4      0            373450   8.0500   NaN        S      mayor
# 5      0            330877   8.4583   NaN        Q      menor
# 6      0             17463  51.8625   E46        S      mayor
# 7      1            349909  21.0750   NaN        S      menor
# 8      2            347742  11.1333   NaN        S      mayor
# 9      0            237736  30.0708   NaN        C      menor

# %%
#El mismo ejemplo anterior pero usando lambda

ds_trabajo2['mayor_edad'] = ds_trabajo2['Age'].apply(lambda x: "Mayor" if x>=21 else "Menor")
ds_trabajo2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked mayor_edad valor_ticket
# 0      0         A/5 21171   7.2500   NaN        S      Mayor       Barato
# 1      0          PC 17599  71.2833   C85        C      Mayor         Caro
# 2      0  STON/O2. 3101282   7.9250   NaN        S      Mayor       Barato
# 3      0            113803  53.1000  C123        S      Mayor         Caro
# 4      0            373450   8.0500   NaN        S      Mayor       Barato

# %% [markdown]
# # Unión de DataFrames
#
# https://pandas.pydata.org/docs/user_guide/merging.html

# %% [markdown]
# Concat

# %%
d1 = {"Nombre": ["Pedro", "Juan"],
      "id": [1, 2]}
d2 = {"Nombre": "Mariano",
      "id": 3}

df1 = pd.DataFrame(d1, index= [1, 2])
df2 = pd.DataFrame(d2, index=[3])

df3 = pd.concat([df1, df2])

df3
# Out:
#     Nombre  id
# 1    Pedro   1
# 2     Juan   2
# 3  Mariano   3

# %%
df1.head()
# Out:
#   Nombre  id
# 1  Pedro   1
# 2   Juan   2

# %%
df1.head()
# Out:
#   Nombre  id
# 1  Pedro   1
# 2   Juan   2

# %%
df2.head()
# Out:
#    Profesión
# 1     Médico
# 2  Ingeniero

# %%
d1 = {"Nombre": ["Pedro", "Juan"],
      "id": [1, 2]}
d2 = {"Profesión": ["Médico", "Ingeniero"]}

df1 = pd.DataFrame(d1, index=[1, 2])
df2 = pd.DataFrame(d2, index=[1, 2])

df3 = pd.concat([df1, df2], axis=1)
df3
# Out:
#   Nombre  id  Profesión
# 1  Pedro   1     Médico
# 2   Juan   2  Ingeniero

# %% [markdown]
# Merge

# %%
d1 = {"Nombre": ["Pedro", "Juan","Pablo"],
      "id": [1, 2, 3],
      "id_profesion": [1,2,1]}

d2 = {"Profesión": ["Médico", "Ingeniero"],
       "id_profesion": [1,2]
      }

df1 = pd.DataFrame(d1, index=[1, 2,3])
df2 = pd.DataFrame(d2, index=[1, 2])

result = pd.merge(df1,df2)
result
# Out:
#   Nombre  id  id_profesion  Profesión
# 0  Pedro   1             1     Médico
# 1   Juan   2             2  Ingeniero
# 2  Pablo   3             1     Médico

# %%
d1 = {"Nombre": ["Pedro", "Juan","Pablo","Manuel"],
      "id": [1, 2, 3, 4],
      "id_profesion": [1,2,1,3]}

d2 = {"Profesión": ["Médico", "Ingeniero"],
       "id_profesion": [1,2]
      }

df1 = pd.DataFrame(d1, index={1, 2,3,4})
df2 = pd.DataFrame(d2, index={1, 2})

result = pd.merge(df1,df2,how='inner')
result
# Out:
#   Nombre  id  id_profesion  Profesión
# 0  Pedro   1             1     Médico
# 1  Pablo   3             1     Médico
# 2   Juan   2             2  Ingeniero

# %%
d1 = {"Nombre": ["Pedro", "Juan","Pablo","Manuel"],
      "id": [1, 2, 3, 4],
      "id_profesion": [1,2,1,3]}

d2 = {"Profesión": ["Médico", "Ingeniero"],
       "id_profesion": [1,2]
      }

df1 = pd.DataFrame(d1, index={1, 2,3,4})
df2 = pd.DataFrame(d2, index={1, 2})

result = pd.merge(df1,df2,how='outer')
result
# Out:
#    Nombre  id  id_profesion  Profesión
# 0   Pedro   1             1     Médico
# 1   Pablo   3             1     Médico
# 2    Juan   2             2  Ingeniero
# 3  Manuel   4             3        NaN

# %%
d1 = {"Nombre": ["Pedro", "Juan","Pablo","Manuel"],
      "id": [1, 2, 3, 4],
      "id_profesion": [1,2,1,3]}

d2 = {"Profesión": ["Médico", "Ingeniero"],
       "id_profesion": [1,2]
      }

df1 = pd.DataFrame(d1, index={1, 2,3,4})
df2 = pd.DataFrame(d2, index={1, 2})

result = pd.merge(df1,df2,how='left')
result
# Out:
#    Nombre  id  id_profesion  Profesión
# 0   Pedro   1             1     Médico
# 1    Juan   2             2  Ingeniero
# 2   Pablo   3             1     Médico
# 3  Manuel   4             3        NaN

# %%
d1 = {"Nombre": ["Pedro", "Juan","Pablo","Manuel"],
      "id": [1, 2, 3, 4],
      "id_profesion": [1,2,1,3]}

d2 = {"Profesión": ["Médico", "Ingeniero"],
       "id_profesion": [1,2]
      }

df1 = pd.DataFrame(d1, index={1, 2,3,4})
df2 = pd.DataFrame(d2, index={1, 2})

result = pd.merge(df1,df2,how='right')
result

# %%
d1 = {"Nombre": ["Pedro", "Juan","Pablo","Manuel"],
      "id": [1, 2, 3, 4],
      "id_profesion": [1,2,1,3]}

d2 = {"Profesión": ["Médico", "Ingeniero"],
       "id_profesion": [1,2]
      }

df1 = pd.DataFrame(d1, index={1, 2,3,4})
df2 = pd.DataFrame(d2, index={1, 2})

result = pd.merge(df1,df2,how='right',left_on="id_profesion",right_on="id_profesion")
result
