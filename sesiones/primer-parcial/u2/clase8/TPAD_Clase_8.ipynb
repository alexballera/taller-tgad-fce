# %% [markdown]
# <figure>
# <center>
# <img src='https://www.economicas.uba.ar/wp-content/uploads/2020/08/cropped-logo_FCE.png' />
# </figure>

# %% [markdown]
# # **Universidad de Buenos Aires**
# ## **Facultad de Ciencias Económicas**
#
# ### **Taller de Programación para el Análisis de Datos**
#
# #### **Clase 8: Manipulación de datos**

# %% [markdown]
# En esta clase veremos multiples funciones para poder realizar diferentes tareas asociadas a lo que se conoce como manipulción de datos

# %% [markdown]
# ###**Librería**

# %%
import pandas as pd

import numpy as np

# %% [markdown]
# ###**Creación de un DataFrame**

# %% [markdown]
# Creación de un DataFrame a partir de un diccionario

# %%
#se crea el diccionario
datos = {'Nombre':['Rosa', 'Pedro', 'Elisa', 'Juan'],
         'Edad':[25, 44, 56, 32],
         'Profesion':['Economista', 'Actuario', 'Contador', 'Administrador'],
         'Salario':[140, 150, 100, 120]
        }
#se convierte a dataframe
df = pd.DataFrame(datos)
df
# Out:
#   Nombre  Edad      Profesion  Salario
# 0   Rosa    25     Economista      140
# 1  Pedro    44       Actuario      150
# 2  Elisa    56       Contador      100
# 3   Juan    32  Administrador      120

# %% [markdown]
# Creación de un DataFrame a partir de una lista anidada

# %%
#creación de la lista anidada
lista = [['Rosa', 25,'Economista',140], ['Pedro', 44,'Actuario',150], ['Elisa', 56,'Contador',100], ['Juan', 32,'Administrador',120]]

#creación del dataframe
df_1=pd.DataFrame(lista, columns=['Nombre', 'Edad', 'Profesion', 'Salario'])
df_1
# Out:
#   Nombre  Edad      Profesion  Salario
# 0   Rosa    25     Economista      140
# 1  Pedro    44       Actuario      150
# 2  Elisa    56       Contador      100
# 3   Juan    32  Administrador      120

# %% [markdown]
# Creación de un DataFrame a partir de un un array (matriz)

# %%
#creación de un array
array = np.array([['Rosa', 25,'Economista',140], ['Pedro', 44,'Actuario',150], ['Elisa', 56,'Contador',100], ['Juan', 32,'Administrador',120]])

#creación del dataframe
df_2=pd.DataFrame(array, columns=['Nombre', 'Edad', 'Profesion', 'Salario'])
df_2
# Out:
#   Nombre Edad      Profesion Salario
# 0   Rosa   25     Economista     140
# 1  Pedro   44       Actuario     150
# 2  Elisa   56       Contador     100
# 3   Juan   32  Administrador     120

# %% [markdown]
# ### **Creación de un DataFrame a partir de un archivo de datos**

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("parthpatel2130/realistic-loan-approval-dataset-us-and-canada")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'realistic-loan-approval-dataset-us-and-canada' dataset.
# Path to dataset files: /kaggle/input/realistic-loan-approval-dataset-us-and-canada

# %%
import os
import glob

csv_files = glob.glob(os.path.join(path, "*.csv"))

if not csv_files:
    raise FileNotFoundError(f"No se encontró ningún archivo .csv en: {path}")

print("CSV encontrado:", csv_files[0])
DATA = pd.read_csv(csv_files[0])
DATA
# Out:
# CSV encontrado: /kaggle/input/realistic-loan-approval-dataset-us-and-canada/Loan_approval_data_2025.csv
#       customer_id  age occupation_status  years_employed  annual_income  \
# 0      CUST100000   40          Employed            17.2          25579
# 1      CUST100001   33          Employed             7.3          43087
# 2      CUST100002   42           Student             1.1          20840
# 3      CUST100003   53           Student             0.5          29147
# 4      CUST100004   32          Employed            12.5          63657
# ...           ...  ...               ...             ...            ...
# 49995  CUST149995   35          Employed             4.3          39449
# 49996  CUST149996   34          Employed             4.4          20496
# 49997  CUST149997   41     Self-Employed             4.8          18743
# 49998  CUST149998   38           Student             0.4          17250
# 49999  CUST149999   53          Employed            17.2          46923
#
# ...

# %% [markdown]
# ### **Atributos de un DataFrame**

# %%
len(DATA)
# Out:
# 50000

# %%
# observamos el número de filas, de columns, el índice fila y columna, el tipo de dato de las columnas, la memoria utilizada
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              50000 non-null  object
#  1   age                      50000 non-null  int64
#  2   occupation_status        50000 non-null  object
#  3   years_employed           50000 non-null  float64
#  4   annual_income            50000 non-null  int64
#  5   credit_score             50000 non-null  int64
#  6   credit_history_years     50000 non-null  float64
#  7   savings_assets           50000 non-null  int64
#  8   current_debt             50000 non-null  int64
#  9   defaults_on_file         50000 non-null  int64
#  10  delinquencies_last_2yrs  50000 non-null  int64
#  11  derogatory_marks         50000 non-null  int64
#  12  product_type             50000 non-null  object
#  13  loan_intent              50000 non-null  object
# ...

# %%
# observamos la cantidad de filas y columnas
DATA.shape
# Out:
# (50000, 20)

# %%
# observamos la cantidad de elementos contenidos en el DataFrame
DATA.size
# Out:
# 1000000

# %%
# observamos el nombre de las columnas
DATA.columns
# Out:
# Index(['customer_id', 'age', 'occupation_status', 'years_employed',
#        'annual_income', 'credit_score', 'credit_history_years',
#        'savings_assets', 'current_debt', 'defaults_on_file',
#        'delinquencies_last_2yrs', 'derogatory_marks', 'product_type',
#        'loan_intent', 'loan_amount', 'interest_rate', 'debt_to_income_ratio',
#        'loan_to_income_ratio', 'payment_to_income_ratio', 'loan_status'],
#       dtype='object')

# %%
# observamos el rango que ocupa el índice fila
DATA.index
# Out:
# RangeIndex(start=0, stop=50000, step=1)

# %%
# observamos el tipo de dato de las columnas
DATA.dtypes
# Out:
# customer_id                 object
# age                          int64
# occupation_status           object
# years_employed             float64
# annual_income                int64
# credit_score                 int64
# credit_history_years       float64
# savings_assets               int64
# current_debt                 int64
# defaults_on_file             int64
# delinquencies_last_2yrs      int64
# derogatory_marks             int64
# product_type                object
# loan_intent                 object
# loan_amount                  int64
# interest_rate              float64
# debt_to_income_ratio       float64
# loan_to_income_ratio       float64
# payment_to_income_ratio    float64
# loan_status                  int64
# dtype: object

# %%
# observamos los 10 primeros registros
DATA.head(10)
# Out:
#   customer_id  age occupation_status  years_employed  annual_income  \
# 0  CUST100000   40          Employed            17.2          25579
# 1  CUST100001   33          Employed             7.3          43087
# 2  CUST100002   42           Student             1.1          20840
# 3  CUST100003   53           Student             0.5          29147
# 4  CUST100004   32          Employed            12.5          63657
# 5  CUST100005   32          Employed            13.4          32015
# 6  CUST100006   53          Employed            22.9          44989
# 7  CUST100007   44     Self-Employed             4.2          80603
# 8  CUST100008   29          Employed             5.9          28416
# 9  CUST100009   41          Employed             7.0          70717
#
#    credit_score  credit_history_years  savings_assets  current_debt  \
# 0           692                   5.3             895         10820
# 1           627                   3.5             169         16550
# ...

# %%
# observamos los 10 útlimos registros
DATA.tail(10)
# Out:
#       customer_id  age occupation_status  years_employed  annual_income  \
# 49990  CUST149990   37          Employed             9.4          37218
# 49991  CUST149991   26          Employed             0.7          22159
# 49992  CUST149992   30          Employed             9.3          24797
# 49993  CUST149993   53          Employed            18.1          36948
# 49994  CUST149994   18          Employed             0.0          64343
# 49995  CUST149995   35          Employed             4.3          39449
# 49996  CUST149996   34          Employed             4.4          20496
# 49997  CUST149997   41     Self-Employed             4.8          18743
# 49998  CUST149998   38           Student             0.4          17250
# 49999  CUST149999   53          Employed            17.2          46923
#
#        credit_score  credit_history_years  savings_assets  current_debt  \
# 49990           588                  11.7            2389         13416
# ...

# %% [markdown]
# ### **Operaciones**

# %%
#obtener los valores únicos de una columna
pd.unique(DATA['defaults_on_file'])
# Out:
# array([0, 1])

# %%
#obtener los valores únicos de una columna
pd.unique(DATA['occupation_status'])
# Out:
# array(['Employed', 'Student', 'Self-Employed'], dtype=object)

# %%
#ordenar el DataFarme por columnas (puede ser una o varias)
DATA.sort_values(by=['customer_id','age'], ascending=True) #si ascending=False oderna de mayor a menor
# Out:
#       customer_id  age occupation_status  years_employed  annual_income  \
# 0      CUST100000   40          Employed            17.2          25579
# 1      CUST100001   33          Employed             7.3          43087
# 2      CUST100002   42           Student             1.1          20840
# 3      CUST100003   53           Student             0.5          29147
# 4      CUST100004   32          Employed            12.5          63657
# ...           ...  ...               ...             ...            ...
# 49995  CUST149995   35          Employed             4.3          39449
# 49996  CUST149996   34          Employed             4.4          20496
# 49997  CUST149997   41     Self-Employed             4.8          18743
# 49998  CUST149998   38           Student             0.4          17250
# 49999  CUST149999   53          Employed            17.2          46923
#
#        credit_score  credit_history_years  savings_assets  current_debt  \
# ...

# %%
#contar la cantidad de casos por agrupamiento
DATA.groupby('loan_status').count()
# Out:
#              customer_id    age  occupation_status  years_employed  \
# loan_status
# 0                  22477  22477              22477           22477
# 1                  27523  27523              27523           27523
#
#              annual_income  credit_score  credit_history_years  \
# loan_status
# 0                    22477         22477                 22477
# 1                    27523         27523                 27523
#
#              savings_assets  current_debt  defaults_on_file  \
# loan_status
# 0                     22477         22477             22477
# 1                     27523         27523             27523
#
#              delinquencies_last_2yrs  derogatory_marks  product_type  \
# loan_status
# 0                              22477             22477         22477
# 1                              27523             27523         27523
#
#              loan_intent  loan_amount  interest_rate  debt_to_income_ratio  \
# loan_status
# ...

# %%
#contar la cantidad de casos sobre una variable, por agrupamiento
DATA.groupby('loan_status').count()['customer_id']
# Out:
# loan_status
# 0    22477
# 1    27523
# Name: customer_id, dtype: int64

# %%
#filtrar
DATA[DATA['age']>=50]
# Out:
#       customer_id  age occupation_status  years_employed  annual_income  \
# 3      CUST100003   53           Student             0.5          29147
# 6      CUST100006   53          Employed            22.9          44989
# 20     CUST100020   52          Employed            31.3          75932
# 31     CUST100031   57     Self-Employed            21.5          38484
# 65     CUST100065   51          Employed            18.7          34543
# ...           ...  ...               ...             ...            ...
# 49969  CUST149969   60          Employed            32.4          76612
# 49978  CUST149978   53           Student             0.8          15000
# 49988  CUST149988   60           Student             1.2          67558
# 49993  CUST149993   53          Employed            18.1          36948
# 49999  CUST149999   53          Employed            17.2          46923
#
#        credit_score  credit_history_years  savings_assets  current_debt  \
# ...

# %%
#filtrar por más de una condición: para esto usamos los operadores vistos
DATA[(DATA['age']>=50) & (DATA['loan_status']==1)]
# Out:
#       customer_id  age occupation_status  years_employed  annual_income  \
# 3      CUST100003   53           Student             0.5          29147
# 6      CUST100006   53          Employed            22.9          44989
# 20     CUST100020   52          Employed            31.3          75932
# 73     CUST100073   53          Employed            33.1          43747
# 106    CUST100106   57     Self-Employed            26.6         116531
# ...           ...  ...               ...             ...            ...
# 49969  CUST149969   60          Employed            32.4          76612
# 49978  CUST149978   53           Student             0.8          15000
# 49988  CUST149988   60           Student             1.2          67558
# 49993  CUST149993   53          Employed            18.1          36948
# 49999  CUST149999   53          Employed            17.2          46923
#
#        credit_score  credit_history_years  savings_assets  current_debt  \
# ...

# %%
#filtrar por más de una condición: para esto usamos los operadores vistos
DATA[(DATA['age']>=60) | (DATA['age']<18)]
# Out:
#       customer_id  age occupation_status  years_employed  annual_income  \
# 113    CUST100113   64     Self-Employed            13.3          79988
# 125    CUST100125   61          Employed            38.2         246598
# 179    CUST100179   67           Student             0.0          15841
# 209    CUST100209   70          Employed             0.4          38886
# 220    CUST100220   62          Employed            15.7          65641
# ...           ...  ...               ...             ...            ...
# 49647  CUST149647   62          Employed             3.8          58545
# 49754  CUST149754   66          Employed            32.8          57718
# 49937  CUST149937   69          Employed            21.6          53096
# 49969  CUST149969   60          Employed            32.4          76612
# 49988  CUST149988   60           Student             1.2          67558
#
#        credit_score  credit_history_years  savings_assets  current_debt  \
# ...

# %%
#filtrar por más de una condición: para esto usamos los operadores vistos
DATA[(DATA['age']!=60)]
# Out:
#       customer_id  age occupation_status  years_employed  annual_income  \
# 0      CUST100000   40          Employed            17.2          25579
# 1      CUST100001   33          Employed             7.3          43087
# 2      CUST100002   42           Student             1.1          20840
# 3      CUST100003   53           Student             0.5          29147
# 4      CUST100004   32          Employed            12.5          63657
# ...           ...  ...               ...             ...            ...
# 49995  CUST149995   35          Employed             4.3          39449
# 49996  CUST149996   34          Employed             4.4          20496
# 49997  CUST149997   41     Self-Employed             4.8          18743
# 49998  CUST149998   38           Student             0.4          17250
# 49999  CUST149999   53          Employed            17.2          46923
#
#        credit_score  credit_history_years  savings_assets  current_debt  \
# ...

# %% [markdown]
# **Uso de función agg()**

# %%
#contar casos
DATA.agg('count')
# Out:
# customer_id                50000
# age                        50000
# occupation_status          50000
# years_employed             50000
# annual_income              50000
# credit_score               50000
# credit_history_years       50000
# savings_assets             50000
# current_debt               50000
# defaults_on_file           50000
# delinquencies_last_2yrs    50000
# derogatory_marks           50000
# product_type               50000
# loan_intent                50000
# loan_amount                50000
# interest_rate              50000
# debt_to_income_ratio       50000
# loan_to_income_ratio       50000
# payment_to_income_ratio    50000
# loan_status                50000
# dtype: int64

# %%
#sobre una sola variable
DATA[['occupation_status']].occupation_status.agg('count')
# Out:
# np.int64(50000)

# %%
#si la varible es numérica se pueden utilizar otras medidas

DATA[['age']].age.agg(['min', 'max'])
# Out:
# min    18
# max    70
# Name: age, dtype: int64

# %%
#si la varible es numérica se pueden utilizar otras medidas

DATA[['savings_assets']].agg(['sum'])
# Out:
#      savings_assets
# sum       179780970

# %%
#Agrupar por variables y contar
DATA.groupby(['occupation_status']).agg('count')
# Out:
#                    customer_id    age  years_employed  annual_income  \
# occupation_status
# Employed                 34971  34971           34971          34971
# Self-Employed            10179  10179           10179          10179
# Student                   4850   4850            4850           4850
#
#                    credit_score  credit_history_years  savings_assets  \
# occupation_status
# Employed                  34971                 34971           34971
# Self-Employed             10179                 10179           10179
# Student                    4850                  4850            4850
#
#                    current_debt  defaults_on_file  delinquencies_last_2yrs  \
# occupation_status
# Employed                  34971             34971                    34971
# Self-Employed             10179             10179                    10179
# Student                    4850              4850                     4850
#
# ...

# %%
#Agrupar por variables y contar
DATA.groupby(['occupation_status']).occupation_status.agg('count')
# Out:
# occupation_status
# Employed         34971
# Self-Employed    10179
# Student           4850
# Name: occupation_status, dtype: int64

# %%
#Agrupar por variable y sumar
DATA.groupby(['occupation_status']).savings_assets.agg('sum')
# Out:
# occupation_status
# Employed         124425107
# Self-Employed     46840557
# Student            8515306
# Name: savings_assets, dtype: int64

# %%
#Agrupar por variables y contar
DATA.groupby(['occupation_status', 'age']).occupation_status.agg('count')
# Out:
# occupation_status  age
# Employed           18     3191
#                    19      511
#                    20      587
#                    21      620
#                    22      654
#                           ...
# Student            66        3
#                    67        4
#                    68        1
#                    69        1
#                    70        9
# Name: occupation_status, Length: 159, dtype: int64

# %% [markdown]
# Para poder visualizar de manera completa

# %%
pd.set_option("display.max_rows", 999) #si el problema es con columnas entonces "display.max_columns"

#Agrupar por más de una variables y contar
DATA.groupby(['occupation_status', 'age']).occupation_status.agg('count')
# Out:
# occupation_status  age
# Employed           18     3191
#                    19      511
#                    20      587
#                    21      620
#                    22      654
#                    23      761
#                    24      789
#                    25      911
#                    26      896
#                    27      956
#                    28     1007
#                    29     1014
#                    30     1100
#                    31     1092
#                    32     1100
#                    33     1119
#                    34     1161
#                    35     1200
#                    36     1129
#                    37     1154
#                    38     1079
#                    39     1040
#                    40     1048
#                    41     1030
#                    42      906
#                    43      893
#                    44      898
#                    45      819
#                    46      720
# ...

# %%
#Agrupar por más de una variables y calcular alguna medida
DATA.groupby(['occupation_status', 'product_type']).savings_assets.agg('mean')
# Out:
# occupation_status  product_type
# Employed           Credit Card       3516.660207
#                    Line of Credit    3464.819303
#                    Personal Loan     3664.650421
# Self-Employed      Credit Card       4834.199602
#                    Line of Credit    4168.370334
#                    Personal Loan     4554.804090
# Student            Credit Card       1805.802673
#                    Line of Credit    1748.197849
#                    Personal Loan     1692.808955
# Name: savings_assets, dtype: float64

# %% [markdown]
# Ingresar a los elementos de un DataFrame

# %%
#obtener elementos que se encuentran en la fila 2
DATA.loc[1]
# Out:
# customer_id                      CUST100001
# age                                      33
# occupation_status                  Employed
# years_employed                          7.3
# annual_income                         43087
# credit_score                            627
# credit_history_years                    3.5
# savings_assets                          169
# current_debt                          16550
# defaults_on_file                          0
# delinquencies_last_2yrs                   1
# derogatory_marks                          0
# product_type                  Personal Loan
# loan_intent                Home Improvement
# loan_amount                           53300
# interest_rate                          14.1
# debt_to_income_ratio                  0.384
# loan_to_income_ratio                  1.237
# payment_to_income_ratio               0.412
# loan_status                               0
# Name: 1, dtype: object

# %%
#obtener elementos que se encuentran en la columna 3
DATA.iloc[:,2]
# Out:
# 0             Employed
# 1             Employed
# 2              Student
# 3              Student
# 4             Employed
#              ...
# 49995         Employed
# 49996         Employed
# 49997    Self-Employed
# 49998          Student
# 49999         Employed
# Name: occupation_status, Length: 50000, dtype: object

# %%
#obtener el elelmento que se encuentra en la fila 2 y columna 3
DATA.iloc[1,2]
# Out:
# 'Employed'

# %%
#recorrer el datafrema por indice fila y obtener los datos del cliente 4
for i in DATA.index:
  if i == 3:
    print(DATA.loc[i])
# Out:
# customer_id                 CUST100003
# age                                 53
# occupation_status              Student
# years_employed                     0.5
# annual_income                    29147
# credit_score                       692
# credit_history_years               9.8
# savings_assets                    1480
# current_debt                     11603
# defaults_on_file                     0
# delinquencies_last_2yrs              1
# derogatory_marks                     0
# product_type               Credit Card
# loan_intent                   Business
# loan_amount                       2900
# interest_rate                    18.74
# debt_to_income_ratio             0.398
# loan_to_income_ratio             0.099
# payment_to_income_ratio          0.033
# loan_status                          1
# Name: 3, dtype: object

# %% [markdown]
# ### **Transformaciones**

# %%
DATA.columns
# Out:
# Index(['customer_id', 'age', 'occupation_status', 'years_employed',
#        'annual_income', 'credit_score', 'credit_history_years',
#        'savings_assets', 'current_debt', 'defaults_on_file',
#        'delinquencies_last_2yrs', 'derogatory_marks', 'product_type',
#        'loan_intent', 'loan_amount', 'interest_rate', 'debt_to_income_ratio',
#        'loan_to_income_ratio', 'payment_to_income_ratio', 'loan_status'],
#       dtype='object')

# %%
#renombrar columnas

DATA=DATA.rename(columns={'customer_id':'id', 'age':'edad', 'occupation_status':'ocupacion', 'years_employed':'antiguedad_laboral', 'annual_income':'ingreso_anual',
                          'credit_score':'puntuacion_crediticia' , 'credit_history_years':'historial_crediticio','savings_assets':'ahorros', 'current_debt':'deuda_actual',
                          'defaults_on_file':'default','delinquencies_last_2yrs':'morosidad_ultimos_2años', 'derogatory_marks': 'anotaciones_negativas',
                          'loan_intent':'motivo_solicitud', 'loan_amount':'monto_solicitado', 'interest_rate':'tasa_interes', 'debt_to_income_ratio':'ratio_ingreso_deuda',
                          'loan_to_income_ratio':'ratio_ingreso_prestamo', 'payment_to_income_ratio':'ratio_ingreso_pagos', 'loan_status':'estado_prestamo'})

DATA
# Out:
#                id  edad      ocupacion  antiguedad_laboral  ingreso_anual  \
# 0      CUST100000    40       Employed                17.2          25579
# 1      CUST100001    33       Employed                 7.3          43087
# 2      CUST100002    42        Student                 1.1          20840
# 3      CUST100003    53        Student                 0.5          29147
# 4      CUST100004    32       Employed                12.5          63657
# ...           ...   ...            ...                 ...            ...
# 49995  CUST149995    35       Employed                 4.3          39449
# 49996  CUST149996    34       Employed                 4.4          20496
# 49997  CUST149997    41  Self-Employed                 4.8          18743
# 49998  CUST149998    38        Student                 0.4          17250
# 49999  CUST149999    53       Employed                17.2          46923
#
#        puntuacion_crediticia  historial_crediticio  ahorros  deuda_actual  \
# ...

# %%
#Por ejemplo, pasar a mayúscula todos los nombres de las columnas

DATA.columns = DATA.columns.str.upper()

DATA

#si ahora aplica lower() vuelve a minúscula
# Out:
#                ID  EDAD      OCUPACION  ANTIGUEDAD_LABORAL  INGRESO_ANUAL  \
# 0      CUST100000    40       Employed                17.2          25579
# 1      CUST100001    33       Employed                 7.3          43087
# 2      CUST100002    42        Student                 1.1          20840
# 3      CUST100003    53        Student                 0.5          29147
# 4      CUST100004    32       Employed                12.5          63657
# ...           ...   ...            ...                 ...            ...
# 49995  CUST149995    35       Employed                 4.3          39449
# 49996  CUST149996    34       Employed                 4.4          20496
# 49997  CUST149997    41  Self-Employed                 4.8          18743
# 49998  CUST149998    38        Student                 0.4          17250
# 49999  CUST149999    53       Employed                17.2          46923
#
#        PUNTUACION_CREDITICIA  HISTORIAL_CREDITICIO  AHORROS  DEUDA_ACTUAL  \
# ...

# %%
#borrar columnas

#para no perder el DATA, se realiza una copia

DATA_1=DATA.copy()
DATA_1

DATA_1=DATA_1.drop(['ID'], axis=1) #si se quiere borrar más de una columna, se agregan los nombres separados por coma: por ejemplo: DATA_1.drop(['ID','ANTIGUEDAD_LABORAL','PUNTUACION_CREDITICIA',.....], axis=1)

DATA_1
# Out:
#        EDAD      OCUPACION  ANTIGUEDAD_LABORAL  INGRESO_ANUAL  \
# 0        40       Employed                17.2          25579
# 1        33       Employed                 7.3          43087
# 2        42        Student                 1.1          20840
# 3        53        Student                 0.5          29147
# 4        32       Employed                12.5          63657
# ...     ...            ...                 ...            ...
# 49995    35       Employed                 4.3          39449
# 49996    34       Employed                 4.4          20496
# 49997    41  Self-Employed                 4.8          18743
# 49998    38        Student                 0.4          17250
# 49999    53       Employed                17.2          46923
#
#        PUNTUACION_CREDITICIA  HISTORIAL_CREDITICIO  AHORROS  DEUDA_ACTUAL  \
# 0                        692                   5.3      895         10820
# ...

# %%
#borrar filas

#para no perder el DATA, se continúa con DATA_1

DATA_1=DATA_1.drop([1,2], axis=0) #al indicar 1, 2 se están borrando las filas 2 y 3

DATA_1 #observará que el índice fila ya no es contínuo por lo cual es necesario resetear el índice
# Out:
#        EDAD      OCUPACION  ANTIGUEDAD_LABORAL  INGRESO_ANUAL  \
# 0        40       Employed                17.2          25579
# 3        53        Student                 0.5          29147
# 4        32       Employed                12.5          63657
# 5        32       Employed                13.4          32015
# 6        53       Employed                22.9          44989
# ...     ...            ...                 ...            ...
# 49995    35       Employed                 4.3          39449
# 49996    34       Employed                 4.4          20496
# 49997    41  Self-Employed                 4.8          18743
# 49998    38        Student                 0.4          17250
# 49999    53       Employed                17.2          46923
#
#        PUNTUACION_CREDITICIA  HISTORIAL_CREDITICIO  AHORROS  DEUDA_ACTUAL  \
# 0                        692                   5.3      895         10820
# ...

# %%
#resetear índice fila

DATA_1=DATA_1.reset_index(drop=True)

DATA_1
#ahora observa que es contínuo. Estos siempre debe realizarse proque sino trae problemas en la posterioridad para operar con el
# Out:
#        EDAD      OCUPACION  ANTIGUEDAD_LABORAL  INGRESO_ANUAL  \
# 0        40       Employed                17.2          25579
# 1        53        Student                 0.5          29147
# 2        32       Employed                12.5          63657
# 3        32       Employed                13.4          32015
# 4        53       Employed                22.9          44989
# ...     ...            ...                 ...            ...
# 49993    35       Employed                 4.3          39449
# 49994    34       Employed                 4.4          20496
# 49995    41  Self-Employed                 4.8          18743
# 49996    38        Student                 0.4          17250
# 49997    53       Employed                17.2          46923
#
#        PUNTUACION_CREDITICIA  HISTORIAL_CREDITICIO  AHORROS  DEUDA_ACTUAL  \
# 0                        692                   5.3      895         10820
# ...

# %% [markdown]
# **Crear variables (columnas)**

# %%
#en base a una columna existente, por ejemplo el ingreso en miles
DATA_1['NUEVA_COL']=DATA_1['INGRESO_ANUAL']/1000
DATA_1
# Out:
#        EDAD      OCUPACION  ANTIGUEDAD_LABORAL  INGRESO_ANUAL  \
# 0        40       Employed                17.2          25579
# 1        53        Student                 0.5          29147
# 2        32       Employed                12.5          63657
# 3        32       Employed                13.4          32015
# 4        53       Employed                22.9          44989
# ...     ...            ...                 ...            ...
# 49993    35       Employed                 4.3          39449
# 49994    34       Employed                 4.4          20496
# 49995    41  Self-Employed                 4.8          18743
# 49996    38        Student                 0.4          17250
# 49997    53       Employed                17.2          46923
#
#        PUNTUACION_CREDITICIA  HISTORIAL_CREDITICIO  AHORROS  DEUDA_ACTUAL  \
# 0                        692                   5.3      895         10820
# ...

# %%
#podríamos querer cambiar el tipo de dato de una columna
DATA_1['NUEVA_COL']=DATA_1['NUEVA_COL'].astype('float64')

# %%
#verificamos
DATA_1.dtypes
# Out:
# EDAD                         int64
# OCUPACION                   object
# ANTIGUEDAD_LABORAL         float64
# INGRESO_ANUAL                int64
# PUNTUACION_CREDITICIA        int64
# HISTORIAL_CREDITICIO       float64
# AHORROS                      int64
# DEUDA_ACTUAL                 int64
# DEFAULT                      int64
# MOROSIDAD_ULTIMOS_2AÑOS      int64
# ANOTACIONES_NEGATIVAS        int64
# PRODUCT_TYPE                object
# MOTIVO_SOLICITUD            object
# MONTO_SOLICITADO             int64
# TASA_INTERES               float64
# RATIO_INGRESO_DEUDA        float64
# RATIO_INGRESO_PRESTAMO     float64
# RATIO_INGRESO_PAGOS        float64
# ESTADO_PRESTAMO              int64
# NUEVA_COL                  float64
# dtype: object

# %% [markdown]
# Podriamos querer convertir a string una columna

# %%
#si la variable es binaria: entonces primero

DATA_1['DEFAULT'].unique()
# Out:
# array([0, 1])

# %%
#reconversión sobre la misma columna (sin crear una nueva)
DATA_1['DEFAULT']=["SI" if i==1 else "NO" for i in DATA_1['DEFAULT']]   #esta forma solo sirve para dos categorías de valor
DATA_1
# Out:
#        EDAD      OCUPACION  ANTIGUEDAD_LABORAL  INGRESO_ANUAL  \
# 0        40       Employed                17.2          25579
# 1        53        Student                 0.5          29147
# 2        32       Employed                12.5          63657
# 3        32       Employed                13.4          32015
# 4        53       Employed                22.9          44989
# ...     ...            ...                 ...            ...
# 49993    35       Employed                 4.3          39449
# 49994    34       Employed                 4.4          20496
# 49995    41  Self-Employed                 4.8          18743
# 49996    38        Student                 0.4          17250
# 49997    53       Employed                17.2          46923
#
#        PUNTUACION_CREDITICIA  HISTORIAL_CREDITICIO  AHORROS  DEUDA_ACTUAL  \
# 0                        692                   5.3      895         10820
# ...

# %%
#veo los valores únicos de un campo multicategoría
DATA_1['OCUPACION'].unique()
# Out:
# array(['Employed', 'Student', 'Self-Employed'], dtype=object)

# %%
#convertimos una variable con más de una categoria de valor a string

DATA_1['OCUPACION'].replace({"Student":0 , "Self-Employed":1 ,  "Employed":2},  inplace = True)
#Notese que para esto estamos utilizando un diccionario, del mismo modo que en RENAME

DATA_1.head(10)
# Out:
# /tmp/ipykernel_35598/3171309214.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   DATA_1['OCUPACION'].replace({"Student":0 , "Self-Employed":1 ,  "Employed":2},  inplace = True)
# /tmp/ipykernel_35598/3171309214.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
# volvemos a los valores originales
DATA_1['OCUPACION'].replace({0:"Student" , 1:"Self-Employed" , 2:"Employed"},  inplace = True)

DATA_1.head(10)
# Out:
#    EDAD      OCUPACION  ANTIGUEDAD_LABORAL  INGRESO_ANUAL  \
# 0    40       Employed                17.2          25579
# 1    53        Student                 0.5          29147
# 2    32       Employed                12.5          63657
# 3    32       Employed                13.4          32015
# 4    53       Employed                22.9          44989
# 5    44  Self-Employed                 4.2          80603
# 6    29       Employed                 5.9          28416
# 7    41       Employed                 7.0          70717
# 8    29       Employed                 5.0          15000
# 9    29        Student                 1.3          17029
#
#    PUNTUACION_CREDITICIA  HISTORIAL_CREDITICIO  AHORROS  DEUDA_ACTUAL DEFAULT  \
# 0                    692                   5.3      895         10820      NO
# 1                    692                   9.8     1480         11603      NO
# 2                    630                   7.2      209         12424      NO
# ...

# %% [markdown]
# **Utilización de cat.code: recategoriza a numéros comenzando en 0 por orden albético ascendente**

# %%
DATA_1['OCUPACION_1']=DATA_1['OCUPACION'].astype('category').cat.codes
DATA_1.head(10)
# Out:
#    EDAD      OCUPACION  ANTIGUEDAD_LABORAL  INGRESO_ANUAL  \
# 0    40       Employed                17.2          25579
# 1    53        Student                 0.5          29147
# 2    32       Employed                12.5          63657
# 3    32       Employed                13.4          32015
# 4    53       Employed                22.9          44989
# 5    44  Self-Employed                 4.2          80603
# 6    29       Employed                 5.9          28416
# 7    41       Employed                 7.0          70717
# 8    29       Employed                 5.0          15000
# 9    29        Student                 1.3          17029
#
#    PUNTUACION_CREDITICIA  HISTORIAL_CREDITICIO  AHORROS  DEUDA_ACTUAL DEFAULT  \
# 0                    692                   5.3      895         10820      NO
# 1                    692                   9.8     1480         11603      NO
# 2                    630                   7.2      209         12424      NO
# ...

# %%
# volvemos a los valores originales: teniendo en cuenta el orden alfabético
DATA_1['OCUPACION'].replace({0:"Employed" , 1:"Self-Employed" , 2:"Student"},  inplace = True)

DATA_1.head(10)
# Out:
#    EDAD      OCUPACION  ANTIGUEDAD_LABORAL  INGRESO_ANUAL  \
# 0    40       Employed                17.2          25579
# 1    53        Student                 0.5          29147
# 2    32       Employed                12.5          63657
# 3    32       Employed                13.4          32015
# 4    53       Employed                22.9          44989
# 5    44  Self-Employed                 4.2          80603
# 6    29       Employed                 5.9          28416
# 7    41       Employed                 7.0          70717
# 8    29       Employed                 5.0          15000
# 9    29        Student                 1.3          17029
#
#    PUNTUACION_CREDITICIA  HISTORIAL_CREDITICIO  AHORROS  DEUDA_ACTUAL DEFAULT  \
# 0                    692                   5.3      895         10820      NO
# 1                    692                   9.8     1480         11603      NO
# 2                    630                   7.2      209         12424      NO
# ...

# %% [markdown]
# **Convertir en variables dummies una existente**

# %%
#creamos variables dummies por cada categoría
pd.get_dummies(DATA_1['OCUPACION'])
#Observamos que al ser string la original, devuelve un booleano
# Out:
#        Employed  Self-Employed  Student
# 0          True          False    False
# 1         False          False     True
# 2          True          False    False
# 3          True          False    False
# 4          True          False    False
# ...         ...            ...      ...
# 49993      True          False    False
# 49994      True          False    False
# 49995     False           True    False
# 49996     False          False     True
# 49997      True          False    False
#
# [49998 rows x 3 columns]

# %%
pd.get_dummies(DATA_1['OCUPACION']).astype(int)
# Out:
#        Employed  Self-Employed  Student
# 0             1              0        0
# 1             0              0        1
# 2             1              0        0
# 3             1              0        0
# 4             1              0        0
# ...         ...            ...      ...
# 49993         1              0        0
# 49994         1              0        0
# 49995         0              1        0
# 49996         0              0        1
# 49997         1              0        0
#
# [49998 rows x 3 columns]

# %%
#agregarlas al dataframe: se crea uno nuevo para no modificar DATA_1
DATA_2=pd.concat([DATA_1, pd.get_dummies(DATA_1['OCUPACION']).astype(int)], axis=1)
DATA_2=DATA_2.drop('OCUPACION', axis=1) #se borra la original
DATA_2.head(10)
# Out:
#    EDAD  ANTIGUEDAD_LABORAL  INGRESO_ANUAL  PUNTUACION_CREDITICIA  \
# 0    40                17.2          25579                    692
# 1    53                 0.5          29147                    692
# 2    32                12.5          63657                    630
# 3    32                13.4          32015                    570
# 4    53                22.9          44989                    674
# 5    44                 4.2          80603                    625
# 6    29                 5.9          28416                    569
# 7    41                 7.0          70717                    638
# 8    29                 5.0          15000                    657
# 9    29                 1.3          17029                    668
#
#    HISTORIAL_CREDITICIO  AHORROS  DEUDA_ACTUAL DEFAULT  \
# 0                   5.3      895         10820      NO
# 1                   9.8     1480         11603      NO
# 2                   7.2      209         12424      NO
# ...

# %% [markdown]
# **Por ejemplo crear una variable nueva en base a otra existente**

# %%
DATA_1.columns
# Out:
# Index(['EDAD', 'OCUPACION', 'ANTIGUEDAD_LABORAL', 'INGRESO_ANUAL',
#        'PUNTUACION_CREDITICIA', 'HISTORIAL_CREDITICIO', 'AHORROS',
#        'DEUDA_ACTUAL', 'DEFAULT', 'MOROSIDAD_ULTIMOS_2AÑOS',
#        'ANOTACIONES_NEGATIVAS', 'PRODUCT_TYPE', 'MOTIVO_SOLICITUD',
#        'MONTO_SOLICITADO', 'TASA_INTERES', 'RATIO_INGRESO_DEUDA',
#        'RATIO_INGRESO_PRESTAMO', 'RATIO_INGRESO_PAGOS', 'ESTADO_PRESTAMO',
#        'NUEVA_COL', 'OCUPACION_1'],
#       dtype='object')

# %%
DATA_1['EDAD'].unique()
# Out:
# array([40, 53, 32, 44, 29, 41, 37, 18, 28, 22, 38, 24, 52, 35, 36, 21, 39,
#        27, 31, 57, 34, 20, 19, 43, 33, 26, 47, 30, 42, 46, 51, 25, 45, 64,
#        48, 61, 23, 50, 67, 70, 62, 60, 56, 54, 49, 59, 58, 55, 65, 66, 63,
#        68, 69])

# %%
#Creamos categorías de edad pero en una nueva variable. Esto requiere recorrer el datafrme por filas

for i, row in DATA_1.iterrows():
  if row.EDAD <= 30  :
        DATA_1.at[i,'EDAD_2'] = 'MENOS_30'
  elif row.EDAD > 30 and row.EDAD <= 50 :
        DATA_1.at[i,'EDAD_2'] = 'ENTRE_31_50'
  elif row.EDAD > 50 and row.EDAD <=70 :
        DATA_1.at[i,'EDAD_2'] = 'ENTRE_51_70'
  else :
        DATA_1.at[i,'EDAD_2'] = 'MAS_70'

# %% [markdown]
# Siempre se debe verificar lo realizado

# %%
control=[]
for i,row in DATA_1[['EDAD','EDAD_2']].iterrows():
  if row.EDAD <= 30  and row.EDAD_2 == 'MENOS_30':
    control.append('OK')
  elif row.EDAD > 30 and row.EDAD <= 50 and row.EDAD_2 == 'ENTRE_31_50':
      control.append('OK')
  elif row.EDAD > 50 and row.EDAD <=70 and row.EDAD_2 == 'ENTRE_51_70':
      control.append('OK')
  else :
      control.append('ERROR')

np.unique(control) #observamos que el único valor es OK
# Out:
# array(['OK'], dtype='<U2')

# %% [markdown]
# **Por ejemplo crear una variable nueva en base a otras existentes**

# %%
DATA_1['OCUPACION'].unique()
# Out:
# array(['Employed', 'Student', 'Self-Employed'], dtype=object)

# %%
DATA_1['MOROSIDAD_ULTIMOS_2AÑOS'].unique()
# Out:
# array([0, 1, 2, 4, 3, 5, 8, 6, 7, 9])

# %% [markdown]
# Las reglas definidas son a modo de ejemplo

# %%
for i, row in DATA_1.iterrows():
  if row.OCUPACION == 'Student' and  row.MOROSIDAD_ULTIMOS_2AÑOS >= 2 :
    DATA_1.at[i,'RIESGO'] = 'ALTO'
  elif row.OCUPACION == 'Self-Employed' and row.MOROSIDAD_ULTIMOS_2AÑOS >= 3 :
    DATA_1.at[i,'RIESGO'] = 'ALTO'
  elif row.OCUPACION == 'Employed' and row.MOROSIDAD_ULTIMOS_2AÑOS >= 4 :
    DATA_1.at[i,'RIESGO'] = 'ALTO'
  elif row.MOROSIDAD_ULTIMOS_2AÑOS > 0 and row.MOROSIDAD_ULTIMOS_2AÑOS < 2:
    DATA_1.at[i,'RIESGO'] = 'MEDIO'
  else :
    DATA_1.at[i,'RIESGO'] = 'NORMAL'

# %%
DATA_1['RIESGO'].unique()
# Out:
# array(['NORMAL', 'MEDIO', 'ALTO'], dtype=object)

# %% [markdown]
# Siempre se debe verificar lo realizado

# %%
control_2=[]
for i,row in DATA_1[['OCUPACION','MOROSIDAD_ULTIMOS_2AÑOS','RIESGO']].iterrows():
  if row.OCUPACION == 'Student' and  row.MOROSIDAD_ULTIMOS_2AÑOS >= 2 and row.RIESGO == 'ALTO':
    control_2.append('OK')
  elif row.OCUPACION == 'Self-Employed' and row.MOROSIDAD_ULTIMOS_2AÑOS >= 3 and row.RIESGO == 'ALTO':
    control_2.append('OK')
  elif row.OCUPACION == 'Employed' and row.MOROSIDAD_ULTIMOS_2AÑOS >= 4 and row.RIESGO == 'ALTO':
    control_2.append('OK')
  elif row.MOROSIDAD_ULTIMOS_2AÑOS > 0 and row.MOROSIDAD_ULTIMOS_2AÑOS < 2 and row.RIESGO == 'MEDIO':
    control_2.append('OK')
  elif row.RIESGO == 'NORMAL':
    control_2.append('OK')
  else :
      control_2.append('ERROR')

np.unique(control_2) #observamos que el único valor es OK
# Out:
# array(['OK'], dtype='<U2')

# %% [markdown]
# ### **Detección de problemas**

# %% [markdown]
# Si bien con un Profilling Report (como se vió en la clase 6), fue posible observar valores faltantes, valores atípicos entre otros, el depender de una API creada por terceros puede resultar una limitante (permisos de uso en un contexto organizacional, modificaciones en la API que no se notifican, etc)
#
# Por esta razón, es importante poder realizar las detecciones sin depender de una API

# %% [markdown]
# **Observar si existen valores faltantes**

# %%
for i in DATA_1:
  if DATA_1.isnull().sum().any()>0:
    print(f"La columna '{i}' contiene ' {DATA_1.isnull().sum()} ' valores faltantes")
  else:
    print(f"La columna '{i}' no contiene valores faltantes")
# Out:
# La columna 'EDAD' no contiene valores faltantes
# La columna 'OCUPACION' no contiene valores faltantes
# La columna 'ANTIGUEDAD_LABORAL' no contiene valores faltantes
# La columna 'INGRESO_ANUAL' no contiene valores faltantes
# La columna 'PUNTUACION_CREDITICIA' no contiene valores faltantes
# La columna 'HISTORIAL_CREDITICIO' no contiene valores faltantes
# La columna 'AHORROS' no contiene valores faltantes
# La columna 'DEUDA_ACTUAL' no contiene valores faltantes
# La columna 'DEFAULT' no contiene valores faltantes
# La columna 'MOROSIDAD_ULTIMOS_2AÑOS' no contiene valores faltantes
# La columna 'ANOTACIONES_NEGATIVAS' no contiene valores faltantes
# La columna 'PRODUCT_TYPE' no contiene valores faltantes
# La columna 'MOTIVO_SOLICITUD' no contiene valores faltantes
# La columna 'MONTO_SOLICITADO' no contiene valores faltantes
# La columna 'TASA_INTERES' no contiene valores faltantes
# La columna 'RATIO_INGRESO_DEUDA' no contiene valores faltantes
# ...

# %% [markdown]
# **Observar si existen filas duplicadas**

# %%
DATA_1[DATA_1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [EDAD, OCUPACION, ANTIGUEDAD_LABORAL, INGRESO_ANUAL, PUNTUACION_CREDITICIA, HISTORIAL_CREDITICIO, AHORROS, DEUDA_ACTUAL, DEFAULT, MOROSIDAD_ULTIMOS_2AÑOS, ANOTACIONES_NEGATIVAS, PRODUCT_TYPE, MOTIVO_SOLICITUD, MONTO_SOLICITADO, TASA_INTERES, RATIO_INGRESO_DEUDA, RATIO_INGRESO_PRESTAMO, RATIO_INGRESO_PAGOS, ESTADO_PRESTAMO, NUEVA_COL, OCUPACION_1, EDAD_2, RIESGO]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# No existen filas duplicadas

# %%
#si quisieramos borrar las filas duplicados
DATA_1.drop_duplicates() #no borrará ninguna fila porque en este caso no hay filas duplicadas
# Out:
#        EDAD      OCUPACION  ANTIGUEDAD_LABORAL  INGRESO_ANUAL  \
# 0        40       Employed                17.2          25579
# 1        53        Student                 0.5          29147
# 2        32       Employed                12.5          63657
# 3        32       Employed                13.4          32015
# 4        53       Employed                22.9          44989
# ...     ...            ...                 ...            ...
# 49993    35       Employed                 4.3          39449
# 49994    34       Employed                 4.4          20496
# 49995    41  Self-Employed                 4.8          18743
# 49996    38        Student                 0.4          17250
# 49997    53       Employed                17.2          46923
#
#        PUNTUACION_CREDITICIA  HISTORIAL_CREDITICIO  AHORROS  DEUDA_ACTUAL  \
# 0                        692                   5.3      895         10820
# ...

# %% [markdown]
# **Detectar cantidad de valores únicos**

# %%
DATA_1.agg('nunique')
# Out:
# EDAD                          53
# OCUPACION                      3
# ANTIGUEDAD_LABORAL           395
# INGRESO_ANUAL              35769
# PUNTUACION_CREDITICIA        432
# HISTORIAL_CREDITICIO         301
# AHORROS                    10382
# DEUDA_ACTUAL               25349
# DEFAULT                        2
# MOROSIDAD_ULTIMOS_2AÑOS       10
# ANOTACIONES_NEGATIVAS          5
# PRODUCT_TYPE                   3
# MOTIVO_SOLICITUD               6
# MONTO_SOLICITADO             996
# TASA_INTERES                1687
# RATIO_INGRESO_DEUDA          796
# RATIO_INGRESO_PRESTAMO      1992
# RATIO_INGRESO_PAGOS          665
# ESTADO_PRESTAMO                2
# NUEVA_COL                  35769
# OCUPACION_1                    3
# EDAD_2                         3
# RIESGO                         3
# dtype: int64

# %% [markdown]
# **Obtención de Valor mínimo y máximo**

# %%
DATA_1.agg(['min', 'max']).transpose()
# Out:
#                                  min            max
# EDAD                              18             70
# OCUPACION                   Employed        Student
# ANTIGUEDAD_LABORAL               0.0           39.9
# INGRESO_ANUAL                  15000         250000
# PUNTUACION_CREDITICIA            348            850
# HISTORIAL_CREDITICIO             0.0           30.0
# AHORROS                            0         300000
# DEUDA_ACTUAL                      60         163344
# DEFAULT                           NO             SI
# MOROSIDAD_ULTIMOS_2AÑOS            0              9
# ANOTACIONES_NEGATIVAS              0              4
# PRODUCT_TYPE             Credit Card  Personal Loan
# MOTIVO_SOLICITUD            Business       Personal
# MONTO_SOLICITADO                 500         100000
# TASA_INTERES                     6.0           23.0
# RATIO_INGRESO_DEUDA            0.002            0.8
# RATIO_INGRESO_PRESTAMO         0.008          2.001
# ...

# %% [markdown]
# **Detectar valores negativos en columnas numéricas**
#
# Si la variable admite valores negatvos desde su concepto, entonces no será un problema. En caso contrario, si (por ejemplo INGRESO)

# %%
for i in DATA_1.columns:
  if DATA_1.dtypes[i] == 'int64' or DATA_1.dtypes[i] == 'float64':
    if (DATA_1[i]<0).any():
      print(f"La columna '{i}' contiene valores negativos")
    else:
      print(f"La columna '{i}' no contiene valores negativos")
# Out:
# La columna 'EDAD' no contiene valores negativos
# La columna 'ANTIGUEDAD_LABORAL' no contiene valores negativos
# La columna 'INGRESO_ANUAL' no contiene valores negativos
# La columna 'PUNTUACION_CREDITICIA' no contiene valores negativos
# La columna 'HISTORIAL_CREDITICIO' no contiene valores negativos
# La columna 'AHORROS' no contiene valores negativos
# La columna 'DEUDA_ACTUAL' no contiene valores negativos
# La columna 'MOROSIDAD_ULTIMOS_2AÑOS' no contiene valores negativos
# La columna 'ANOTACIONES_NEGATIVAS' no contiene valores negativos
# La columna 'MONTO_SOLICITADO' no contiene valores negativos
# La columna 'TASA_INTERES' no contiene valores negativos
# La columna 'RATIO_INGRESO_DEUDA' no contiene valores negativos
# La columna 'RATIO_INGRESO_PRESTAMO' no contiene valores negativos
# La columna 'RATIO_INGRESO_PAGOS' no contiene valores negativos
# La columna 'ESTADO_PRESTAMO' no contiene valores negativos
# La columna 'NUEVA_COL' no contiene valores negativos

# %% [markdown]
# **Detección de valores atípicos**
#
# Esto es detectar los valores atípicos en base al criterio de BoxPlot: todos aquellos valores que superan los bigotes

# %%
for i in DATA_1.columns:
  if DATA_1.dtypes[i] == 'int64' or DATA_1.dtypes[i] == 'float64':
    lim_sup=np.percentile(DATA_1[i],75) + 1.5*(np.percentile(DATA_1[i],75)-np.percentile(DATA_1[i],25))
    lim_inf=np.percentile(DATA_1[i],25) - 1.5*(np.percentile(DATA_1[i],75)-np.percentile(DATA_1[i],25))
    if (DATA_1[i] > lim_sup).any() or (DATA_1[i] < lim_inf).any():
      extreme_values = DATA_1[(DATA_1[i] > lim_sup) | (DATA_1[i] < lim_inf)][i]
      if len(extreme_values.unique())==1:
        print(f"La columna '{i}' contiene '{len(extreme_values.unique())}' valor extremo.")
        print(f"El valor extremo es '{extreme_values.unique()}' ")
      else:
        print(f"La columna '{i}' contiene '{len(extreme_values.unique())}' valores extremos.")
        print(f"Los primeros 10 valores extremos son '{extreme_values.unique()[:10]}' ") #se muestran solo 10
    else:
      print(f"La columna '{i}' no contiene valores extremos.")
# Out:
# La columna 'EDAD' contiene '2' valores extremos.
# Los primeros 10 valores extremos son '[70 69]'
# La columna 'ANTIGUEDAD_LABORAL' contiene '129' valores extremos.
# Los primeros 10 valores extremos son '[31.3 33.1 26.6 38.2 34.1 33.2 28.5 26.7 34.3 30.8]'
# La columna 'INGRESO_ANUAL' contiene '2261' valores extremos.
# Los primeros 10 valores extremos son '[172243 148299 116531 246598 134440 132904 170371 116002 165877 126202]'
# La columna 'PUNTUACION_CREDITICIA' contiene '84' valores extremos.
# Los primeros 10 valores extremos son '[820 440 823 819 439 428 850 430 462 826]'
# La columna 'HISTORIAL_CREDITICIO' contiene '15' valores extremos.
# Los primeros 10 valores extremos son '[30.  29.8 28.9 29.9 29.5 28.7 29.6 28.8 29.2 29. ]'
# La columna 'AHORROS' contiene '5529' valores extremos.
# Los primeros 10 valores extremos son '[19667  9216  6339 20476 17865 85551  9578 18406 52072  8553]'
# La columna 'DEUDA_ACTUAL' contiene '2799' valores extremos.
# ...

# %%
#si por ejemplo hacemos un boxplot de EDAD, observamos los dos valores atípicos
import seaborn as sns
sns.boxplot(x=DATA_1['EDAD'])
# Out:
# <Axes: xlabel='EDAD'>

# %% [markdown]
# **Observar valores únicos en variables categóricas**
#
# Al observar se podrá ver si todos los valores están escritos de la misma forma. Si alguna presenta una letra distinta, un espacio de más, etc, aparecerá como valor mostrado

# %%
for i in DATA_1:
  if DATA_1.dtypes[i] == 'object':
    extreme_values = DATA_1[i].unique()
    print(f"La columna '{i}' contiene los siguientes valores únicos' {extreme_values} '")
  else:
    pass
# Out:
# La columna 'OCUPACION' contiene los siguientes valores únicos' ['Employed' 'Student' 'Self-Employed'] '
# La columna 'DEFAULT' contiene los siguientes valores únicos' ['NO' 'SI'] '
# La columna 'PRODUCT_TYPE' contiene los siguientes valores únicos' ['Credit Card' 'Personal Loan' 'Line of Credit'] '
# La columna 'MOTIVO_SOLICITUD' contiene los siguientes valores únicos' ['Business' 'Education' 'Personal' 'Home Improvement' 'Medical'
#  'Debt Consolidation'] '
# La columna 'EDAD_2' contiene los siguientes valores únicos' ['ENTRE_31_50' 'ENTRE_51_70' 'MENOS_30'] '
# La columna 'RIESGO' contiene los siguientes valores únicos' ['NORMAL' 'MEDIO' 'ALTO'] '
