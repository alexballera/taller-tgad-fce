# %% [markdown]
# <figure>
# <center>
# <img src='https://www.economicas.uba.ar/wp-content/uploads/2020/08/cropped-logo_FCE.png' />
# </figure>

# %% [markdown]
# # **Universidad de Buenos Aires**
# ## **Facultad de Ciencias Económicas**
#
# ### **Taller de Programación para el Análisis de Datos**
#
# #### **Clase 11: Descriptiva de datos**

# %% [markdown]
# En esta clase veremos como obtener diferentes medidas estadísticas para su posterior interpretación y análisis

# %% [markdown]
# **Cálculo de medidas estadísticas**

# %% [markdown]
# En Python hay funciones programadas que permiten obtener el cálculo de medidas estadísticas. Ciertas funciones son nativas (aquellas que no requieren de importar una librería) y otras no (es decir, resulta necesario importar uan librería para disponer de las funciones).
#
# Generalmente, a las librerías se les asigna un alias para invocarlas de manera más simple en términso de escribir menos código.

# %% [markdown]
# Numpy: https://numpy.org/
#
# Statistics: https://docs.python.org/es/dev/library/statistics.html
#
# Scipy Stats: https://docs.scipy.org/doc/scipy/reference/stats.html

# %% [markdown]
# ### **Librería**

# %%
import pandas as pd
import numpy as np
import sympy
import statistics as stats
import scipy.stats as ss
import math
import warnings
warnings.filterwarnings('ignore')
import kagglehub

# %% [markdown]
# ### **Medidas estadísticas descriptivas**

# %%
path = kagglehub.dataset_download("parthpatel2130/realistic-loan-approval-dataset-us-and-canada")

print("Path to dataset files:", path)

DATA=pd.read_csv("/root/.cache/kagglehub/datasets/parthpatel2130/realistic-loan-approval-dataset-us-and-canada/versions/1/Loan_approval_data_2025.csv")
DATA.head()
# Out:
# Using Colab cache for faster access to the 'realistic-loan-approval-dataset-us-and-canada' dataset.
# Path to dataset files: /kaggle/input/realistic-loan-approval-dataset-us-and-canada
#   customer_id  age occupation_status  years_employed  annual_income  \
# 0  CUST100000   40          Employed            17.2          25579
# 1  CUST100001   33          Employed             7.3          43087
# 2  CUST100002   42           Student             1.1          20840
# 3  CUST100003   53           Student             0.5          29147
# 4  CUST100004   32          Employed            12.5          63657
#
#    credit_score  credit_history_years  savings_assets  current_debt  \
# 0           692                   5.3             895         10820
# 1           627                   3.5             169         16550
# 2           689                   8.4              17          7852
# 3           692                   9.8            1480         11603
# ...

# %% [markdown]
# **Medidas de tendencia central:**
#
# **MEDIA ARIMÉTICA**: Es el promedio simple de los valores de la variable aletoria Es muy sensible a valores atípicos siendo aquellos que se alejan del comportamiento “normal" de los datos. Su cálculo es:
#
# \begin{align}
#          \bar{X} = {\sum_{i=1}^n x_i\over n}
# \end{align}
#
# **MEDIANA**: Es el valor central (o mitad que es equivalente al 50%) cuando los datos se encuentran ordenados de manera creciente. Su cálculo permite obtener la posición donde se encuentra el valor dentro de la distribución de los datos:
#
# \begin{align}
#          X_{me}
# \end{align}
#
# Recordamos que en este caso se aplicabla la siguiente regla (siendo lo que realiza Python para el calculo, también en el caso de los percentiles):
#
# Para obtener su valor se debe primero calcular:
# Distancia=k*(n-1) donde k es el porcentaje que en este caso es 0,5
#
# Si:
# - Distancia=número entero => es la posición. Buscaré en el ´índice de mis datos dicha posición y me fijare el valor que toma la variable siendo este el valor de la mediana
# - Distancia=número decimal => debo interpolar . El resultado de esta operación será el valor de la mediana
#
# **MODA**: Es el valor más frecuente, es decir, el que más veces se repite dentro de la distribución. Si dos o mas valores son los de mayor frecuencia de aparición entonces estamos frente a una distribución multimodal:
#
# \begin{align}
#         x_{mo}
# \end{align}

# %% [markdown]
# MEDIA ARITMÉTICA

# %%
MEDIA_MUESTRAL1 = DATA['annual_income'].mean() #utilizando función nativa
MEDIA_MUESTRAL1
# Out:
# np.float64(50062.89204)

# %%
MEDIA_MUESTRAL2=stats.mean(DATA['annual_income']) #utilizando la función pero de la librería stats
MEDIA_MUESTRAL2
# Out:
# 50062.89204

# %%
MEDIA_MUESTRAL1== MEDIA_MUESTRAL2
# Out:
# np.True_

# %% [markdown]
# MEDIANA

# %%
MEDIANA1 = DATA['annual_income'].median() #utilizando función nativa
MEDIANA1
# Out:
# 41607.5

# %%
MEDIANA2 =stats.median(DATA['annual_income']) #utilizando la función pero de la librería stats
MEDIANA2
# Out:
# 41607.5

# %%
MEDIANA1 == MEDIANA2
# Out:
# True

# %% [markdown]
# VALOR MODAL

# %%
MODO1 = DATA['annual_income'].mode() #utilizando función nativa
MODO1
# Out:
# 0    15000
# Name: annual_income, dtype: int64

# %%
MODO2=stats.mode(DATA['annual_income']) #utilizando la función pero de la librería stats
MODO2
# Out:
# 15000

# %% [markdown]
# ¿Pero hay un solo valor modal?

# %%
MULTIMODAL=stats.multimode(DATA['annual_income']) #utilizando la función pero de la librería stats
MULTIMODAL

#obsevamos que no, solo hay un valor modal. Lo recomendable es siempre utilizar esta función por si llega a haber más de un valor modal
# Out:
# [15000]

# %% [markdown]
# **Medidas de Tendencia no central**
#
# - Percentiles: permiten saber el porcentaje de observaciones que se encuentran por debajo de cierto valor y por encima al dividir la distribución de los datos en 100 partes iguales. Su cálculo, que brinda una posición dentro de la distribución de los valores de la variable aletoria, es:
#
# \begin{align}
#          {P_k} = {n * k\over 100}
# \end{align}
#
# Equivalencias:
#
# ${P_{10}} = {D_{1}}$
#
# ${P_{20}} = {D_{2}}$
#
# ${P_{25}} = {Q_{1}}$
#
# ${P_{30}} = {D_{3}}$
#
# ${P_{40}} = {D_{4}}$
#
# ${P_{50}} = {Q_{2}} = {D_{5}} = {X_{me}}$
#
# ${P_{60}} = {D_{6}}$
#
# ${P_{70}} = {D_{7}}$
#
# ${P_{75}} = {Q_{3}}$
#
# ${P_{80}} = {D_{8}}$
#
# ${P_{90}} = {D_{9}}$
#
# ${P_{100}} = {Q_{4}} = {D_{10}}$
#
# Donde $D_i$ refiere a decil siendo aquel que divide al distribución de los datos en 10 partes iguales, y $Q_i$ refiere a cuartil siendo aquel que divide a la distribución de los datos en 4 partes iguales.

# %%
PERCENTILES=np.percentile(DATA['annual_income'], [5, 10, 25, 50, 60, 75, 90, 100]) #utlizando al librería numpy
PERCENTILES
# Out:
# array([ 15000.  ,  18541.9 ,  27280.5 ,  41607.5 ,  48636.4 ,  62723.25,
#         91198.6 , 250000.  ])

# %%
PERCENTILES[0]
# Out:
# np.float64(15000.0)

# %% [markdown]
# **Medidas de dispersión:**
#
# - RANGO: permite saber la amplitud del dominio de la distribución de los datos. Su cálculo es:
#
# \begin{align}
#          {Rango} = { X_{max} - X_{min}}
# \end{align}
#
# - RANGO INTERCUARTÍLICO: amplitud del intervalo donde se acumula el 50% de la distribución de los datos. Su cálculo es:
#
# \begin{align}
#          {RIC} = { Q_{3} - Q_{1}}
# \end{align}
#
# - VARIANZA MUESTRAL: indica cuanto se alejan los datos del valor medio de la distribución en términos cuadráticos. Su cálculo es:
#
# \begin{align}
#         S^2= {\sum_{i=1}^n (x_i - \bar{X})^2\over n-1}
# \end{align}
#
# - DESVÍO MUESTRAL: indica cuanto se alejan los datos del valor medio de la distribución en la misma unidad de media que la variable. Su cálculo es:
#
# \begin{align}
#         S= {\sqrt {S^2}}
# \end{align}
#
# - COEFICIENTE DE VARIACIÓN: mide la relación entre el desvío muestral y la media muestral. Su cálculo es:
#
# \begin{align}
#         CV= {S \over \bar{X}}
# \end{align}

# %% [markdown]
# RANGO

# %%
RANGO=DATA['annual_income'].max() - DATA['annual_income'].min() #utilizando funciones nativas
RANGO
# Out:
# 235000

# %% [markdown]
# RIC

# %%
RIC=np.percentile(DATA['annual_income'], 75) - np.percentile(DATA['annual_income'], 25) #utlizando al librería numpy
RIC
# Out:
# np.float64(35442.75)

# %% [markdown]
# VARIANZA MUESTRAL

# %%
DATA['annual_income'].var() #utilizando función nativa
# Out:
# 1064749596.4328105

# %%
VARIANZA=stats.variance(DATA['annual_income']) #utilizando la función pero de la librería stats
VARIANZA
# Out:
# 1064749596.4327933

# %% [markdown]
# DESVÍO MUESTRAL

# %%
DATA['annual_income'].std() #utilizando función nativa
# Out:
# 32630.501014124966

# %%
DESVIO=stats.stdev(DATA['annual_income']) #utilizando la función pero de la librería stats
DESVIO
# Out:
# 32630.501014124704

# %% [markdown]
# COEFICIENTE DE VARIACIÓN

# %%
CV=DESVIO/MEDIA_MUESTRAL1
CV
# Out:
# np.float64(0.6517901720110996)

# %%
ss.variation(DATA['annual_income'], ddof=1) #utilizando librería scipy.stats

#se recomienda utilizar ddof=1 para garantizar que la desviación estándar de la muestra se calcule como la raíz cuadrada de la varianza de la muestra insesgada
# Out:
# np.float64(0.6517901720110996)

# %% [markdown]
# **Medidas de forma**
#
# **COEFICIENTE DE ASIMETRÍA**: permite saber cuan dispersos se encuentran los datos respecto respecto de la media. Su cálculo es:
#
# \begin{align}
#          {A_s} = {{\sum_{i=1}^n {\left( (x_i - \bar{X}) \over {S} \right)}^3} \over n}
# \end{align}
#
# Interpretación:
#
# - Si ${A_s} < 0 $ entonces la distribución de los datos es asimétrica negativa (concentración de datos a derecha y cola a izquierda). Entonces se cumple que ${\bar{X} < X_{me}}$
#
# - Si ${A_s} = 0 $ entonces la distribución de los datos es simétrica. Entonces se cumple que ${\bar{X} = X_{me}}$
#
# - Si ${A_s} > 0 $ entonces la distribución de los datos es asimétrica positiva (concentración de datos a izquierda y cola a derecha). Entonces se cumple que ${\bar{X} > X_{me}}$
#
# **COEFICIENTE DE CURTOSIS**: permite saber como es la forma de la concentración de los datos. Su cálculo es:
#
# \begin{align}
#          {K} = {{\sum_{i=1}^n {\left( (x_i - \bar{X}) \over {S} \right)}^4} \over n}
# \end{align}
#
# Interpretación:
#
# - Si ${K} < 3 $ entonces la distribución es platicúrtica (la forma de la distribución es más aplanada).
#
# - Si ${K} = 3 $ entonces la distribución es mesocúrtica (la forma de la distribución no es ni muy aplanada ni muy puntiaguda).
#
# - Si ${K} > 3 $ entonces la distribución es leptocúrtica (la forma de la distribución presenta un pico en el centro).
#
# Las medidas de forma suelen apreciarse a través de gráficos. Particularmente, en estadística hay dos principales: histograma y boxplot. Estos ayudan a visualizar de una manera resumida varias de las medidas anteriores.

# %% [markdown]
# COEFICIENTE DE ASIMETRÍA

# %%
CA=DATA['annual_income'].skew() #utilizando función nativa
CA
# Out:
# np.float64(1.8878688896751907)

# %%
ss.skew(DATA['annual_income'],bias=False) #utilizando librería scipy.stats
# Out:
# np.float64(1.8878688896751907)

# %% [markdown]
# COEFICIENTE DE CURTOSIS

# %%
CC=DATA['annual_income'].kurtosis() #utilizando función nativa
CC
# Out:
# np.float64(5.227918962101391)

# %%
ss.kurtosis(DATA['annual_income'],bias=False) #utilizando librería scipy.stats
# Out:
# np.float64(5.227918962101391)

# %% [markdown]
# Si se quiere armar una tabla con todas las medidas calculadas, entonces:

# %%
Medidas=pd.DataFrame({ 'Media Muestral': [MEDIA_MUESTRAL1], 'Mediana': [MEDIANA1], 'Valor Modal 1': MODO1, 'Valor Modal Multimodal': [MULTIMODAL[0]],
                     'P05': [PERCENTILES[0]], 'P10': [PERCENTILES[1]], 'P25': [PERCENTILES[2]],'P50': [PERCENTILES[3]], 'P60': [PERCENTILES[4]],
                      'P75': [PERCENTILES[5]], 'P90': [PERCENTILES[6]],
                     'Rango': [RANGO], 'RIC': [RIC], 'Varianza Muestral': [VARIANZA], 'Desvío Muestral': [DESVIO], 'Coef Variación': [CV],
                      'Coef Asimetría': [CA], 'Coef Curtosis': [CC]
                     }).transpose()
Medidas=Medidas.reset_index(inplace=False)
Medidas.columns=['Estadísticas', 'Valores']
pd.options.display.float_format = '{:.2f}'.format #evitar notación científica y/o acotar decimales
Medidas
# Out:
#               Estadísticas       Valores
# 0           Media Muestral      50062.89
# 1                  Mediana      41607.50
# 2            Valor Modal 1      15000.00
# 3   Valor Modal Multimodal      15000.00
# 4                      P05      15000.00
# 5                      P10      18541.90
# 6                      P25      27280.50
# 7                      P50      41607.50
# 8                      P60      48636.40
# 9                      P75      62723.25
# 10                     P90      91198.60
# 11                   Rango     235000.00
# 12                     RIC      35442.75
# 13       Varianza Muestral 1064749596.43
# 14         Desvío Muestral      32630.50
# 15          Coef Variación          0.65
# 16          Coef Asimetría          1.89
# 17           Coef Curtosis          5.23

# %% [markdown]
# Es posible exportar la tabla de datos. Aparecerá en el menú de la izquierda. En los tres puntitos- > Descargar

# %%
Medidas.to_csv('/content/Medidas.csv', sep=";")

# %% [markdown]
# Podemos escribir un programa para hacer todos los cálculos de las medidas por cada variable

# %%
DATA.columns
# Out:
# Index(['customer_id', 'age', 'occupation_status', 'years_employed',
#        'annual_income', 'credit_score', 'credit_history_years',
#        'savings_assets', 'current_debt', 'defaults_on_file',
#        'delinquencies_last_2yrs', 'derogatory_marks', 'product_type',
#        'loan_intent', 'loan_amount', 'interest_rate', 'debt_to_income_ratio',
#        'loan_to_income_ratio', 'payment_to_income_ratio', 'loan_status'],
#       dtype='object')

# %%
np.percentile(DATA['annual_income'], [5, 10, 25, 50, 60, 75, 90, 100])
# Out:
# array([ 15000.  ,  18541.9 ,  27280.5 ,  41607.5 ,  48636.4 ,  62723.25,
#         91198.6 , 250000.  ])

# %%
for i in DATA:
  if DATA[i].dtype=='int64' or DATA[i].dtype=='float64':
    print(f"La media de la variable {i} es: {round(stats.mean(DATA[i]),2)}")
    print(f"La mediana de la variable {i} es: {round(stats.median(DATA[i]),2)}")
    print(f"La moda de la variable {i} es: {round(stats.mode(DATA[i]),2)}")
    print(f"El P05 de la variable {i} es: {np.percentile(DATA[i], [5]).item()}")
    print(f"El P10 de la variable {i} es: {np.percentile(DATA[i], [10]).item()}")
    print(f"El P20 de la variable {i} es: {np.percentile(DATA[i], [20]).item()}")
    print(f"El P25 de la variable {i} es: {np.percentile(DATA[i], [25]).item()}")
    print(f"El P30 de la variable {i} es: {np.percentile(DATA[i], [30]).item()}")
    print(f"El P40 de la variable {i} es: {np.percentile(DATA[i], [40]).item()}")
    print(f"El P50 de la variable {i} es: {np.percentile(DATA[i], [50]).item()}")
    print(f"El P60 de la variable {i} es: {np.percentile(DATA[i], [60]).item()}")
    print(f"El P70 de la variable {i} es: {np.percentile(DATA[i], [70]).item()}")
    print(f"El P75 de la variable {i} es: {np.percentile(DATA[i], [75]).item()}")
    print(f"El P80 de la variable {i} es: {np.percentile(DATA[i], [80]).item()}")
    print(f"El P90 de la variable {i} es: {np.percentile(DATA[i], [90]).item()}")
    print(f"El P100 de la variable {i} es: {np.percentile(DATA[i], [100]).item()}")
    print(f"El RIC de la variable {i} es: {np.percentile(DATA[i], [75])-np.percentile(DATA[i], [25]).item()}")
    print(f"El máximo valor de la variable {i} es: {DATA[i].max()}")
    print(f"El mínimo valor de la variable {i} es: {DATA[i].min()}")
    print(f"El Rango de la variable {i} es: {DATA[i].max()-DATA[i].min()}")
    print(f"La varianza muestral de la variable {i} es: {DATA[i].var()}")
    print(f"El desvío muestral de la variable {i} es: {DATA[i].std()}")
    print(f"El coeficiente de asimetría de la variable {i} es: {DATA[i].skew()}")
    print(f"El coeficiente de curtosis de la variable {i} es: {DATA[i].kurtosis()}")
# Out:
# La media de la variable age es: 34.96
# La mediana de la variable age es: 35.0
# La moda de la variable age es: 18
# El P05 de la variable age es: 18.0
# El P10 de la variable age es: 19.0
# El P20 de la variable age es: 24.0
# El P25 de la variable age es: 26.0
# El P30 de la variable age es: 28.0
# El P40 de la variable age es: 31.0
# El P50 de la variable age es: 35.0
# El P60 de la variable age es: 37.0
# El P70 de la variable age es: 41.0
# El P75 de la variable age es: 43.0
# El P80 de la variable age es: 45.0
# El P90 de la variable age es: 50.0
# El P100 de la variable age es: 70.0
# El RIC de la variable age es: [17.]
# El máximo valor de la variable age es: 70
# El mínimo valor de la variable age es: 18
# El Rango de la variable age es: 52
# La varianza muestral de la variable age es: 123.6233286229801
# El desvío muestral de la variable age es: 11.118602817934459
# El coeficiente de asimetría de la variable age es: 0.3358600793243518
# ...

# %% [markdown]
# ### **Covarianza y Correlación lineal**

# %% [markdown]
# **Interpretación de la Covarianza:**
#
# - La Cov(X,Y) > 0 si la relación entre X e Y es fuertemente positiva.
#  Esto es, a valores grandes de X suceden conjuntamente con
# valores grandes de Y (y viceversa).
#
# - La Cov(X,Y) < 0 si la relación entre X e Y es fuertemente negativa.
# Esto es, a valores grandes de X suceden conjuntamente
# con valores pequeños de Y (y viceversa).
#
# - La Cov(X,Y)=0 no existe relación entre X e Y
#
# **Interpretación de la correlación lineal**
#
# - R=1 relación lineal perfectamente positiva. Esto sucederá cuando X e Y estén fuertemente  relacionadas de manera positiva.
#
# - R= -1 relación lineal perfectamente negativa. Esto sucederá cuando X e Y estén fuertemente relacionadas de manera negativa.
#
# - R=0  indica que existe una ausencia completa de relación lineal entre X e Y.
#
# - 1<R<0 indica que la relación es lineal negativa:
# 	- Si -1<R≤ -0,8 entonces relación lineal fuertemente negativa
# 	- Si -0,8<R ≤ -0,5 entonces relación lineal moderadamente negativa
# 	- Si -0,5<R< 0 entonces relación lineal débilmente negativa
#
# - 0<R<1 indica que la relación es lineal positiva:
# 	- Si 0<R< 0,5 entonces relación lineal débilmente positiva
# 	- Si 0<R< 0,8 entonces relación lineal moderadamente positiva
# 	- Si 0,8<R< 1 entonces relación lineal fuertemente positiva

# %% [markdown]
# Para calcular Covarianza y Correlación todas las variables deben ser numéricas

# %%
DATA_1=DATA.copy()
DATA_1.head()
# Out:
#   customer_id  age occupation_status  years_employed  annual_income  \
# 0  CUST100000   40          Employed           17.20          25579
# 1  CUST100001   33          Employed            7.30          43087
# 2  CUST100002   42           Student            1.10          20840
# 3  CUST100003   53           Student            0.50          29147
# 4  CUST100004   32          Employed           12.50          63657
#
#    credit_score  credit_history_years  savings_assets  current_debt  \
# 0           692                  5.30             895         10820
# 1           627                  3.50             169         16550
# 2           689                  8.40              17          7852
# 3           692                  9.80            1480         11603
# 4           630                  7.20             209         12424
#
#    defaults_on_file  delinquencies_last_2yrs  derogatory_marks   product_type  \
# ...

# %%
#convertimos a categorías numéricas las variables object
for i in DATA_1:
  if DATA_1[i].dtype=='object':
    DATA_1[i]=DATA_1[i].astype('category').cat.codes
  else:
    pass

# %%
DATA_1.dtypes
# Out:
# customer_id                  int32
# age                          int64
# occupation_status             int8
# years_employed             float64
# annual_income                int64
# credit_score                 int64
# credit_history_years       float64
# savings_assets               int64
# current_debt                 int64
# defaults_on_file             int64
# delinquencies_last_2yrs      int64
# derogatory_marks             int64
# product_type                  int8
# loan_intent                   int8
# loan_amount                  int64
# interest_rate              float64
# debt_to_income_ratio       float64
# loan_to_income_ratio       float64
# payment_to_income_ratio    float64
# loan_status                  int64
# dtype: object

# %% [markdown]
# COVARIANZA

# %%
DATA_1.cov()  #utilizando función nativa
# Out:
#                          customer_id      age  occupation_status  \
# customer_id             208337500.00   -67.82              19.31
# age                           -67.82   123.62              -0.01
# occupation_status              19.31    -0.01               0.43
# years_employed                 69.54    53.05              -1.30
# annual_income            -1110791.52 96076.11            -791.65
# credit_score                 1152.03   265.77              -0.32
# credit_history_years          101.94    50.98               0.01
# savings_assets            1754650.23 26144.04            -152.13
# current_debt             -1135645.04 26458.88            -183.66
# defaults_on_file                9.86    -0.16               0.00
# delinquencies_last_2yrs        17.58    -0.95               0.00
# derogatory_marks              -28.80    -0.45              -0.00
# product_type                  -42.24     0.07              -0.00
# ...

# %%
#para evitar la notación científica y/o acotar decimales

pd.options.display.float_format = '{:.2f}'.format #cantidad de decimales 8 máximo a mostrar

DATA_1.cov()  #utilizando función nativa
# Out:
#                          customer_id      age  occupation_status  \
# customer_id             208337500.00   -67.82              19.31
# age                           -67.82   123.62              -0.01
# occupation_status              19.31    -0.01               0.43
# years_employed                 69.54    53.05              -1.30
# annual_income            -1110791.52 96076.11            -791.65
# credit_score                 1152.03   265.77              -0.32
# credit_history_years          101.94    50.98               0.01
# savings_assets            1754650.23 26144.04            -152.13
# current_debt             -1135645.04 26458.88            -183.66
# defaults_on_file                9.86    -0.16               0.00
# delinquencies_last_2yrs        17.58    -0.95               0.00
# derogatory_marks              -28.80    -0.45              -0.00
# product_type                  -42.24     0.07              -0.00
# ...

# %%
stats.covariance(DATA_1['age'], DATA_1['annual_income']) #utilizando librería stats pero solo permite el cálculo entre dos variables
# Out:
# 96076.10538630532

# %% [markdown]
# CORRELACIÓN DE PEARSON

# %%
DATA_1.corr() #utilizando función nativa
# Out:
#                          customer_id   age  occupation_status  years_employed  \
# customer_id                     1.00 -0.00               0.00            0.00
# age                            -0.00  1.00              -0.00            0.63
# occupation_status               0.00 -0.00               1.00           -0.26
# years_employed                  0.00  0.63              -0.26            1.00
# annual_income                  -0.00  0.26              -0.04            0.24
# credit_score                    0.00  0.37              -0.01            0.24
# credit_history_years            0.00  0.64               0.00            0.40
# savings_assets                  0.01  0.18              -0.02            0.13
# current_debt                   -0.01  0.18              -0.02            0.16
# defaults_on_file                0.00 -0.06               0.00           -0.04
# delinquencies_last_2yrs         0.00 -0.10               0.00           -0.06
# ...

# %%
np.corrcoef(DATA_1['age'], DATA_1['annual_income']) #utilizando librería numpy pero solo permite el cálculo entre dos variables
# Out:
# array([[1.       , 0.2648143],
#        [0.2648143, 1.       ]])

# %% [markdown]
# ### **Intervalos de Confianza**

# %% [markdown]
# Al trabajar con muestras, resulta importante conocer cuando cerca o lejos nos encontramos respecto del verdadero valor de la media o varianza de cada variable, principalmente

# %%
#se crean funciones para el cálculo de los intervalos
def IC_MEDIA_VARDESCON(media_muestral, desv_muestral, N, alfa):
  import scipy.stats as ss
  ESTADÍSTICO= ss.t.ppf(1-(alfa/2), N-1)
  Li=media_muestral - ESTADÍSTICO*(desv_muestral/(N**0.5))
  Ls=media_muestral + ESTADÍSTICO*(desv_muestral/(N**0.5))
  if Li>Ls:
    intervalo='ERROR'
  else:
    INTERVALO=(Li, Ls)
    from IPython.display import display, Math
    intervalo_media=display(Math('IC['+str(round(INTERVALO[0],4))+'\leq \mu \leq'+ str(round(INTERVALO[1],4))+']='+str(1-alfa)))
  return intervalo_media


def IC_VARIANZA(media_muestral, desv_muestral, N, alfa):
   import scipy.stats as ss
   ESTADÍSTICO_1= ss.chi2.ppf(1-(alfa/2), N-1)
   ESTADÍSTICO_2= ss.chi2.ppf((alfa/2), N-1)
   Li=(N-1)*(desv_muestral**2) / ESTADÍSTICO_1
   Ls=(N-1)*(desv_muestral**2) / ESTADÍSTICO_2
   if Li <0 or Li>Ls:
     intervalo='ERROR'
   else:
     INTERVALO=(Li, Ls)
     from IPython.display import display, Math
     intervalo_var=display(Math('IC['+str(round(INTERVALO[0],4))+'\leq \sigma^2 \leq'+ str(round(INTERVALO[1],4))+']='+str(1-alfa)))
   return intervalo_var

# %%
for i in DATA:
  if DATA[i].dtype=='int64' or DATA[i].dtype=='float64':
    print(f"El intervalo de confianza para la media de la variable {i} es:")
    IC_MEDIA_VARDESCON(DATA[i].mean(), DATA[i].std(),len(DATA[i]),0.05)
    print(f"El intervalo de confianza para la varianza de la variable {i} es:")
    IC_VARIANZA(DATA[i].mean(), DATA[i].std(),len(DATA[i]),0.05)
# Out:
# El intervalo de confianza para la media de la variable age es:
# $\displaystyle IC[34.8596\leq \mu \leq35.0545]=0.95$
# El intervalo de confianza para la varianza de la variable age es:
# $\displaystyle IC[122.1051\leq \sigma^2 \leq125.1702]=0.95$
# El intervalo de confianza para la media de la variable years_employed es:
# $\displaystyle IC[7.3881\leq \mu \leq7.5216]=0.95$
# El intervalo de confianza para la varianza de la variable years_employed es:
# $\displaystyle IC[57.2324\leq \sigma^2 \leq58.6691]=0.95$
# El intervalo de confianza para la media de la variable annual_income es:
# $\displaystyle IC[49776.8714\leq \mu \leq50348.9127]=0.95$
# El intervalo de confianza para la varianza de la variable annual_income es:
# $\displaystyle IC[1051673230.444\leq \sigma^2 \leq1078072518.3156]=0.95$
# El intervalo de confianza para la media de la variable credit_score es:
# $\displaystyle IC[643.0474\leq \mu \leq644.1822]=0.95$
# ...

# %% [markdown]
# Para otros intervalos ver: https://github.com/TGADEstadisticaI/EstadisticaI/tree/main

# %% [markdown]
# ### **Test de hipótesis**

# %% [markdown]
# Al trabajar con muestras, también nos puede interesar validar algún suposición sobre la verdadera media o varianza de cada variable, principalmente

# %%
def TH_MEDIA_VARDESCON(media_muestral, mu, S, n, alfa, simbolo_H1):
  import scipy.stats as ss
  import numpy as np
  tobs=round((media_muestral-mu) / (S/np.sqrt(n)),4)
  if simbolo_H1=='>':
    talfa  = round(ss.t.ppf(1-alfa, n-1),4)
    if tobs > talfa:
      respuesta='Como se cumple C.D ya que ' + 'tobs='+str(tobs)+' es mayor que '+ 't_1-alfa;n-1='+str(talfa)+' entonces se rechaza H0'
    else:
      respuesta='Como no se cumple C.D ya que ' + 'tobs='+str(tobs)+' es menor que '+ 't_1-alfa;n-1='+str(talfa)+' entonces no se rechaza H0'

    p_valor=round(1-ss.t.cdf(tobs, n-1),8)
    if p_valor < alfa:
      respuesta1='Como se cumple C.D ya que ' + 'P-valor='+str(p_valor)+  ' es menor que '+ 'alfa='+ str(alfa)+' entonces se rechaza H0'
    else:
      respuesta1='Como no se cumple C.D ya que ' + 'P-valor='+str(p_valor)+  ' es mayor que '+ 'alfa='+ str(alfa)+' entonces no se rechaza H0'

  elif simbolo_H1=='<':
    talfa  = round(ss.t.ppf(alfa, n-1),4)
    if tobs < talfa:
      respuesta='Como se cumple C.D ya que ' + 'tobs='+str(tobs)+' es menor que '+ 'talfa;n-1='+str(talfa)+' entonces se rechaza H0'
    else:
      respuesta='Como no se cumple C.D ya que ' + 'tobs='+str(tobs)+' es mayor que '+ 'talfa;n-1='+str(talfa)+' entonces no se rechaza H0'

    p_valor=round(ss.t.cdf(tobs, n-1),8)
    if p_valor < alfa:
      respuesta1='Como se cumple C.D ya que ' + 'P-valor='+str(p_valor)+  ' es menor que '+ 'alfa='+ str(alfa)+' entonces se rechaza H0'
    else:
      respuesta1='Como no se cumple C.D ya que ' + 'P-valor='+str(p_valor)+  ' es mayor que '+ 'alfa='+ str(alfa)+' entonces no se rechaza H0'

  else:
    talfa  = round(ss.t.ppf(1-alfa/2, n-1),4)
    if np.abs(tobs) > talfa:
      respuesta='Como se cumple C.D ya que ' + '|tobs|='+'|'+str(tobs)+'|'+' es mayor que '+ 't_1-alfa/2;n-1='+str(talfa)+' entonces se rechaza H0'
    else:
      respuesta='Como no se cumple C.D ya que ' + '|tobs|='+'|'+str(tobs)+'|'+' es menor que '+ 't_1-alfa/2;n-1='+str(talfa)+' entonces no se rechaza H0'

    p_valor=2*round(1-ss.t.cdf(abs(tobs), n-1),8)
    if p_valor < alfa:
      respuesta1='Como se cumple C.D ya que ' + 'P-valor='+str(p_valor)+  ' es menor que '+ 'alfa='+ str(alfa)+' entonces se rechaza H0'
    else:
      respuesta1='Como no se cumple C.D ya que ' + 'P-valor='+str(p_valor)+  ' es mayor que '+ 'alfa='+ str(alfa)+' entonces no se rechaza H0'

  return respuesta, respuesta1

def TH_MEDIA_VARIANZA(var_muestral, var_pob, n, alfa, simbolo_H1):
  import scipy.stats as ss
  import numpy as np
  chiobs=round((n-1)*var_muestral / var_pob,4)
  if simbolo_H1=='>':
    chialfa  = round(ss.chi2.ppf(1-alfa, n-1),4)
    if chiobs > chialfa:
      respuesta='Como se cumple C.D ya que ' + 'chiobs='+str(chiobs)+' es mayor que '+ 'Chi_1-alfa;n-1='+str(chialfa)+' entonces se rechaza H0'
    else:
      respuesta='Como no se cumple C.D ya que ' + 'chiobs='+str(chiobs)+' es menor que '+ 'Chi_1-alfa;n-1='+str(chialfa)+' entonces no se rechaza H0'

    p_valor=round(1-ss.chi2.cdf(chiobs, n-1),8)
    if p_valor < alfa:
      respuesta1='Como se cumple C.D ya que ' + 'P-valor='+str(p_valor)+  ' es menor que '+ 'alfa='+ str(alfa)+' entonces se rechaza H0'
    else:
      respuesta1='Como no se cumple C.D ya que ' + 'P-valor='+str(p_valor)+  ' es mayor que '+ 'alfa='+ str(alfa)+' entonces no se rechaza H0'

  elif simbolo_H1=='<':
    chialfa  = round(ss.chi2.ppf(alfa, n-1),4)
    if chiobs < chialfa:
      respuesta='Como se cumple C.D ya que ' + 'chiobs='+str(chiobs)+' es menor que '+ 'chialfa;n-1='+str(chialfa)+' entonces se rechaza H0'
    else:
      respuesta='Como no se cumple C.D ya que ' + 'chiobs='+str(chiobs)+' es mayor que '+ 'chialfa;n-1='+str(chialfa)+' entonces no se rechaza H0'

    p_valor=round(ss.chi2.cdf(chiobs, n-1),8)
    if p_valor < alfa:
      respuesta1='Como se cumple C.D ya que ' + 'P-valor='+str(p_valor)+  ' es menor que '+ 'alfa='+ str(alfa)+' entonces se rechaza H0'
    else:
      respuesta1='Como no se cumple C.D ya que ' + 'P-valor='+str(p_valor)+  ' es mayor que '+ 'alfa='+ str(alfa)+' entonces no se rechaza H0'

  else:
    chialfa  = round(ss.chi2.ppf(1-alfa/2, n-1),4)
    if np.abs(chiobs) > chialfa:
      respuesta='Como se cumple C.D ya que ' + '|chiobs|='+'|'+str(chiobs)+'|'+' es mayor que '+ 'Chi_1-alfa/2;n-1='+str(chialfa)+' entonces se rechaza H0'
    else:
      respuesta='Como no se cumple C.D ya que ' + '|chiobs|='+'|'+str(chiobs)+'|'+' es menor que '+ 'Chi_1-alfa/2;n-1='+str(chialfa)+' entonces no se rechaza H0'

    p_valor=2*np.min([round(1-ss.chi2.cdf(chiobs, n-1),8), round(ss.chi2.cdf(chiobs, n-1),8)])
    if p_valor < alfa:
      respuesta1='Como se cumple C.D ya que ' + 'P-valor='+str(p_valor)+  ' es menor que '+ 'alfa='+ str(alfa)+' entonces se rechaza H0'
    else:
      respuesta1='Como no se cumple C.D ya que ' + 'P-valor='+str(p_valor)+  ' es mayor que '+ 'alfa='+ str(alfa)+' entonces no se rechaza H0'

  return respuesta, respuesta1

# %%
TH_MEDIA_VARIANZA(DATA[i].var(), 30,  len(DATA[i]),0.05, '>')
# Out:
# ('Como no se cumple C.D ya que chiobs=412.423 es menor que Chi_1-alfa;n-1=50520.2777 entonces no se rechaza H0',
#  'Como no se cumple C.D ya que P-valor=1.0 es mayor que alfa=0.05 entonces no se rechaza H0')

# %%
#aplicarlos a todoas juntas teniendo en cuenta que se esta fijando un único valor de parámetro poblacional (si no correr de manera individual)
for i in DATA:
  if DATA[i].dtype=='int64' or DATA[i].dtype=='float64':
    print(f"El resultado del test de hipótesis para la media de la variable {i} es: {TH_MEDIA_VARDESCON(DATA[i].mean(), 20 ,DATA[i].std(),len(DATA[i]),0.05,'>')[0]}")
    print(f"El resultado del test de hipótesis para la media de la variable {i} es: {TH_MEDIA_VARDESCON(DATA[i].mean(), 20 ,DATA[i].std(),len(DATA[i]),0.05,'>')[1]}")
    print(f"El resultado del test de hipótesis para la varianza de la variable {i} es: {TH_MEDIA_VARIANZA(DATA[i].var(), 30,  len(DATA[i]),0.05, '>')[0]}")
    print(f"El resultado del test de hipótesis para la varianza de la variable {i} es: {TH_MEDIA_VARIANZA(DATA[i].var(), 30,  len(DATA[i]),0.05, '>')[1]}")
# Out:
# El resultado del test de hipótesis para la media de la variable age es: Como se cumple C.D ya que tobs=300.8022 es mayor que t_1-alfa;n-1=1.6449 entonces se rechaza H0
# El resultado del test de hipótesis para la media de la variable age es: Como se cumple C.D ya que P-valor=0.0 es menor que alfa=0.05 entonces se rechaza H0
# El resultado del test de hipótesis para la varianza de la variable age es: Como se cumple C.D ya que chiobs=206034.7603 es mayor que Chi_1-alfa;n-1=50520.2777 entonces se rechaza H0
# El resultado del test de hipótesis para la varianza de la variable age es: Como se cumple C.D ya que P-valor=0.0 es menor que alfa=0.05 entonces se rechaza H0
# El resultado del test de hipótesis para la media de la variable years_employed es: Como no se cumple C.D ya que tobs=-368.5157 es menor que t_1-alfa;n-1=1.6449 entonces no se rechaza H0
# ...

# %% [markdown]
# Para otros test ver: https://github.com/TGADEstadisticaI/EstadisticaI/tree/main
