# %% [markdown]
# <figure>
# <center>
# <img src='https://www.economicas.uba.ar/wp-content/uploads/2020/08/cropped-logo_FCE.png' />
# </figure>

# %% [markdown]
# # **Universidad de Buenos Aires**
# ## **Facultad de Ciencias Económicas**
#
# ### **Taller de Programación para el Análisis de Datos**
#
# #### **Práctica Unidad 2 Tercera parte**

# %% [markdown]
# En base al material (ejemplos y actividades) visto en clase, resuelva los siguientes ejercicios

# %%
import pandas as pd
import numpy as np
import kagglehub
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ###**Ejercicio 1**

# %% [markdown]
# **Cree una función denoiminada descarga que devuelva el path donde se descargó el siguiente DataFrame : https://www.kaggle.com/datasets/janiobachmann/bank-marketing-dataset Luego utilicelá para leer el dataframe con pandas (deberpa completar /NOMBREARCHIVO.csv)**

# %% [markdown]
# **Cree una función que devuelva un gráfico de barras (usando plotly) con la cantidad para una variable categórica ingresada por el usuario**

# %% [markdown]
# **Cree una función que devuelva un boxplot para la variable que ingrese el usuario, considerando la posibilidad de utilizar más de una variable para multiples boxplots**

# %% [markdown]
# **Cree una función que devuelva un scatterplot para dos variables que ingrese el usuario, considerando la posibilidad de utilizar filtros para clasificar**

# %% [markdown]
# **Cree una función que devuelva un gráfico de torta para uan variable que ingrese el usuario**

# %% [markdown]
# ###**Ejercicio 2**

# %% [markdown]
# **Cree una función donde el usuario ingrese uno o varios tickers (symbolo del activo) separado por coma y sin espacio, fecha de inicio, fecha de fin, descargue la cotización de cierre diaria (deberá concatenar) y devuelva un solo gráfico de líneas con todos los activos**

# %% [markdown]
# ###**EJERCICIO 3**

# %% [markdown]
# **Busque datos de su interés para graficar y cree diversos gráficos que permitan describir características. Al final, interprete en celdas de texto**
